# %% [markdown]
# # Daten kombinieren

# %% [markdown]
# **Inhalt:** Verschiedene Quellen kombinieren, optisch und tabellarisch auswerten
#
# **Nötige Skills:** Daten explorieren, filtern, klassifizieren
#
# **Lernziele:**
# - Besser verstehen, wie Merge funktioniert
# - Daten kombinieren, Hypothesen testen
# - Einführung in Geopandas

# %% [markdown]
# # Das Beispiel
#
# Der Immobilienboom hat die Schweiz über die letzten Jahre stark geprägt.
#
# Dazu haben wir Daten aus verschiedenen Quellen, die wir kombinieren möchten:
# - Bevölkerungsdaten aus Schweizer Gemeinden (BFS)
# - Wohnungsbau in Schweizer Gemeinden (BFS)
# - Leerwohnungsziffer in Schweizer Gemeinden (BFS)
#
# Anhand dieser Daten wollen wir herausfinden:
# - Welche Gemeinden sind am meisten gewachsen? Wo wurde am stärksten am Markt vorbeigebaut?
#
# Und natürlich wollen wir unsere Resultate schön darstellen.

# %% [markdown]
# ## Vorbereitung

# %% [markdown]
# Wir importieren ausnahmsweise etwas mehr Bibliotheken als sonst...

# %%
import pandas as pd

# %%
import geopandas as gpd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-5-a62d01c1d62e> in <module>
# ----> 1 import geopandas as gpd
#
# ModuleNotFoundError: No module named 'geopandas'

# %%
from shapely.geometry import Point
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-df8e65c5217a> in <module>
# ----> 1 from shapely.geometry import Point
#
# ModuleNotFoundError: No module named 'shapely'

# %%
import matplotlib

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %% [markdown]
# ## Daten laden

# %% [markdown]
# ### Einwohnerzahlen

# %% [markdown]
# Wir starten mit einem File, das die Einwohnerzahl der Schweizer Gemeinden beinhaltet, für alle Jahre von 1981 bis 2016.

# %%
df_bev = pd.read_excel('dataprojects/immobilienboom/data/BFS Gemeinden Einwohnerzahlen.xlsx')

# %% [markdown]
# Check: Wie viele Gemeinden sind enthalten?

# %%
df_bev.shape
# Out:
# (2282, 38)

# %%
df_bev.head(2)
# Out:
#    Gemeindenummer Gemeindename    1981    1982    1983    1984    1985  \
# 0             261       Zürich  370103  366040  363449  356665  354525
# 1            6621       Genève  156617  157322  158426  158806  159527
#
#      1986    1987    1988  ...    2007    2008    2009    2010    2011  \
# 0  351545  349549  346879  ...  350125  358540  365132  368677  372857
# 1  159895  160645  161473  ...  178603  179971  183287  185958  187470
#
#      2012    2013    2014    2015    2016
# 0  376990  380777  384786  391359  396955
# 1  188234  189033  191557  194565  198072
#
# [2 rows x 38 columns]

# %% [markdown]
# **Tipp:** Um sämtliche Spalten anzuzeigen, können wir bei Pandas die Display-Option anders einstellen:

# %%
pd.set_option("display.max_columns", 50)

# %%
df_bev.head(2)
# Out:
#    Gemeindenummer Gemeindename    1981    1982    1983    1984    1985  \
# 0             261       Zürich  370103  366040  363449  356665  354525
# 1            6621       Genève  156617  157322  158426  158806  159527
#
#      1986    1987    1988    1989    1990    1991    1992    1993    1994  \
# 0  351545  349549  346879  345159  342861  341934  343267  345235  343045
# 1  159895  160645  161473  163998  165404  168530  169025  170189  171744
#
#      1995    1996    1997    1998    1999    2000    2001    2002    2003  \
# 0  342872  343869  341250  338594  336821  336822  337035  340197  342116
# 1  172737  173549  172425  172586  172809  173519  174691  175697  177306
#
#      2004    2005    2006    2007    2008    2009    2010    2011    2012  \
# 0  342853  345236  347517  350125  358540  365132  368677  372857  376990
# 1  178500  178487  178722  178603  179971  183287  185958  187470  188234
#
#      2013    2014    2015    2016
# 0  380777  384786  391359  396955
# 1  189033  191557  194565  198072

# %% [markdown]
# ### Wohnungszahlen

# %% [markdown]
# Wir haben drei Files für die Anzahl der Wohnungen:
#
# - **eines für die totale Anzahl Wohnungen pro Gemeinde, von 2009 bis 2016**

# %%
df_wohn_tot = pd.read_excel('dataprojects/immobilienboom/data//BFS Anzahl Wohnungen Total.xlsx')

# %% [markdown]
# **Check:** Wie viele Gemeinden sind im File?

# %%
df_wohn_tot.shape
# Out:
# (2287, 10)

# %%
df_wohn_tot.head(3)
# Out:
#    Gemeindenummer        Gemeindename  2009  2010  2011  2012  2013  2014  \
# 0               1     Aeugst am Albis   689   856   856   870   875   876
# 1               2  Affoltern am Albis  4904  5170  5201  5286  5427  5477
# 2               3          Bonstetten  2242  2289  2303  2302  2320  2354
#
#    2015  2016
# 0   887   891
# 1  5527  5614
# 2  2383  2428

# %% [markdown]
# - **eines für die Wohnungen in Einfamilienhäusern**

# %%
df_wohn_efh = pd.read_excel('dataprojects/immobilienboom/data/BFS Anzahl Wohnungen EFH.xlsx')

# %%
df_wohn_efh.head(2)
# Out:
#    Gemeindenummer        Gemeindename  2009  2010  2011  2012  2013  2014  \
# 0               1     Aeugst am Albis   314   384   384   388   381   380
# 1               2  Affoltern am Albis  1077  1085  1087  1090  1086  1087
#
#    2015  2016
# 0   381   380
# 1  1082  1081

# %% [markdown]
# - **eines für die Anzahl der Wohnungen in Mehrfamilienhäuser**

# %%
df_wohn_mfh = pd.read_excel('dataprojects/immobilienboom/data/BFS Anzahl Wohnungen MFH.xlsx')

# %%
df_wohn_mfh.head(2)
# Out:
#    Gemeindenummer        Gemeindename  2009  2010  2011  2012  2013  2014  \
# 0               1     Aeugst am Albis   280   372   374   381   387   391
# 1               2  Affoltern am Albis  2959  3051  3068  3173  3327  3365
#
#    2015  2016
# 0   401   402
# 1  3428  3453

# %% [markdown]
# ### Leerwohnungsziffern

# %% [markdown]
# Schliesslich haben wir eine Datei, welche die aktuelle Leerwohnungsziffer für jede Gemeinde beinhaltet.

# %%
df_lwz = pd.read_excel('dataprojects/immobilienboom/data/BFS Leerwohnungsziffer 2017.xlsx')

# %% [markdown]
# **Check:** Wie viele Gemeinden sind drin? (Hint: nicht genau gleich viele wie im anderen File...)

# %%
df_lwz.shape
# Out:
# (2240, 3)

# %%
df_lwz.head(2)
# Out:
#    Gemeindenummer            Gemeinde  Leerwohnungsziffer
# 0               1     Aeugst am Albis            2.581369
# 1               2  Affoltern am Albis            1.229070

# %% [markdown]
# ## Analyse

# %% [markdown]
# Wir möchten nun die drei (fünf) Tabellen gemeinsam auswerten, und zwar im Hinblick auf Fragen wie:
# - Was sind Gemeinden, die einen starken Bauboom hatten und nun eine hohe Leerwohnungsziffer aufweisen?
# - Haben die Leerstände etwas mit der Gemeindegrösse zu tun, gibt es in Städten höhere/tiefere Ziffern als in Dörfern?
#
# Um Fragen dieser Art zu beantworten, müssen wir uns zwei Dinge überlegen:
# 1. Was sind geeignete Indikatoren, die wir konkret bilden wollen, um unsere Fragen zu beantworten?
# 2. Wie bringen wir die verschiedenen Indikatoren zusammen, um sie gemeinsam auszuwerten?
#
# Wir starten mal mit der ersten Überlegung...

# %% [markdown]
# ### Indikatoren bilden

# %% [markdown]
# Wir wählen zu Analysezwecken drei Indikatoren aus:
# - das Bevölkerungswachstum zwischen 2009 und 2016, in Prozent
# - das Wohnungswachstum (total) zwischen 2009 und 2016, in Prozent
# - die Leerwohungsziffer 2017, in Prozent
#
# Zwei der drei Indikatoren müssen wir erst noch bilden.

# %%
df_bev['Bevölkerungswachstum'] = (df_bev['2016'] / df_bev['2009'] - 1) * 100

# %%
df_bev.head(2)
# Out:
#    Gemeindenummer Gemeindename    1981    1982    1983    1984    1985  \
# 0             261       Zürich  370103  366040  363449  356665  354525
# 1            6621       Genève  156617  157322  158426  158806  159527
#
#      1986    1987    1988    1989    1990    1991    1992    1993    1994  \
# 0  351545  349549  346879  345159  342861  341934  343267  345235  343045
# 1  159895  160645  161473  163998  165404  168530  169025  170189  171744
#
#      1995    1996    1997    1998    1999    2000    2001    2002    2003  \
# 0  342872  343869  341250  338594  336821  336822  337035  340197  342116
# 1  172737  173549  172425  172586  172809  173519  174691  175697  177306
#
#      2004    2005    2006    2007    2008    2009    2010    2011    2012  \
# 0  342853  345236  347517  350125  358540  365132  368677  372857  376990
# 1  178500  178487  178722  178603  179971  183287  185958  187470  188234
#
#      2013    2014    2015    2016  Bevölkerungswachstum
# 0  380777  384786  391359  396955              8.715478
# 1  189033  191557  194565  198072              8.066584

# %%
df_wohn_tot['Wohnungswachstum Total'] = (df_wohn_tot['2016'] / df_wohn_tot['2009'] - 1) * 100
# -1 weil Prozentausrechnen (wert_neu/wert_alt -1) *100 = Prozent

# %%
df_wohn_tot.head(2)
# Out:
#    Gemeindenummer        Gemeindename  2009  2010  2011  2012  2013  2014  \
# 0               1     Aeugst am Albis   689   856   856   870   875   876
# 1               2  Affoltern am Albis  4904  5170  5201  5286  5427  5477
#
#    2015  2016  Wohnungswachstum Total
# 0   887   891               29.317852
# 1  5527  5614               14.477977

# %% [markdown]
# ### Tabellen zusammenführen

# %% [markdown]
# Nun müssen wir die drei Indikatoren in einer Tablle zusammenbringen. Wir benutzen dazu die Funktion `merge()`:
#
# **1. zunächst schliessen wir die Wohnungszahlen mit den Bevölkerungszahlen zusammen:**

# %%
df_1 = df_bev.merge(df_wohn_tot, how='inner', on='Gemeindenummer')
df_1.head(2)
# Out:
#    Gemeindenummer Gemeindename_x    1981    1982    1983    1984    1985  \
# 0             261         Zürich  370103  366040  363449  356665  354525
# 1            6621         Genève  156617  157322  158426  158806  159527
#
#      1986    1987    1988    1989    1990    1991    1992    1993    1994  \
# 0  351545  349549  346879  345159  342861  341934  343267  345235  343045
# 1  159895  160645  161473  163998  165404  168530  169025  170189  171744
#
#      1995    1996    1997    1998    1999    2000    2001    2002    2003  \
# 0  342872  343869  341250  338594  336821  336822  337035  340197  342116
# 1  172737  173549  172425  172586  172809  173519  174691  175697  177306
#
#      2004    2005    2006    2007    2008  2009_x  2010_x  2011_x  2012_x  \
# 0  342853  345236  347517  350125  358540  365132  368677  372857  376990
# 1  178500  178487  178722  178603  179971  183287  185958  187470  188234
#
#    2013_x  2014_x  2015_x  2016_x  Bevölkerungswachstum Gemeindename_y  \
# 0  380777  384786  391359  396955              8.715478         Zürich
# 1  189033  191557  194565  198072              8.066584         Genève
#
#    2009_y  2010_y  2011_y  2012_y  2013_y  2014_y  2015_y  2016_y  \
# 0  207183  208090  209701  211942  214470  215608  218586  220940
# 1  101701  104440  104760  105217  106075  106313  107056  107474
#
#    Wohnungswachstum Total
# 0                6.640024
# 1                5.676444

# %% [markdown]
# Pandas hat nun anhand der Gemeindenummer (einem unique identifier) die beiden Dataframes fusioniert.

# %% [markdown]
# **Frage:** Wie viele Gemeinden sind im neuen Dataframe enthalten? Woher kommt diese Zahl?
#
# Und: Wie viele Gemeinden wären enthalten, wenn wir `how='outer'` gewählt hätten? Warum?

# %%
#Antwort
df_1.shape
# Out:
# (2282, 49)

# %%
df_bev.merge(df_wohn_tot, how='outer', on='Gemeindenummer').shape
#df1.merge(df2, how='outer', on = 'Spaltenname(df1==df2)')

#inner: schnittmenge
#outer: alle infos darum herum
#left: alles links davon, auch bei Leerstellen
# Out:
# (2287, 49)

# %%
df_bev.head()
# Out:
#    Gemeindenummer Gemeindename    1981    1982    1983    1984    1985  \
# 0             261       Zürich  370103  366040  363449  356665  354525
# 1            6621       Genève  156617  157322  158426  158806  159527
# 2            2701        Basel  181852  180347  179583  177788  176227
# 3            5586     Lausanne  126306  126298  126675  126750  126211
# 4             351         Bern  146793  145285  143816  142060  140612
#
#      1986    1987    1988    1989    1990    1991    1992    1993    1994  \
# 0  351545  349549  346879  345159  342861  341934  343267  345235  343045
# 1  159895  160645  161473  163998  165404  168530  169025  170189  171744
# 2  174606  173160  171574  170080  169587  172785  174604  175510  176220
# 3  125004  124206  124022  123468  122600  117487  117518  117571  117153
# 4  138574  137134  136292  135147  134393  130844  130818  130069  129423
#
#      1995    1996    1997    1998    1999    2000    2001    2002    2003  \
# 0  342872  343869  341250  338594  336821  336822  337035  340197  342116
# 1  172737  173549  172425  172586  172809  173519  174691  175697  177306
# 2  175561  174007  172945  171170  168735  166678  165785  164665  164916
# 3  116795  115878  114510  114022  114161  114518  114536  115272  116073
# 4  128422  127469  125936  124412  123254  122686  122788  122211  122559
#
#      2004    2005    2006    2007    2008    2009    2010    2011    2012  \
# 0  342853  345236  347517  350125  358540  365132  368677  372857  376990
# 1  178500  178487  178722  178603  179971  183287  185958  187470  188234
# 2  164802  164964  163930  163081  163521  164937  166173  163216  164516
# 3  116811  117389  117388  118049  119180  122284  125885  127821  129383
# 4  122299  122304  122178  122422  122658  122925  123466  124381  125681
#
#      2013    2014    2015    2016  Bevölkerungswachstum
# 0  380777  384786  391359  396955              8.715478
# 1  189033  191557  194565  198072              8.066584
# 2  165566  167386  168620  169916              3.018728
# 3  130421  132788  133897  135629             10.913120
# 4  127515  128848  130015  131554              7.019727

# %%
df_bev['Bevölkerungswachstum'].value_counts()
# Out:
#  0.000000     15
# -1.515152      3
#  1.680672      2
#  5.319149      2
#  3.703704      2
#  2.836879      2
#  1.923077      2
# -15.686275     2
#  3.793103      2
#  6.730769      2
# -1.282051      2
#  2.588997      2
#  6.535948      2
#  4.545455      2
# -10.526316     2
#  1.990050      2
# -0.975610      2
#  1.115242      2
#  5.263158      2
#  2.500000      2
#  6.122449      2
# -5.128205      2
#  12.956811     2
# -5.454545      2
#  10.666667     2
#  6.896552      2
#  0.491803      2
#  6.818182      2
#  5.303030      2
# -3.968254      2
#               ..
#  11.618257     1
#  15.478516     1
#  17.400722     1
#  17.129630     1
#  5.494505      1
#  12.850655     1
#  21.635012     1
#  12.130926     1
#  5.912299      1
#  0.495540      1
#  8.251017      1
#  0.192725      1
#  3.356890      1
#  5.187320      1
#  2.146691      1
# -4.915254      1
#  11.958406     1
#  15.283019     1
#  0.602293      1
# -1.859504      1
#  14.595362     1
#  7.450000      1
#  15.922330     1
#  8.604207      1
#  9.363296      1
# -2.718759      1
#  8.774921      1
#  8.531995      1
#  0.252101      1
#  21.558989     1
# Name: Bevölkerungswachstum, Length: 2234, dtype: int64

# %% [markdown]
# **Quiz:** Finden Sie die fünf Gemeinden, die in der Bevölkerungszahlen-Tabelle nicht enthalten sind.

# %%
#Antwort

# %% [markdown]
# **2. Nun nehmen wir noch die Leerwohnungsziffer dazu**

# %%
df_2 = df_1.merge(df_lwz, how='inner', on='Gemeindenummer')

# %%
df_2.head(2)
# Out:
#    Gemeindenummer Gemeindename_x    1981    1982    1983    1984    1985  \
# 0             261         Zürich  370103  366040  363449  356665  354525
# 1            6621         Genève  156617  157322  158426  158806  159527
#
#      1986    1987    1988    1989    1990    1991    1992    1993    1994  \
# 0  351545  349549  346879  345159  342861  341934  343267  345235  343045
# 1  159895  160645  161473  163998  165404  168530  169025  170189  171744
#
#      1995    1996    1997    1998    1999    2000    2001    2002    2003  \
# 0  342872  343869  341250  338594  336821  336822  337035  340197  342116
# 1  172737  173549  172425  172586  172809  173519  174691  175697  177306
#
#    ...    2005    2006    2007    2008  2009_x  2010_x  2011_x  2012_x  \
# 0  ...  345236  347517  350125  358540  365132  368677  372857  376990
# 1  ...  178487  178722  178603  179971  183287  185958  187470  188234
#
#    2013_x  2014_x  2015_x  2016_x  Bevölkerungswachstum  Gemeindename_y  \
# 0  380777  384786  391359  396955              8.715478          Zürich
# 1  189033  191557  194565  198072              8.066584          Genève
#
#    2009_y  2010_y  2011_y  2012_y  2013_y  2014_y  2015_y  2016_y  \
# 0  207183  208090  209701  211942  214470  215608  218586  220940
# 1  101701  104440  104760  105217  106075  106313  107056  107474
#
#    Wohnungswachstum Total  Gemeinde Leerwohnungsziffer
# 0                6.640024    Zürich           0.205486
# 1                5.676444    Genève           0.573162
#
# [2 rows x 51 columns]

# %% [markdown]
# **Tipp:** Es lohnt sich, bei merge-Operationen ein neues Dataframe zu erstellen, sonst gibt es schnell mal ein Chaos.

# %% [markdown]
# Weil wir an den meisten Infos in diese Tabelle gar nicht interessiert sind, selektieren wir etwas, auch der Übersichtlichkeit halber.
#
# Wir wählen nur unsere drei Indikatoren sowie den aktuellen Bevölkerungsstand.

# %%
df_3 = df_2[['Gemeindenummer', 'Gemeinde', '2016_x', 'Bevölkerungswachstum', 'Wohnungswachstum Total', 'Leerwohnungsziffer']].copy()
df_3.rename(columns={'2016_x': 'Bevölkerung'}, inplace=True)
df_3.head(2)
# Out:
#    Gemeindenummer Gemeinde  Bevölkerung  Bevölkerungswachstum  \
# 0             261   Zürich       396955              8.715478
# 1            6621   Genève       198072              8.066584
#
#    Wohnungswachstum Total  Leerwohnungsziffer
# 0                6.640024            0.205486
# 1                5.676444            0.573162

# %% [markdown]
# Wir sind nun bereit für eine erste Analyse - am einfachsten mit ein paar Scatterplots, da sieht man schnell mal, ob etwas zusammenhängt.

# %% [markdown]
# ### Charts

# %% [markdown]
# **Frage:** Wie hängen Wohnungswachstum und Leerwohnungsziffer zusammen?

# %%
df_3.plot(kind='scatter', x='Bevölkerungswachstum', y='Leerwohnungsziffer', figsize=(10,7))

# %% [markdown]
# Antwort: In einigen Gemeinden ist die Bevölkerung sehr stark gewachsen, dort sind die Leerstände allerdings nicht so gross. Tendenziell am meisten Leerstände gibt es in der Mitte der Verteilung. Schrumpfende Gemeinden haben meist nicht ganz so hohe Leerstände.

# %% [markdown]
# Wir können den Plot übrigens noch etwas aufhübschen und die Punkte nach Bevölkerungsgrösse skalieren...

# %%
area = df_3['Bevölkerung'] / 1000
df_3.plot(kind='scatter', x='Bevölkerungswachstum', y='Leerwohnungsziffer', s=area, alpha=0.6, figsize=(10,7))

# %% [markdown]
# **Quiz:** Wie hängt das Wohnungswachstum mit dem Bevölkerungswachstum zusammen? Zeichnen Sie einen Plot.

# %%
#Antwort
df_bev.merge(df_wohn_tot, how='outer', on='Gemeindenummer').sort_values('Bevölkerungswachstum')
# Out:
#       Gemeindenummer          Gemeindename_x    1981    1982    1983    1984  \
# 1210            3986                Tujetsch  1319.0  1358.0  1328.0  1339.0
# 2281            5102                 Corippo    45.0    41.0    38.0    44.0
# 2254            6011            Zwischbergen   176.0   177.0   181.0   182.0
# 2222            3669              Tschappina   153.0   163.0   159.0   158.0
# 2221            6773             Beurnevésin   175.0   176.0   180.0   179.0
# 2266            5309               Cerentino    50.0    49.0    49.0    45.0
# 2277             972                  Berken    61.0    59.0    59.0    57.0
# 2172            3837                 Calanca   221.0   218.0   212.0   224.0
# 2220            6759                  Soubey   156.0   160.0   163.0   162.0
# 2236            6716              Mettembert    62.0    62.0    64.0    67.0
# 2276            3707               Lohn (GR)    36.0    33.0    33.0    33.0
# 2275             715              Rebévelier    50.0    51.0    48.0    49.0
# 2246            3804                  Buseno   127.0   124.0   121.0   112.0
# 2260            3691             Hinterrhein    72.0    72.0    69.0    68.0
# 2197            1204                   Bauen   176.0   173.0   165.0   175.0
# 1881             877           Niedermuhlern   494.0   495.0   511.0   508.0
# 2239            5105                  Frasco    60.0    56.0    55.0    55.0
# 2278             708                Schelten    55.0    54.0    53.0    53.0
# 1908            6075     Reckingen-Gluringen   482.0   497.0   505.0   509.0
# 1626            5077                Pollegio   694.0   690.0   703.0   682.0
# 2211            5662                 Brenles   123.0   116.0   126.0   124.0
# 2175            6793                  Lugnez   202.0   196.0   192.0   194.0
# 2184             325    Busswil bei Melchnau   206.0   206.0   193.0   200.0
# 2116            6102                 Albinen   248.0   247.0   246.0   240.0
# 666             5072                   Faido  3450.0  3468.0  3467.0  3374.0
# 2097            2612            Beinwil (SO)   333.0   325.0   326.0   318.0
# 1968            3983         Medel (Lucmagn)   463.0   457.0   444.0   439.0
# 2114            6195                  Ferden   329.0   332.0   329.0   331.0
# 2267            3703       Casti-Wergenstein    36.0    39.0    37.0    40.0
# 1833            6715               Mervelier   454.0   442.0   447.0   450.0
# ...              ...                     ...     ...     ...     ...     ...
# 1914            2039        Rueyres-les-Prés   191.0   191.0   190.0   191.0
# 877             4041            Stetten (AG)   945.0   980.0   989.0   995.0
# 2189            5915           Essert-Pittet    97.0   100.0   105.0   105.0
# 1096            5456                Cudrefin   605.0   609.0   606.0   616.0
# 1155            2010                 Cheyres   379.0   370.0   393.0   417.0
# 1175             102                  Weiach   683.0   662.0   672.0   669.0
# 1374            5553               Champagne   499.0   503.0   492.0   495.0
# 527              224                 Pfungen  2132.0  2158.0  2142.0  2070.0
# 597             2198          Granges-Paccot  1121.0  1077.0  1075.0  1114.0
# 2166            5557  Fontaines-sur-Grandson    98.0    87.0    89.0    92.0
# 1521            5484                 Gollion   391.0   400.0   378.0   386.0
# 603             5675                  Lucens  2013.0  2036.0  1987.0  2006.0
# 1054            6611                  Chancy   547.0   555.0   547.0   536.0
# 1385            5537      Villars-le-Terroir   518.0   519.0   526.0   542.0
# 1872            5513          Bioley-Orjulaz   160.0   157.0   152.0   156.0
# 2111            2049                Vuissens   142.0   145.0   142.0   140.0
# 2017            5819                 Henniez   255.0   263.0   261.0   269.0
# 1395            5408                 Noville   416.0   417.0   426.0   440.0
# 2235            5063                Bedretto    67.0    65.0    57.0    55.0
# 787             5523             Froideville   992.0  1027.0  1056.0  1087.0
# 1102            5716                  Eysins   546.0   559.0   549.0   560.0
# 1090            5413              Roche (VD)   778.0   758.0   784.0   809.0
# 1793            5471                 Bettens   204.0   208.0   210.0   211.0
# 2136            5701          Arnex-sur-Nyon    63.0    62.0    60.0    65.0
# 1507            5708      Chavannes-des-Bois   228.0   236.0   218.0   236.0
# 2282            4546                     NaN     NaN     NaN     NaN     NaN
# 2283            4683                     NaN     NaN     NaN     NaN     NaN
# 2284            4723                     NaN     NaN     NaN     NaN     NaN
# 2285            4724                     NaN     NaN     NaN     NaN     NaN
# 2286            4786                     NaN     NaN     NaN     NaN     NaN
#
#         1985    1986    1987    1988    1989    1990    1991    1992    1993  \
# 1210  1344.0  1316.0  1303.0  1305.0  1300.0  1332.0  1509.0  1532.0  1522.0
# 2281    45.0    41.0    39.0    39.0    39.0    38.0    40.0    38.0    38.0
# 2254   176.0   179.0   181.0   184.0   187.0   191.0   184.0   190.0   179.0
# 2222   161.0   160.0   162.0   164.0   162.0   163.0   151.0   162.0   161.0
# 2221   178.0   178.0   179.0   174.0   160.0   159.0   164.0   163.0   157.0
# 2266    51.0    54.0    56.0    58.0    59.0    60.0    57.0    56.0    55.0
# 2277    58.0    63.0    61.0    59.0    60.0    60.0    58.0    57.0    56.0
# 2172   235.0   231.0   232.0   235.0   239.0   235.0   243.0   251.0   245.0
# 2220   165.0   156.0   150.0   141.0   142.0   132.0   150.0   149.0   145.0
# 2236    80.0    77.0    84.0    91.0    94.0    93.0   106.0   116.0   122.0
# 2276    32.0    30.0    29.0    27.0    30.0    33.0    47.0    49.0    48.0
# 2275    50.0    50.0    49.0    48.0    47.0    46.0    51.0    49.0    48.0
# 2246   111.0   113.0   110.0   109.0   106.0   105.0   114.0   110.0   110.0
# 2260    75.0    74.0    75.0    76.0    74.0    73.0    74.0    78.0    81.0
# 2197   174.0   173.0   169.0   172.0   172.0   178.0   213.0   220.0   224.0
# 1881   505.0   496.0   508.0   502.0   493.0   496.0   504.0   515.0   513.0
# 2239    59.0    61.0    65.0    64.0    65.0    61.0    71.0    77.0    86.0
# 2278    54.0    56.0    54.0    56.0    62.0    62.0    57.0    53.0    58.0
# 1908   508.0   511.0   516.0   526.0   526.0   530.0   542.0   529.0   529.0
# 1626   707.0   678.0   660.0   675.0   676.0   674.0   682.0   702.0   727.0
# 2211   122.0   116.0   120.0   126.0   138.0   132.0   144.0   144.0   132.0
# 2175   195.0   200.0   201.0   192.0   204.0   205.0   227.0   232.0   231.0
# 2184   198.0   201.0   202.0   204.0   210.0   206.0   196.0   198.0   204.0
# 2116   242.0   249.0   250.0   262.0   252.0   256.0   259.0   258.0   260.0
# 666   3328.0  3283.0  3227.0  3247.0  3247.0  3239.0  3325.0  3347.0  3379.0
# 2097   325.0   322.0   310.0   310.0   296.0   296.0   320.0   315.0   324.0
# 1968   436.0   432.0   428.0   421.0   418.0   413.0   490.0   491.0   496.0
# 2114   331.0   337.0   357.0   356.0   351.0   350.0   353.0   346.0   343.0
# 2267    44.0    40.0    41.0    40.0    43.0    44.0    52.0    51.0    52.0
# 1833   433.0   421.0   438.0   435.0   459.0   449.0   511.0   512.0   553.0
# ...      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 1914   188.0   201.0   207.0   208.0   203.0   205.0   223.0   238.0   235.0
# 877   1029.0  1201.0  1282.0  1301.0  1330.0  1326.0  1396.0  1487.0  1499.0
# 2189   111.0   122.0   113.0   114.0   127.0   113.0   122.0   124.0   136.0
# 1096   620.0   638.0   661.0   676.0   680.0   695.0   729.0   743.0   786.0
# 1155   420.0   453.0   487.0   495.0   540.0   535.0   532.0   560.0   574.0
# 1175   685.0   704.0   721.0   709.0   692.0   731.0   744.0   758.0   775.0
# 1374   491.0   480.0   478.0   496.0   490.0   500.0   530.0   563.0   608.0
# 527   2072.0  2036.0  2084.0  2196.0  2225.0  2278.0  2269.0  2277.0  2318.0
# 597   1218.0  1357.0  1406.0  1500.0  1630.0  1692.0  1595.0  1681.0  1741.0
# 2166   100.0   102.0   100.0    96.0    98.0    98.0   102.0   107.0   104.0
# 1521   404.0   410.0   403.0   402.0   418.0   429.0   431.0   429.0   451.0
# 603   2016.0  2031.0  2031.0  2025.0  2029.0  2092.0  2144.0  2236.0  2280.0
# 1054   574.0   577.0   608.0   630.0   631.0   630.0   660.0   716.0   738.0
# 1385   544.0   554.0   563.0   565.0   573.0   576.0   595.0   594.0   604.0
# 1872   162.0   160.0   159.0   162.0   184.0   196.0   225.0   226.0   247.0
# 2111   141.0   148.0   152.0   156.0   156.0   160.0   163.0   168.0   166.0
# 2017   267.0   262.0   261.0   238.0   248.0   250.0   268.0   259.0   263.0
# 1395   454.0   463.0   453.0   476.0   458.0   481.0   532.0   550.0   556.0
# 2235    65.0    66.0    68.0    65.0    64.0    59.0    67.0    73.0    70.0
# 787   1141.0  1179.0  1210.0  1249.0  1247.0  1264.0  1314.0  1327.0  1348.0
# 1102   597.0   631.0   686.0   705.0   699.0   703.0   780.0   791.0   817.0
# 1090   852.0   881.0   887.0   889.0   878.0   859.0   880.0   880.0   903.0
# 1793   193.0   203.0   204.0   213.0   213.0   212.0   214.0   242.0   230.0
# 2136    67.0    68.0    69.0    71.0    82.0    99.0   116.0   104.0   106.0
# 1507   236.0   243.0   253.0   270.0   289.0   290.0   312.0   333.0   330.0
# 2282     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2283     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2284     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2285     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2286     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#         1994    1995    1996    1997    1998    1999    2000    2001    2002  \
# 1210  1515.0  1506.0  1490.0  1497.0  1480.0  1580.0  1597.0  1549.0  1567.0
# 2281    35.0    34.0    33.0    31.0    29.0    28.0    33.0    24.0    24.0
# 2254   173.0   177.0   159.0   161.0   162.0   160.0   158.0   152.0   127.0
# 2222   172.0   167.0   171.0   166.0   165.0   173.0   172.0   166.0   159.0
# 2221   152.0   147.0   161.0   170.0   160.0   167.0   170.0   166.0   162.0
# 2266    54.0    53.0    55.0    53.0    53.0    58.0    58.0    62.0    62.0
# 2277    57.0    56.0    61.0    58.0    57.0    53.0    50.0    50.0    49.0
# 2172   248.0   253.0   258.0   263.0   252.0   260.0   245.0   247.0   242.0
# 2220   147.0   145.0   144.0   151.0   147.0   147.0   145.0   135.0   144.0
# 2236   118.0   119.0   123.0   119.0   129.0   129.0   127.0   118.0   130.0
# 2276    50.0    48.0    51.0    52.0    56.0    57.0    57.0    48.0    44.0
# 2275    46.0    43.0    44.0    42.0    39.0    41.0    42.0    31.0    32.0
# 2246   108.0   113.0   116.0   115.0   115.0   116.0   112.0   110.0   117.0
# 2260    87.0    89.0    82.0    79.0    78.0    88.0   104.0   102.0    96.0
# 2197   229.0   230.0   235.0   237.0   227.0   226.0   217.0   227.0   215.0
# 1881   514.0   520.0   520.0   502.0   500.0   530.0   529.0   522.0   531.0
# 2239    91.0    83.0    86.0    90.0    96.0    98.0   106.0   104.0   104.0
# 2278    60.0    63.0    56.0    51.0    53.0    50.0    55.0    52.0    50.0
# 1908   548.0   578.0   590.0   600.0   593.0   577.0   570.0   546.0   550.0
# 1626   738.0   751.0   753.0   760.0   750.0   754.0   732.0   739.0   771.0
# 2211   136.0   137.0   136.0   140.0   145.0   147.0   157.0   165.0   168.0
# 2175   243.0   242.0   238.0   234.0   230.0   219.0   220.0   224.0   231.0
# 2184   208.0   203.0   203.0   200.0   205.0   198.0   191.0   191.0   191.0
# 2116   272.0   286.0   296.0   285.0   290.0   280.0   281.0   267.0   267.0
# 666   3433.0  3504.0  3502.0  3402.0  3420.0  3336.0  3304.0  3257.0  3199.0
# 2097   319.0   323.0   318.0   317.0   314.0   323.0   317.0   306.0   320.0
# 1968   487.0   481.0   489.0   499.0   506.0   499.0   510.0   498.0   499.0
# 2114   344.0   347.0   345.0   337.0   333.0   328.0   319.0   313.0   329.0
# 2267    49.0    47.0    49.0    45.0    44.0    52.0    52.0    57.0    54.0
# 1833   554.0   575.0   576.0   591.0   604.0   620.0   600.0   597.0   599.0
# ...      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 1914   246.0   244.0   249.0   254.0   247.0   246.0   246.0   241.0   243.0
# 877   1554.0  1597.0  1594.0  1574.0  1535.0  1553.0  1541.0  1571.0  1569.0
# 2189   136.0   128.0   125.0   127.0   131.0   128.0   118.0   124.0   127.0
# 1096   842.0   839.0   866.0   835.0   842.0   838.0   841.0   865.0   864.0
# 1155   574.0   573.0   609.0   624.0   653.0   672.0   682.0   691.0   726.0
# 1175   801.0   834.0   887.0   904.0   930.0   968.0   966.0  1007.0  1002.0
# 1374   643.0   644.0   654.0   654.0   658.0   670.0   662.0   648.0   657.0
# 527   2346.0  2349.0  2386.0  2453.0  2467.0  2443.0  2441.0  2471.0  2562.0
# 597   1754.0  1768.0  1790.0  1814.0  1823.0  1868.0  1955.0  1978.0  2046.0
# 2166   107.0   110.0   116.0   115.0   121.0   140.0   131.0   132.0   134.0
# 1521   446.0   461.0   501.0   513.0   510.0   531.0   566.0   558.0   567.0
# 603   2256.0  2270.0  2267.0  2239.0  2213.0  2176.0  2122.0  2175.0  2145.0
# 1054   782.0   804.0   831.0   824.0   835.0   838.0   877.0   911.0   902.0
# 1385   596.0   599.0   611.0   596.0   616.0   621.0   633.0   659.0   682.0
# 1872   272.0   270.0   276.0   279.0   287.0   287.0   289.0   284.0   284.0
# 2111   170.0   165.0   166.0   168.0   177.0   173.0   174.0   178.0   161.0
# 2017   263.0   267.0   262.0   247.0   249.0   252.0   245.0   244.0   242.0
# 1395   555.0   564.0   575.0   596.0   608.0   633.0   633.0   632.0   633.0
# 2235    71.0    73.0    72.0    71.0    77.0    82.0    80.0    77.0    80.0
# 787   1356.0  1366.0  1388.0  1435.0  1449.0  1458.0  1480.0  1469.0  1503.0
# 1102   860.0   866.0   857.0   830.0   851.0   852.0   859.0   838.0   833.0
# 1090   909.0   922.0   906.0   897.0   895.0   894.0   903.0   875.0   878.0
# 1793   240.0   233.0   241.0   266.0   271.0   291.0   299.0   301.0   304.0
# 2136   105.0   116.0   112.0   132.0   130.0   118.0   122.0   120.0   126.0
# 1507   357.0   400.0   421.0   427.0   413.0   417.0   437.0   437.0   423.0
# 2282     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2283     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2284     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2285     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2286     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#         2003    2004    2005    2006    2007    2008  2009_x  2010_x  2011_x  \
# 1210  1581.0  1707.0  1811.0  1845.0  1881.0  1852.0  1838.0  1791.0  1732.0
# 2281    24.0    20.0    17.0    17.0    18.0    19.0    18.0    15.0    12.0
# 2254   127.0   126.0   129.0   126.0   114.0   105.0   111.0   102.0    80.0
# 2222   160.0   158.0   162.0   160.0   162.0   162.0   161.0   142.0   141.0
# 2221   166.0   154.0   156.0   150.0   155.0   152.0   155.0   150.0   139.0
# 2266    68.0    69.0    69.0    66.0    65.0    63.0    65.0    57.0    60.0
# 2277    53.0    52.0    52.0    49.0    51.0    50.0    49.0    46.0    49.0
# 2172   239.0   237.0   240.0   229.0   229.0   227.0   228.0   233.0   218.0
# 2220   151.0   156.0   145.0   154.0   150.0   148.0   158.0   153.0   147.0
# 2236   126.0   133.0   129.0   126.0   134.0   131.0   128.0   121.0   123.0
# 2276    45.0    52.0    48.0    50.0    50.0    50.0    51.0    48.0    46.0
# 2275    34.0    49.0    49.0    49.0    50.0    51.0    51.0    48.0    47.0
# 2246   104.0   100.0    98.0   102.0   107.0   109.0   109.0   104.0   100.0
# 2260    84.0    96.0   105.0    97.0    85.0    78.0    78.0    74.0    71.0
# 2197   209.0   197.0   195.0   192.0   186.0   195.0   186.0   186.0   184.0
# 1881   530.0   529.0   525.0   518.0   529.0   538.0   543.0   538.0   464.0
# 2239   107.0   106.0   104.0   101.0   105.0   114.0   117.0   113.0   105.0
# 2278    50.0    53.0    51.0    51.0    50.0    49.0    44.0    45.0    41.0
# 1908   537.0   527.0   512.0   508.0   508.0   510.0   504.0   491.0   493.0
# 1626   807.0   888.0   992.0  1051.0   982.0   879.0   855.0   861.0   807.0
# 2211   166.0   165.0   169.0   168.0   173.0   166.0   166.0   164.0   161.0
# 2175   221.0   219.0   215.0   217.0   217.0   214.0   212.0   207.0   204.0
# 2184   194.0   193.0   191.0   193.0   183.0   202.0   195.0   190.0   201.0
# 2116   262.0   272.0   278.0   271.0   273.0   281.0   278.0   287.0   278.0
# 666   3252.0  3272.0  3321.0  3363.0  3447.0  3403.0  3407.0  3494.0  3382.0
# 2097   323.0   315.0   309.0   305.0   306.0   309.0   302.0   302.0   302.0
# 1968   491.0   487.0   480.0   473.0   464.0   455.0   443.0   451.0   435.0
# 2114   336.0   329.0   325.0   303.0   274.0   277.0   277.0   262.0   261.0
# 2267    54.0    57.0    58.0    61.0    60.0    60.0    59.0    58.0    58.0
# 1833   577.0   564.0   572.0   581.0   570.0   563.0   575.0   562.0   551.0
# ...      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 1914   251.0   250.0   251.0   252.0   282.0   303.0   312.0   320.0   320.0
# 877   1554.0  1534.0  1511.0  1521.0  1497.0  1526.0  1540.0  1565.0  1640.0
# 2189   129.0   124.0   122.0   122.0   126.0   120.0   118.0   132.0   134.0
# 1096   898.0   924.0   948.0   968.0  1034.0  1053.0  1090.0  1199.0  1289.0
# 1155   756.0   813.0   843.0   844.0   884.0   963.0  1006.0  1134.0  1153.0
# 1175  1012.0   970.0   987.0   959.0   966.0   994.0   982.0   992.0   987.0
# 1374   660.0   670.0   667.0   684.0   713.0   734.0   743.0   793.0   811.0
# 527   2665.0  2648.0  2647.0  2648.0  2629.0  2642.0  2660.0  2748.0  2971.0
# 597   2139.0  2134.0  2254.0  2260.0  2218.0  2322.0  2377.0  2477.0  2608.0
# 2166   140.0   139.0   140.0   137.0   134.0   135.0   135.0   142.0   145.0
# 1521   577.0   615.0   625.0   606.0   596.0   619.0   611.0   621.0   623.0
# 603   2191.0  2209.0  2267.0  2263.0  2217.0  2290.0  2352.0  2370.0  2685.0
# 1054   890.0   915.0   917.0   924.0  1022.0  1081.0  1120.0  1117.0  1150.0
# 1385   677.0   714.0   737.0   748.0   738.0   733.0   724.0   753.0   784.0
# 1872   281.0   301.0   330.0   324.0   334.0   342.0   329.0   409.0   452.0
# 2111   175.0   171.0   165.0   156.0   159.0   164.0   171.0   181.0   180.0
# 2017   236.0   242.0   242.0   238.0   242.0   236.0   236.0   234.0   247.0
# 1395   639.0   644.0   645.0   652.0   682.0   697.0   706.0   697.0   696.0
# 2235    80.0    68.0    70.0    71.0    78.0    83.0    74.0    67.0    64.0
# 787   1515.0  1512.0  1519.0  1524.0  1562.0  1612.0  1658.0  1727.0  1758.0
# 1102   843.0   865.0   925.0   944.0   960.0   995.0  1020.0  1195.0  1253.0
# 1090   877.0   876.0   895.0   894.0   897.0   900.0   946.0   956.0  1000.0
# 1793   288.0   287.0   288.0   296.0   305.0   330.0   328.0   347.0   339.0
# 2136   117.0   128.0   118.0   118.0   122.0   128.0   124.0   139.0   135.0
# 1507   426.0   424.0   425.0   416.0   396.0   422.0   458.0   518.0   555.0
# 2282     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2283     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2284     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2285     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2286     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#       2012_x  2013_x  2014_x  2015_x  2016_x  Bevölkerungswachstum  \
# 1210  1693.0  1542.0  1405.0  1359.0  1324.0            -27.965180
# 2281    12.0    12.0    12.0    13.0    13.0            -27.777778
# 2254    76.0    87.0    86.0    89.0    84.0            -24.324324
# 2222   139.0   137.0   138.0   128.0   126.0            -21.739130
# 2221   134.0   134.0   131.0   124.0   126.0            -18.709677
# 2266    58.0    62.0    61.0    56.0    53.0            -18.461538
# 2277    46.0    42.0    43.0    44.0    40.0            -18.367347
# 2172   214.0   205.0   206.0   187.0   187.0            -17.982456
# 2220   142.0   145.0   144.0   134.0   132.0            -16.455696
# 2236   114.0   114.0   112.0   105.0   107.0            -16.406250
# 2276    46.0    42.0    40.0    41.0    43.0            -15.686275
# 2275    46.0    45.0    45.0    44.0    43.0            -15.686275
# 2246   104.0    94.0    92.0    90.0    92.0            -15.596330
# 2260    65.0    66.0    63.0    65.0    66.0            -15.384615
# 2197   178.0   170.0   172.0   164.0   158.0            -15.053763
# 1881   477.0   461.0   471.0   466.0   463.0            -14.732965
# 2239   106.0   102.0   106.0   104.0   100.0            -14.529915
# 2278    39.0    34.0    40.0    40.0    38.0            -13.636364
# 1908   476.0   460.0   454.0   438.0   436.0            -13.492063
# 1626   782.0   786.0   762.0   762.0   741.0            -13.333333
# 2211   162.0   157.0   145.0   144.0   144.0            -13.253012
# 2175   203.0   192.0   190.0   191.0   184.0            -13.207547
# 2184   204.0   200.0   194.0   188.0   170.0            -12.820513
# 2116   266.0   268.0   257.0   251.0   243.0            -12.589928
# 666   3321.0  3255.0  3071.0  3038.0  2986.0            -12.356912
# 2097   286.0   282.0   271.0   277.0   265.0            -12.251656
# 1968   424.0   422.0   408.0   398.0   389.0            -12.189616
# 2114   260.0   255.0   254.0   248.0   244.0            -11.913357
# 2267    51.0    49.0    53.0    51.0    52.0            -11.864407
# 1833   553.0   527.0   529.0   522.0   508.0            -11.652174
# ...      ...     ...     ...     ...     ...                   ...
# 1914   349.0   362.0   376.0   423.0   432.0             38.461538
# 877   1671.0  1758.0  1958.0  2013.0  2139.0             38.896104
# 2189   148.0   151.0   152.0   150.0   164.0             38.983051
# 1096  1362.0  1426.0  1431.0  1462.0  1516.0             39.082569
# 1155  1240.0  1242.0  1338.0  1373.0  1411.0             40.258449
# 1175  1029.0  1083.0  1077.0  1158.0  1379.0             40.427699
# 1374   912.0   960.0  1001.0  1003.0  1048.0             41.049798
# 527   3310.0  3386.0  3535.0  3651.0  3757.0             41.240602
# 597   2729.0  2926.0  3102.0  3170.0  3358.0             41.270509
# 2166   153.0   148.0   154.0   183.0   191.0             41.481481
# 1521   663.0   727.0   792.0   812.0   866.0             41.734861
# 603   2855.0  3017.0  3163.0  3298.0  3334.0             41.751701
# 1054  1134.0  1129.0  1373.0  1519.0  1598.0             42.678571
# 1385   824.0   830.0   893.0   944.0  1034.0             42.817680
# 1872   440.0   460.0   456.0   458.0   470.0             42.857143
# 2111   204.0   228.0   253.0   253.0   245.0             43.274854
# 2017   263.0   276.0   266.0   287.0   339.0             43.644068
# 1395   720.0   785.0   912.0   971.0  1029.0             45.750708
# 2235    70.0    76.0    90.0   103.0   108.0             45.945946
# 787   1896.0  1989.0  2113.0  2315.0  2429.0             46.501809
# 1102  1342.0  1352.0  1398.0  1498.0  1506.0             47.647059
# 1090  1183.0  1388.0  1440.0  1521.0  1529.0             61.627907
# 1793   386.0   405.0   434.0   529.0   557.0             69.817073
# 2136   187.0   197.0   199.0   196.0   219.0             76.612903
# 1507   761.0   797.0   823.0   876.0   885.0             93.231441
# 2282     NaN     NaN     NaN     NaN     NaN                   NaN
# 2283     NaN     NaN     NaN     NaN     NaN                   NaN
# 2284     NaN     NaN     NaN     NaN     NaN                   NaN
# 2285     NaN     NaN     NaN     NaN     NaN                   NaN
# 2286     NaN     NaN     NaN     NaN     NaN                   NaN
#
#               Gemeindename_y  2009_y  2010_y  2011_y  2012_y  2013_y  2014_y  \
# 1210                Tujetsch    1668    1693    1692    1732    1748    1773
# 2281                 Corippo      71      71      71      71      71      71
# 2254            Zwischbergen      84      84      84      85      81      83
# 2222              Tschappina     177     180     180     184     184     184
# 2221             Beurnevésin      81      81      81      81      83      79
# 2266               Cerentino     142     142     143     143     143     143
# 2277                  Berken      21      21      21      21      21      21
# 2172                 Calanca     382     383     384     386     386     390
# 2220                  Soubey     151     153     153     153     153     153
# 2236              Mettembert      66      66      66      67      67      62
# 2276               Lohn (GR)      42      42      42      45      45      47
# 2275              Rebévelier      17      17      17      17      17      17
# 2246                  Buseno     154     155     155     155     155     155
# 2260             Hinterrhein      70      70      70      70      71      71
# 2197                   Bauen     112     114     114     114     116     118
# 1881           Niedermuhlern     227     230     233     233     233     234
# 2239                  Frasco     230     244     245     245     249     252
# 2278                Schelten      17      17      17      17      17      18
# 1908     Reckingen-Gluringen     599     596     600     613     616     615
# 1626                Pollegio     393     398     402     403     403     408
# 2211                 Brenles      65      67      67      67      67      67
# 2175                  Lugnez     100     100     100     100     100      93
# 2184    Busswil bei Melchnau      99      99      99     102     102     102
# 2116                 Albinen     346     347     350     350     350     355
# 666                    Faido    3487    3517    3539    3670    3695    3710
# 2097            Beinwil (SO)     127     128     127     127     127     127
# 1968         Medel (Lucmagn)     282     288     289     296     318     325
# 2114                  Ferden     182     194     194     193     193     195
# 2267       Casti-Wergenstein      61      62      66      67      67      67
# 1833               Mervelier     235     238     238     238     238     238
# ...                      ...     ...     ...     ...     ...     ...     ...
# 1914        Rueyres-les-Prés     125     130     134     137     145     167
# 877             Stetten (AG)     654     740     745     837     844     853
# 2189           Essert-Pittet      65      65      67      68      68      69
# 1096                Cudrefin     717     759     783     814     831     847
# 1155                 Cheyres     719     729     754     769     788     804
# 1175                  Weiach     443     452     486     492     496     557
# 1374               Champagne     343     351     391     412     416     424
# 527                  Pfungen    1255    1374    1536    1541    1579    1622
# 597           Granges-Paccot    1174    1215    1222    1300    1358    1368
# 2166  Fontaines-sur-Grandson      70      71      72      74      76      80
# 1521                 Gollion     280     280     290     304     358     371
# 603                   Lucens    1172    1371    1408    1479    1535    1571
# 1054                  Chancy     432     431     436     438     516     561
# 1385      Villars-le-Terroir     323     330     349     372     396     412
# 1872          Bioley-Orjulaz     170     186     190     199     200     199
# 2111                Vuissens      83      95      98     105     108     109
# 2017                 Henniez     122     126     130     133     133     131
# 1395                 Noville     290     304     319     368     405     434
# 2235                Bedretto     171     171     171     174     174     178
# 787              Froideville     691     727     765     825     905     963
# 1102                  Eysins     520     544     579     592     609     628
# 1090              Roche (VD)     478     496     583     656     682     685
# 1793                 Bettens     142     142     154     171     198     228
# 2136          Arnex-sur-Nyon      56      56      83      84      86      86
# 1507      Chavannes-des-Bois     186     212     323     326     326     329
# 2282            Schlatt (TG)     686     696     703     712     727     738
# 2283                 Lengwil     582     593     596     601     635     670
# 2284                 Braunau     277     284     292     294     303     314
# 2285               Eschlikon    1688    1703    1742    1837    1894    1898
# 2286              Wilen (TG)     830     826     831     848     895     943
#
#       2015_y  2016_y  Wohnungswachstum Total
# 1210    1777    1779                6.654676
# 2281      71      72                1.408451
# 2254      84      85                1.190476
# 2222     183     239               35.028249
# 2221      79      78               -3.703704
# 2266     153     155                9.154930
# 2277      21      21                0.000000
# 2172     392     393                2.879581
# 2220     153     153                1.324503
# 2236      63      65               -1.515152
# 2276      47      49               16.666667
# 2275      17      17                0.000000
# 2246     157     158                2.597403
# 2260      71      70                0.000000
# 2197     121     120                7.142857
# 1881     236     240                5.726872
# 2239     265     269               16.956522
# 2278      18      18                5.882353
# 1908     618     623                4.006678
# 1626     413     429                9.160305
# 2211      67      67                3.076923
# 2175      93      96               -4.000000
# 2184     102     102                3.030303
# 2116     357     358                3.468208
# 666     3776    3830                9.836536
# 2097     127     131                3.149606
# 1968     415     419               48.581560
# 2114     199     206               13.186813
# 2267      67      69               13.114754
# 1833     240     244                3.829787
# ...      ...     ...                     ...
# 1914     170     189               51.200000
# 877      932     951               45.412844
# 2189      71      76               16.923077
# 1096     876     909               26.778243
# 1155     818     823               14.464534
# 1175     665     704               58.916479
# 1374     435     437               27.405248
# 527     1653    1686               34.342629
# 597     1594    1621               38.074957
# 2166      81      85               21.428571
# 1521     412     429               53.214286
# 603     1578    1609               37.286689
# 1054     587     588               36.111111
# 1385     443     456               41.176471
# 1872     201     206               21.176471
# 2111     109     115               38.554217
# 2017     154     163               33.606557
# 1395     444     449               54.827586
# 2235     178     185                8.187135
# 787     1016    1072               55.137482
# 1102     634     655               25.961538
# 1090     686     740               54.811715
# 1793     231     243               71.126761
# 2136      86      86               53.571429
# 1507     333     356               91.397849
# 2282     767     781               13.848397
# 2283     704     717               23.195876
# 2284     319     321               15.884477
# 2285    1927    1938               14.810427
# 2286     972    1003               20.843373
#
# [2287 rows x 49 columns]

# %% [markdown]
# **Quiz:** Bilden Sie eine neue Kennzahl, die das Wohnungswachstum mit dem Bevölkerungswachstum vergleicht.
#
# Wie verhält sich diese Kennzal zur Leerwohnungsziffer?

# %%
#Antwort

# %% [markdown]
# Offensichtlich bringen uns diese Charts auch nicht viel weiter. Wir wissen jetzt zwar, dass die grossen Städte kein besonders hohes Wachstum verzeichneten und auch nicht sehr hohe Leerstände aufweisen, aber nicht viel mehr.
#
# Da hilft nur ein: Geopandas, to the rescue!

# %% [markdown]
# ## Geo Plots

# %% [markdown]
# Geopandas funktioniert sehr ähnlich wie Pandas - bietet aber zusätzliche Funktionalität!
#
# Zuerst müssen wir ein paar Geodaten laden, so genannte shape files.

# %% [markdown]
# ### Geodaten laden

# %% [markdown]
# Zuerst eines für die Schweizer Landesgrenzen...

# %%
gdf_ch = gpd.read_file('dataprojects/immobilienboom/shp/g1l17.shp')
gdf_ch.head(2)

# %% [markdown]
# ... dann eines für die Gemeinden...

# %%
gdf_gemeinden = gpd.read_file('dataprojects/immobilienboom/shp/g1g17.shp')
gdf_gemeinden.head(2)

# %% [markdown]
# ... und noch eines für die Seen!

# %%
gdf_lakes = gpd.read_file('dataprojects/immobilienboom/shp/g1s17.shp')
gdf_lakes.head(2)

# %% [markdown]
# Das coole an Geopandas ist: Man kann diese Shapefiles mit wenigen Zeilen Code zeichnen lassen.

# %%
ax = gdf_ch.plot(edgecolor='grey', color='white', alpha=1, linewidth=2, figsize=(20,13))
gdf_lakes.plot(edgecolor='grey', facecolor='lightblue', alpha=1, linewidth=1, ax=ax)
gdf_gemeinden.plot(edgecolor='grey', color='white', alpha=1, linewidth=0.2, ax=ax)
ax.axis('off')

# %% [markdown]
# Das hier brauchen wir später noch:

# %%
title_font = {
    'family': 'sans-serif',
    'color':  'black',
    'weight': 'bold',
    'size': 20
}
point_names = {
    'family': 'sans-serif',
    'color':  'black',
    'weight': 'normal',
    'size': 10
}

# %% [markdown]
# ### Geodaten mit den restlichen Infos verbinden

# %% [markdown]
# Damit wir auf der Karte nicht nur die Gemeinden einzeichnen können, sondern auch die restlichen Infos (zB die Leerwohnungsziffer), müssen wir erneut zwei Tabellen verschmelzen. Merke: In der Geodaten-Tabelle heisst das dazugehörige Index-Feld für die Gemeinenummer nicht "Gemeindenummer", sondern "GMDNR".

# %%
gdf_gemeinden_m = gdf_gemeinden.merge(df_3, how="inner", left_on="GMDNR", right_on="Gemeindenummer")

# %%
gdf_gemeinden_m.head(2)

# %% [markdown]
# ### Choropleth Maps

# %% [markdown]
# Machen wir mal einen ersten Plot, um zu schauen, welche Gemeinden einwohnermässig am meisten gewachsen sind.

# %%
#Selber Code wie oben, für die Landesgrenzen und die Seen
ax = gdf_ch.plot(edgecolor='grey', color='white', alpha=1, linewidth=2, figsize=(20,13))
gdf_lakes.plot(edgecolor='grey', facecolor='lightblue', alpha=1, linewidth=1, ax=ax)

#Code für die Gemeinden, eingefärbt nach der Spalte "Bevölkerungswachstum"
gdf_gemeinden_m.plot(edgecolor='grey', column='Bevölkerungswachstum', cmap='YlOrRd', scheme='quantiles', alpha=0.8, linewidth=0.5, ax=ax, legend=True)

my_title = "Bevölkerungswachstum in den Gemeinden zwischen 2009 und 2016"
plt.text(480000, 312000, my_title, fontdict=title_font)

ax.axis('off')

# %% [markdown]
# ### Dot Maps

# %% [markdown]
# Ich persönlich mag choropleth maps nicht so - viel lieber dot maps.
#
# Dazu müssen wir kurz die Geometrie unseres Geodataframes ändern (was das genau ist, wird später im Kurs noch behandelt)

# %%
gdf_gemeinden_m['point_geometry'] = gdf_gemeinden_m.apply(lambda row: Point(row.X_CNTR, row.Y_CNTR), axis=1)

# %%
gdf_gemeinden_m = gdf_gemeinden_m.set_geometry('point_geometry')

# %% [markdown]
# Plus, wir kreieren uns noch eine zusätzliche Spalte mit dem marker size:

# %%
#play around with the marker size
gdf_gemeinden_m['markersize'] = (gdf_gemeinden_m['Bevölkerung'] ** 0.5) / 1.5

# %% [markdown]
# Jetzt sind wir ready für diesen Plot-Typ

# %%
#Selber Code wie oben, für die Landesgrenzen und die Seen
ax = gdf_ch.plot(edgecolor='grey', color='#EEEEEE', alpha=1, linewidth=2, figsize=(20,13))
gdf_lakes.plot(edgecolor='grey', facecolor='lightblue', alpha=1, linewidth=1, ax=ax)

#Wir haben die Gemetrie zuvor auf einen Punkt gesetzt - darum kommt das jetzt etwas anders raus
gdf_gemeinden_m.plot(markersize=gdf_gemeinden_m['markersize'], column='Bevölkerungswachstum', cmap='YlOrRd', scheme='quantiles', alpha=0.7, linewidth=0.5, legend=True, ax=ax)

my_title = "Bevölkerungswachstum in den Gemeinden zwischen 2009 und 2016"
plt.text(480000, 312000, my_title, fontdict=title_font)

ax.axis('off')

# %% [markdown]
# Das schöne ist: Man sieht jetzt, wo die Gemeinden wirklich sind, und vor allem auch: wie gross sie sind.
#
# Es zeigt sich: Stark gewachsen ist die Bevölkerung vor allem um den Genfersee sowie im Raum Zug-Zürich.

# %% [markdown]
# Machen wir gleich noch einen Plot - mit den **Leerstandsziffern**

# %%
#Selber Code wie oben, für die Landesgrenzen und die Seen
ax = gdf_ch.plot(edgecolor='grey', color='#EEEEEE', alpha=1, linewidth=2, figsize=(20,13))
gdf_lakes.plot(edgecolor='grey', facecolor='lightblue', alpha=1, linewidth=1, ax=ax)

#Die Gemeinden, eingefärbt anhand der Leerwohnungsziffer
gdf_gemeinden_m.plot(markersize=gdf_gemeinden_m['markersize'], column='Leerwohnungsziffer', cmap='YlOrRd', scheme='quantiles', alpha=0.8, linewidth=0.5, legend=True, ax=ax)

my_title = "Leerwohnungsziffer 2017"
plt.text(480000, 312000, my_title, fontdict=title_font)

ax.axis('off')

# %% [markdown]
# Man sieht nun sehr rasch, wo die Problemzonen sind: im Mittelland, im Wallis, um den Bodensee.
#
# Die Frage ist: Können wir die "schlimmsten" Gemeinden irgendwie identifizieren?

# %% [markdown]
# ## Gemeinden filtern

# %% [markdown]
# Wir gehen jetzt einfach mal explorativ vor - und selektieren eine Reihe von Gemeinden anhand von bestimmten Kriterien, die wir als problematisch oder einfach nur als interessant erachten im Kontext des Immobilien-Baubooms der letzten Jahre.
#
# Zum Beispiel:
# - hohes Wohnungswachstum (>20%)
# - hohe Leerstandsziffer (>4%)
# - minimale Grösse (>500 Einwohner)
#
# Was sind das für Gemeinden?

# %%
gdf_gemeinden_1 = gdf_gemeinden_m[(gdf_gemeinden_m['Leerwohnungsziffer'] >= 4) & (gdf_gemeinden_m['Wohnungswachstum Total'] > 20) & (gdf_gemeinden_m['Bevölkerung'] > 500)]

# %%
gdf_gemeinden_1.sort_values('Wohnungswachstum Total', ascending=False)[['Gemeinde', 'Bevölkerung', 'Wohnungswachstum Total', 'Leerwohnungsziffer']]

# %% [markdown]
# Und wo sind sie?

# %%
#Selber Code wie oben, für die Landesgrenzen und die Seen
ax = gdf_ch.plot(edgecolor='grey', color='#EEEEEE', alpha=1, linewidth=2, figsize=(20,13))
gdf_lakes.plot(edgecolor='grey', facecolor='lightblue', alpha=1, linewidth=1, ax=ax)

#Die Gemeinden, eingefärbt anhand der Leerwohnungsziffer (Achtung, neue, angepasste Farbskala!)
gdf_gemeinden_1.plot(markersize=gdf_gemeinden_1['markersize'], column='Leerwohnungsziffer', cmap='YlOrRd', scheme='quantiles', alpha=0.8, linewidth=0.5, legend=True, ax=ax)

#Wir schreiben die Punkte noch an :-)
for i in gdf_gemeinden_1.index:
    y = gdf_gemeinden_1.loc[i, 'Y_CNTR']
    x = gdf_gemeinden_1.loc[i, 'X_MAX']
    gemeindename = gdf_gemeinden_1.loc[i, 'Gemeinde']
    plt.text(x, y, gemeindename, fontdict=point_names)

my_title = "Gemeinden mit hohen Leerständen und grossem Bauboom"
plt.text(480000, 312000, my_title, fontdict=title_font)

ax.axis('off')

# %% [markdown]
# Falls wir mal eine Reportage aus einer Gemeinde machen wollen, in der viel gebaut wurde - am Markt vorbei - wären das hier die Kandidaten!

# %% [markdown]
# ## Und nun, zum selber machen...
#
# Welches sind Gemeinden, die man sich näher anschauen sollte?
# 1. Wählen Wie Indikatoren aus, der Sie interessiert (zB: Einfamilienhäuser, Leerstände)
# 1. Verbinden Sie die Datensets
# 1. Geodaten und restliche Daten verbinden
# 1. Filtern Sie eine Reihe von Gemeinden heraus, die speziell auffallen
# 1. Plotten Sie diese Gemeinden auf einer Karte
#
# Keine Angst: Geopandas-Funktionen kommen erst im letzten Schritt rein.

# %% [markdown]
# ### 1. Indikatoren wählen

# %% [markdown]
# Gehen Sie nochmals ganz nach oben zurück, zum Teil "Analyse".
#
# Und berechnen Sie eine Reihe von Indikatoren, die Sie näher untersuchen wollen, aus den Tabellen "df_bev", "df_wohn_tot", "df_wohn_EFH", "df_wohn_MFH", "df_lwz". (Oder wenn Sie ganz verwegen sind: Holen Sie sich vom www.bfs.admin.ch irgendeine andere Statistik auf Gemeindeebene, welche die Gemeindenummer beinhaltet!)

# %% [markdown]
# ### 2. Tabellen zusammenführen
#
# Benutzen Sie die Funktion `merge()`, um ihre Zahlen in einer einzigen Tabelle zu verschmelzen!

# %% [markdown]
# ### 3. Geodaten mit Tabellen verbinden
# Holen Sie sich nochmals das originale Geodataframe "gdf_gemeinden". Führen Sie dieses zusammen mit ihrer Tabelle.

# %% [markdown]
# ### 4. Gemeinden filtern
# Spielen Sie mit den Parametern so lange, bis Sie eine Liste von ungefähr 30 Gemeinden erhalten, die alle ihre Kriterien erfüllen.

# %% [markdown]
# ### 5. Dot Map der gefilterten Gemeinden
# Die hohe Kunst des Programmierens ist: Code kopieren, Code anpassen. Nicht vergessen: Punkt-Geometrie im Geodataframe nochmals setzen!
