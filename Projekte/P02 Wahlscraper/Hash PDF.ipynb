# %%
# Hash PDF

# %%
# Import Zeug
import hashlib
import requests
import time
from bs4 import BeautifulSoup

# %%
# so eine Vorlage
with open('test_pdf.pdf', 'rb') as f:
    h1 = hashlib.sha256(f.read()).digest()
h2 = hashlib.sha256(pdf.content).digest() 
h1 == h2
True
# Out:
# True

# %%
# Test von Pycharm


base_url = "http://blog.manuelapaganini.ch/wordpress/das-hier-ist-ein-testeintrag/"

r = requests.get(base_url)
soup = BeautifulSoup(r.content, 'lxml')

pdf_link = soup.find("a", {"class": "fileName"})

pdf_link.get('href')
# Out:
# 'http://blog.manuelapaganini.ch/wordpress/wp-content/uploads/2019/10/test_pdf.pdf'

# %%
# access test page
# get link
# hash pdf in link
# save hash as file
# wait
# hash pdf in link
# save hash as file
# compare files
# restart


# import stuff
import time
import requests
from bs4 import BeautifulSoup


# define function
def get_pdf(url):
    r = requests.get(url)
    soup = BeautifulSoup(r.content, 'lxml')
    pdf_link = soup.find("a", {"class": "fileName"})
    # print(pdf_link.get('href'))
    return(pdf_link.get('href'))


# define variables
count = 1
base_url = "http://blog.manuelapaganini.ch/wordpress/das-hier-ist-ein-testeintrag/"
pdf = requests.get(get_pdf(base_url))
file1 = hash(pdf.content)
file2 = None

# compare files after timelapse
while count < 5:

    time.sleep(20)

    pdf = requests.get(get_pdf(base_url))
    file2 = hash(pdf.content)

    print("Same file.") if file1 == file2 else print("New file!")
    print("Count is ", count)

    file1 = file2
    count += 1

print("End of loop.")

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
from datetime import datetime

now = datetime.now()

url = "https://daslamm.ch/"
r = requests.get(url)
soup = BeautifulSoup(r.content, 'lxml')
titles = soup.find_all('h2')
lst = []
for title in titles:
    lst.append(title.text)

df = pd.DataFrame(lst)
df.to_csv(str(now)+"lamm_titel.csv")
# Out:
#                                                     0
# 0   Proteste in Chile: Ein Aufschrei gegen das neo...
# 1   Seit dem 21.10 arbeiten Frauen* unentgeltlich....
# 2                   Zahlen und Züge, Fakten und Flüge
# 3   Schweizer Waffengeschäfte mit chilenischen Mil...
# 4   „Ich habe mich selbst lange nicht als politisc...
# 5   Diese Schweiz verträgt keine grossen Veränderu...
# 6         Mattea Meyer, betreibt die SP Lagerpolitik?
# 7                                          Instagram
# 8                                         #Ernährung
# 9   Die 6 häufigsten Einwände gegen die sogenannte...
# 10  Glencores Meisterwerk im aufkommenden Genre de...
# 11  Drei Argumente gegen Plastikverpackungen – und...
# 12                                          #porträt
# 13  „Wenn Sie die Lieferkette nachvollziehen wolle...
# 14  Sexuelle Gewalt auf der Flucht: Ein Monat, ein...
# 15  Schweizer Incel (17): „Ich möchte eigentlich k...
# ...

# %%
from bs4 import BeautifulSoup
import requests
from datetime import datetime

now = datetime.now()

url = "https://daslamm.ch/"
r = requests.get(url)
soup = BeautifulSoup(r.content, 'lxml')
titles = soup.find_all('h2')
lst = []
for title in titles:
    lst.append(title.text)
    

lst = open("lamm_"+ str(now)+ ".txt","w")
