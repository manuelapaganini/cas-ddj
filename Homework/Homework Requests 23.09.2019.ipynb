# %% [markdown]
# Importiere die requests Library

# %%
import requests

# %% [markdown]
# Importiere die Pandas Library in der Kurzform.

# %%
import pandas as pd

# %%
from datetime import datetime

# %% [markdown]
# 1. Unter Verwendung der [USGS.gov Earthquake API](https://earthquake.usgs.gov) ziehe heraus, wieviele Erdbeben sich im August 2018 ereignet haben?

# %%
url = 'https://earthquake.usgs.gov/fdsnws/event/1/count?starttime=2018-08-01&endtime=2018-08-31'
response = requests.get(url)
response.text
# Out:
# '17045'

# %% [markdown]
# 2. Mache das gleiche für August 2017, 2016, 2015?

# %%
url_anfang = 'https://earthquake.usgs.gov/fdsnws/event/1/count?starttime=201'
url_mitte = '-01-01&endtime=201'
url_ende = '-12-31'
year = 5

for elem in range(5,8):
    print(url_anfang + str(elem) + url_mitte + str(elem) + url_ende)
    r = requests.get(url_anfang + str(elem) + url_mitte + str(elem) + url_ende)
    print("201" + str(elem) +":", str(r.text))
# Out:
# https://earthquake.usgs.gov/fdsnws/event/1/count?starttime=2015-01-01&endtime=2015-12-31
# 2015: 126613
# https://earthquake.usgs.gov/fdsnws/event/1/count?starttime=2016-01-01&endtime=2016-12-31
# 2016: 125699
# https://earthquake.usgs.gov/fdsnws/event/1/count?starttime=2017-01-01&endtime=2017-12-31
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-32ee3043fdea> in <module>
#       6 for elem in range(5,8):
#       7     print(url_anfang + str(elem) + url_mitte + str(elem) + url_ende)
# ----> 8     r = requests.get(url_anfang + str(elem) + url_mitte + str(elem) + url_ende)
#       9     print("201" + str(elem) +":", str(r.text))
#
# ~/anaconda3/lib/python3.7/site-packages/requests/api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~/anaconda3/lib/python3.7/site-packages/requests/api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# ~/anaconda3/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~/anaconda3/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~/anaconda3/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378             except TypeError:  # Python 3
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#     382                     # Remove the TypeError from the exception chain in Python 3;
#
# ~/anaconda3/lib/python3.7/http/client.py in getresponse(self)
#    1319         try:
#    1320             try:
# -> 1321                 response.begin()
#    1322             except ConnectionError:
#    1323                 self.close()
#
# ~/anaconda3/lib/python3.7/http/client.py in begin(self)
#     294         # read until we get a non-100 response
#     295         while True:
# --> 296             version, status, reason = self._read_status()
#     297             if status != CONTINUE:
#     298                 break
#
# ~/anaconda3/lib/python3.7/http/client.py in _read_status(self)
#     255
#     256     def _read_status(self):
# --> 257         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     258         if len(line) > _MAXLINE:
#     259             raise LineTooLong("status line")
#
# ~/anaconda3/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     295     def recv_into(self, *args, **kwargs):
#     296         try:
# --> 297             return self.connection.recv_into(*args, **kwargs)
#     298         except OpenSSL.SSL.SysCallError as e:
#     299             if self.suppress_ragged_eofs and e.args == (-1, 'Unexpected EOF'):
#
# ~/anaconda3/lib/python3.7/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1819             result = _lib.SSL_peek(self._ssl, buf, nbytes)
#    1820         else:
# -> 1821             result = _lib.SSL_read(self._ssl, buf, nbytes)
#    1822         self._raise_ssl_error(self._ssl, result)
#    1823
#
# KeyboardInterrupt:

# %% [markdown]
# 3. Zeige nur die Erdbeben an, die in den letzten 5 Jahren eine Mindeststärke von 5,5 hatten? (Neue Parameter kannst Du mit den Zeichen "&" ergänzen. Lese Dich in die Dokumentation ein, um noch mehr Parameter kennezulernen)

# %%
# Version 3

url = 'https://earthquake.usgs.gov/fdsnws/event/1/count?starttime=2014-09-23&endtime=2019-09-23&minmagnitude=5.5'
response = requests.get(url)
response.text
# Out:
# '2233'

# %%
#Version 2
#<- nur des letzten Monats, weil es sonst mein Jupyter Notebook sprengt.
url = 'https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=2019-08-22&endtime=2019-09-23&minmagnitude=5.5'
r = requests.get(url)
r = r.json()

erdbeben = r['features']

eine_liste = []
for item in erdbeben:
    magnitude = item['properties']['mag']
    place = item['properties']['place']
    
    mini_dict = {"Mangitude": magnitude, 
                "Place": place}
    eine_liste.append(mini_dict)
pd.DataFrame(eine_liste).head()
# Out:
#    Mangitude                              Place
# 0        5.6          79km ENE of Hihifo, Tonga
# 1        5.9   186km NNW of Saumlaki, Indonesia
# 2        5.6           6km N of Durres, Albania
# 3        5.7    76km NNE of Blimbing, Indonesia
# 4        6.0  71km NNE of Sumbersari, Indonesia

# %%
# Version 1

url = 'https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=2019-08-22&endtime=2019-09-23'
r = requests.get(url)
r = r.json()

erdbeben = r['features']

# %%
# real stuff <- nur des letzten Monats, weil es sonst mein Jupyter Notebook sprengt.

mag_lst = []

for item in erdbeben:
    #print(item['properties']['mag'])
    try:
        if float(item['properties']['mag']) >= 5.5:
            magnitude = item['properties']['mag']
            place = item['properties']['place']
        #zeit = item[['properties']['time']] <- für später

            mini_dict = {"Place": place,
                    "Magnitude": magnitude}
            mag_lst.append(mini_dict)
    except:
        print("The following event could not be processed: \n", item['properties'])

pd.DataFrame(mag_lst).head()
# Out:
#    Magnitude                              Place
# 0        5.6          79km ENE of Hihifo, Tonga
# 1        5.9   186km NNW of Saumlaki, Indonesia
# 2        5.6           6km N of Durres, Albania
# 3        5.7    76km NNE of Blimbing, Indonesia
# 4        6.0  71km NNE of Sumbersari, Indonesia

# %% [markdown]
# 4. Zeige eine Liste der 10 stärksten Erdbeben des laufenden Jahres an. (Nicht vergessen, nun musst Du die Methode wechseln. Nicht mehr "count", sondern "query").

# %%
# Grundvoraussetzungen

url_3 = 'https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=2019-01-01&endtime=2019-09-23&orderby=magnitude&limit=10'
r = requests.get(url_3)
r = r.json()

erdbeben = r['features']

# %%
# real stuff 

max_lst = []

for item in erdbeben:
    magnitude = item['properties']['mag']
    place = item['properties']['place']
    
    mini_dict = {"Mangitude": magnitude, 
                "Place": place}
    max_lst.append(mini_dict)

pd.DataFrame(max_lst)
# Out:
#    Mangitude                                      Place
# 0        8.0                   78km SE of Lagunas, Peru
# 1        7.6    46km SSE of Namatanai, Papua New Guinea
# 2        7.5               111km ESE of Palora, Ecuador
# 3        7.3  116km NE of L'Esperance Rock, New Zealand
# 4        7.3            292km NW of Saumlaki, Indonesia
# 5        7.2              93km NNE of Laiwui, Indonesia
# 6        7.1        33km NW of Bulolo, Papua New Guinea
# 7        7.1        2019 Ridgecrest Earthquake Sequence
# 8        7.0                 23km NNE of Azangaro, Peru
# 9        6.9       134km WSW of Kota Ternate, Indonesia

# %% [markdown]
# 5. Wo haben sich diese Erdbeben ereignet?

# %%
#siehe oben

# %% [markdown]
# 6. Ziehe auch die Zeit mit heraus?

# %%
max_lst = []

for item in erdbeben:
    magnitude = item['properties']['mag']
    place = item['properties']['place']
    zeit =      (item['properties']['time'])
    zeit = zeit/1000
    zeit =  datetime.utcfromtimestamp(zeit).strftime('%Y-%m-%d') #time.ctime(int(zeit))

    
    mini_dict = {"Mangitude": magnitude, 
                "Place": place,
                 "Time": zeit}
    
    max_lst.append(mini_dict)

pd.DataFrame(max_lst)
# Out:
#     Mangitude                                              Place        Time
# 0         5.6                          79km ENE of Hihifo, Tonga  2019-09-22
# 1         5.9                   186km NNW of Saumlaki, Indonesia  2019-09-21
# 2         5.6                           6km N of Durres, Albania  2019-09-21
# 3         5.7                    76km NNE of Blimbing, Indonesia  2019-09-19
# 4         6.0                  71km NNE of Sumbersari, Indonesia  2019-09-19
# 5         6.2                      73km NNE of Pendok, Indonesia  2019-09-19
# 6         5.5              112km SSE of Pondaguitan, Philippines  2019-09-18
# 7         5.8                     104km ENE of Laiwui, Indonesia  2019-09-14
# 8         5.5                          South of the Fiji Islands  2019-09-11
# 9         5.6                 203km SE of Sarangani, Philippines  2019-09-10
# 10        5.7                           255km W of Sitka, Alaska  2019-09-10
# 11        5.6                      23km SE of Bobon, Philippines  2019-09-10
# 12        5.5                         Southeast of Easter Island  2019-09-09
# 13        5.9                       74km SSW of Isangel, Vanuatu  2019-09-06
# 14        5.9                        284km WNW of Bandon, Oregon  2019-09-05
# 15        5.5                        Northern Mid-Atlantic Ridge  2019-09-05
# 16        5.6                                    Carlsberg Ridge  2019-09-05
# 17        5.8                         226km WNW of Pangai, Tonga  2019-09-04
# 18        5.9                        Northern Mid-Atlantic Ridge  2019-09-02
# 19        6.6                      34km NNE of Ndoi Island, Fiji  2019-09-01
# 20        5.5                         Southern East Pacific Rise  2019-09-01
# 21        5.7                         Southern East Pacific Rise  2019-08-31
# 22        5.5                           26km NW of Shwebo, Burma  2019-08-31
# 23        6.3                          285km W of Bandon, Oregon  2019-08-29
# 24        5.9                      141km ENE of Hachinohe, Japan  2019-08-28
# 25        5.6  185km S of Bristol Island, South Sandwich Islands  2019-08-28
# 26        5.6  156km S of Bristol Island, South Sandwich Islands  2019-08-28
# 27        6.6  131km S of Bristol Island, South Sandwich Islands  2019-08-27
# 28        5.5                     114km NNW of Nuku`alofa, Tonga  2019-08-24
# 29        6.0                           58km SW of Sola, Vanuatu  2019-08-24
# 30        5.6                         153km NNW of Sola, Vanuatu  2019-08-22
# 31        5.9              90km ESE of Sigave, Wallis and Futuna  2019-08-22

# %% [markdown]
# 7. Konvertiere die Unix Zeit zu leserlichen Zeit? (Suche nicht zu lange, schau mal an, wies im Pandas aussieht.)
