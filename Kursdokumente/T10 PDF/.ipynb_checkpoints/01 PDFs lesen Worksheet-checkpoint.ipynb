# %% [markdown]
# # PDFs Lesen

# %% [markdown]
# Zuerst importieren wir die Module die wir brauchen:

# %%
import camelot
import pandas as pd
import tabula

# %%
url = 'https://www.police.be.ch/police/de/index/ueber-uns/kantonspolizei/statistik/Verkehrsstatistik.assetref/dam/documents/POM/Police/de/Statistik/Bericht_110%20ohne%20AB_AS%20Gemeinden-Stand%202018%20%28D%29.pdf'

# %%
tables = camelot.read_pdf(url, pages='1')
tables
# Out:
# <TableList n=0>

# %%
# <- Das funktioniert nicht so ganz. Wir ändern die flavor-Einstellung, lattice ist standard.

tables = camelot.read_pdf(url, flavor='lattice', pages = '1')
tables
# Out:
# <TableList n=0>

# %%
# <- auch nicht. Wir ändern auf 'stream', dh camelot guckt nach Weissraum zwischen den Daten. 
tables = camelot.read_pdf(url, flavor='stream', pages = '1')
tables
# Out:
# <TableList n=1>

# %%
# Tada! Das hat funktioniert. Aber er nimmt nur bis zu einer gewissen Zeilen. Deshalb definieren wir noch  
# die Fläche auf der sich die Tabelle befindet.
tables_stream = camelot.read_pdf(url, flavor='stream', pages = 'all', table_areas=['0,842,595,0'])
tables_stream[1].df
# Out:
#                                  0  \
# 0
# 1                             2018
# 2          Unfälle und Verunfallte
# 3   nach Unfallfolgen und Gemeinde
# 4
# 5
# 6
# 7
# 8                            Total
# 9                         Cormoret
# 10                       Cortébert
# 11                           Court
# 12                      Courtelary
# 13                        Crémines
# 14                        Därligen
# 15                      Därstetten
# 16     Deisswil bei Münchenbuchsee
# 17                      Diemerswil
# 18                       Diemtigen
# 19             Diessbach bei Büren
# 20                        Dotzigen
# 21                      Dürrenroth
# 22                         Eggiwil
# 23                          Epsach
# 24                         Eriswil
# 25                            Eriz
# 26                          Erlach
# 27          Erlenbach im Simmental
# 28                         Ersigen
# 29                         Eschert
# 30                         Evilard
# 31                          Fahrni
# 32                         Farnern
# 33                       Ferenbalm
# 34                   Finsterhennen
# 35                Forst-Längenbühl
# 36                     Fraubrunnen
# 37                  Frauenkappelen
# 38                    Freimettigen
# 39                        Frutigen
# 40                            Gals
# 41                        Gampelen
# 42                       Gerzensee
# 43                         Golaten
# 44                       Gondiswil
# 45                          Graben
# 46                        Grandval
# 47                     Grindelwald
# 48                  Grossaffoltern
# 49                Grosshöchstetten
# 50                          Gsteig
# 51                     Gsteigwiler
# 52                      Guggisberg
# 53                   Gündlischwand
# 54                          Gurbrü
# 55                        Gurzelen
# 56                       Guttannen
# 57                         Habkern
# 58                         Hagneck
#
#                                                  1            2         3  \
# 0   Übersicht: Gemeinde ohne Autobahn, Autostrasse
# 1
# 2
# 3
# 4
# 5                                                   Unfälle mit
# 6                                      Unfälle mit    Personen-
# 7                                     Sach-schaden      schaden  Getötete
# 8                                            2 489        2 397        34
# 9                                                3            6         0
# 10                                               2            0         0
# 11                                               0            3         0
# 12                                               4            3         0
# 13                                               2            3         0
# 14                                               9            5         0
# 15                                               2            0         0
# 16                                               1            0         0
# 17                                               0            0         0
# 18                                               4            4         0
# 19                                               2            5         0
# 20                                               6            3         0
# 21                                               2            1         0
# 22                                               4            4         0
# 23                                               1            1         0
# 24                                               0            2         0
# 25                                               0            2         0
# 26                                               1            0         0
# 27                                               9            9         0
# 28                                               5            1         0
# 29                                               0            0         0
# 30                                               3            3         0
# 31                                               0            1         0
# 32                                               0            0         0
# 33                                               3            4         0
# 34                                               1            1         0
# 35                                               0            0         0
# 36                                               4            8         0
# 37                                               1            1         0
# 38                                               0            0         0
# 39                                              17           12         1
# 40                                               4            0         0
# 41                                               4            4         0
# 42                                               1            2         0
# 43                                               0            1         0
# 44                                               0            1         0
# 45                                               1            1         0
# 46                                               0            1         0
# 47                                               7            5         0
# 48                                               5            4         0
# 49                                               6            5         0
# 50                                               5            2         0
# 51                                               1            0         0
# 52                                               0            4         0
# 53                                               1            3         0
# 54                                               1            2         0
# 55                                               0            1         0
# 56                                               3            7         0
# 57                                               0            2         0
# 58                                               2            1         0
#
#             4           5           6                 7
# 0
# 1
# 2
# 3
# 4                   davon
# 5                 lebens-
# 6     Schwer-  bedrohlich   erheblich
# 7   verletzte  Verletzte¹  Verletzte¹  Leicht-verletzte
# 8         506          30         476             2 344
# 9           1           0           1                 8
# 10          0           0           0                 0
# 11          0           0           0                 3
# 12          3           0           3                 1
# 13          1           0           1                 2
# 14          0           0           0                 9
# 15          0           0           0                 0
# 16          0           0           0                 0
# 17          0           0           0                 0
# 18          2           0           2                 6
# 19          1           0           1                 4
# 20          1           0           1                 4
# 21          0           0           0                 1
# 22          2           0           2                 7
# 23          1           0           1                 0
# 24          1           0           1                 1
# 25          1           0           1                 1
# 26          0           0           0                 0
# 27          1           0           1                10
# 28          0           0           0                 2
# 29          0           0           0                 0
# 30          1           0           1                 2
# 31          1           0           1                 0
# 32          0           0           0                 0
# 33          1           0           1                 3
# 34          0           0           0                 1
# 35          0           0           0                 0
# 36          1           0           1                 8
# 37          0           0           0                 1
# 38          0           0           0                 0
# 39          5           1           4                 7
# 40          0           0           0                 0
# 41          1           0           1                 3
# 42          0           0           0                 2
# 43          0           0           0                 1
# 44          1           0           1                 0
# 45          0           0           0                 1
# 46          1           0           1                 0
# 47          1           0           1                 4
# 48          1           0           1                 4
# 49          1           0           1                 5
# 50          1           0           1                 1
# 51          0           0           0                 0
# 52          2           0           2                 2
# 53          0           0           0                 4
# 54          0           0           0                 2
# 55          0           0           0                 1
# 56          2           0           2                 7
# 57          1           1           0                 1
# 58          0           0           0                 1

# %% [markdown]
# ## Datenbereinigung

# %%
#Wir schauen uns nun die Seite 3 an, um unsere Befehle für eine Standard-Seite anzupassen. 
# (da die erste Seite häufig etwas abweicht von den folgenden)

test_df = tables_stream[3].df # <- .df ist ein camelot-Befehl.
test_df.head(10)
# Out:
#                                 0  \
# 0
# 1                            2018
# 2         Unfälle und Verunfallte
# 3  nach Unfallfolgen und Gemeinde
# 4
# 5
# 6
# 7
# 8                           Total
# 9                      Langenthal
#
#                                                 1            2         3  \
# 0  Übersicht: Gemeinde ohne Autobahn, Autostrasse
# 1
# 2
# 3
# 4
# 5                                                  Unfälle mit
# 6                                     Unfälle mit    Personen-
# 7                                    Sach-schaden      schaden  Getötete
# 8                                           2 489        2 397        34
# 9                                              35           46         1
#
#            4           5           6                 7
# 0
# 1
# 2
# 3
# 4                  davon
# 5                lebens-
# 6    Schwer-  bedrohlich   erheblich
# 7  verletzte  Verletzte¹  Verletzte¹  Leicht-verletzte
# 8        506          30         476             2 344
# 9          7           0           7                50

# %%
# <- soweit so cool, aber die Daten interessieren uns erst ab Zeile 9. Deshalb lesen wir die Tabelle erst ab da.
test_df[9:].head()
# Out:
#                       0   1   2  3  4  5  6   7
# 9            Langenthal  35  46  1  7  0  7  50
# 10  Langnau im Emmental  17  19  2  2  0  2  17
# 11              Lauenen   1   0  0  0  0  0   0
# 12               Laupen  12   5  0  0  0  0   6
# 13           Lauperswil   4  10  0  2  1  1  13

# %%
# diese Tabelle packen wir in eine Variable
data = test_df[9:]

# %% [markdown]
# data.columns = headers

# %%
# Jetzt kommt der Clou: wir erstellen eine For-Loop, welche die Daten jeder Seite zusammenklebt.  

ff = pd.DataFrame() # Leere liste, in die wir gleich die Seiten dazuholen. 

# Damit die Spalten wieder Überschriften haben, machen wir eine Liste mit neuen Spaltennamen
headers = ['Gemeinde', 'Sachschaden', 'Personenschaden', 'Getötete', 'Schwerverletzte', 
           'Lebensbedrohlich Verletzte' 'Erheblich Verletzte', 'Leichtverletzte']

for number in range(0, 8):
    temp = tables_stream[number].df
    temp = temp[9:]
    templcolumns = headers
    ff = pd.concat(ff, temp)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-86f39ee6912f> in <module>
#      11     temp = temp[9:]
#      12     templcolumns = headers
# ---> 13     ff = pd.concat(ff, temp)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     226                        keys=keys, levels=levels, names=names,
#     227                        verify_integrity=verify_integrity,
# --> 228                        copy=copy, sort=sort)
#     229     return op.get_result()
#     230
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/concat.py in __init__(self, objs, axis, join, join_axes, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     242             raise TypeError('first argument must be an iterable of pandas '
#     243                             'objects, you passed an object of type '
# --> 244                             '"{name}"'.format(name=type(objs).__name__))
#     245
#     246         if join == 'outer':
#
# TypeError: first argument must be an iterable of pandas objects, you passed an object of type "DataFrame"

# %%
ff.info()

# %%
def clean(elem):
    if elem == "":
        return 0
    else: return elem

ff = ff.applymap(clean)    # applymap ist eine Pandas-Funktion, die über die gesamte Tabelle geht.

# %%
# Zwischenzeitlich die Gemeinden löschen, und am Schluss hier wieder anhängen. Unterdessen alle anderen Spalten
# zu Ints verwandeln.

gem = ff['Gemeinde']
del ff['Gemeinde']
ff = ff.astype(int)
ff['Gemeinde'] = gem
ff = ff[['Gemeinde', 'Sachschaden', 'Personenschaden', 'Getötete', 'Schwerverletzte', 
           'Lebensbedrohlich Verletzte' 'Erheblich Verletzte', 'Leichtverletzte']].copy #um die Reihenfolge

# %%
#index anpassen
ff = ff.reset_index()
del ff['index']

# %%
ff
