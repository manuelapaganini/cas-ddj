# %% [markdown]
# # Daten Plotten

# %% [markdown]
# Jetzt geht es daran, die Daten sichtbar zu machen.

# %%
# import stuff

import pandas as pd
# %matplotlib inline

# %%
pd = pd.read_csv('Verzeichnis_per.csv')

# %%
pd
# Out:
#       Unnamed: 0                       Name Gender Person    ID  \
# 0              1        Abeztout Abderrahim   Herr      f  4423
# 1              2       Ackermann Christophe   Herr      m  1544
# 2              3              Ackermann Urs   Herr      m  3557
# 3              4                Adam Samuel   Herr      m  2628
# 4              5           Aebischer Adrian   Herr      m  1289
# 5              6        Aebischer Christoph   Herr      m  1580
# 6              7          Aebischer Fernand   Herr      m    36
# 7              8          Aebischer Florent   Herr      m  3328
# 8              9        Aebischer Jean-Marc   Herr      m  1038
# 9             10        Aebischer Jean-Marc   Herr      m  4664
# 10            11       Aebischer Jean-Marie   Herr      m   609
# 11            12           Aebischer Maryse   Frau      f   755
# 12            13           Aebischer Mélody   Frau      f  4438
# 13            14          Aebischer Nicolas   Herr      m  1035
# ...

# %%
pd['Unnamed: 0'].drop()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-e742453fc75f> in <module>
# ----> 1 pd['Unnamed: 0'].drop()
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3827         return super(Series, self).drop(labels=labels, axis=axis, index=index,
#    3828                                         columns=columns, level=level,
# -> 3829                                         inplace=inplace, errors=errors)
#    3830
#    3831     @Substitution(**_shared_doc_kwargs)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3771             axes, _ = self._construct_axes_from_arguments((index, columns), {})
#    3772         else:
# ...

# %%
pd.info
# Out:
# <bound method DataFrame.info of       Unnamed: 0                       Name Gender Person    ID  \
# 0              1        Abeztout Abderrahim   Herr      f  4423
# 1              2       Ackermann Christophe   Herr      m  1544
# 2              3              Ackermann Urs   Herr      m  3557
# 3              4                Adam Samuel   Herr      m  2628
# 4              5           Aebischer Adrian   Herr      m  1289
# 5              6        Aebischer Christoph   Herr      m  1580
# 6              7          Aebischer Fernand   Herr      m    36
# 7              8          Aebischer Florent   Herr      m  3328
# 8              9        Aebischer Jean-Marc   Herr      m  1038
# 9             10        Aebischer Jean-Marc   Herr      m  4664
# 10            11       Aebischer Jean-Marie   Herr      m   609
# 11            12           Aebischer Maryse   Frau      f   755
# 12            13           Aebischer Mélody   Frau      f  4438
# ...
