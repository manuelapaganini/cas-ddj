# %% [markdown]
# # Scraper Post-Request

# %% [markdown]
# Der Reihe nach:
#
# * Url(mit post-zusatz) aufrufen.
# * Dabei Post-Info senden
# * Antwort als Json weiterverarbeiten.
#
# For-Loop:
#
# * Für das Array das zurück kommt eine For-Loop bauen.
# * Darin ein Dictionary aufsetzen, welches die Angaben die mich interessieren Pandas-tauglich macht
# * & Das zu einer Liste hinzufügen.
# * in der For-Loop die sub_url des Eintrags aufrufen (url + id)
# * Mit BeautifulSoup auf die sub_page angucken & die Elemente "legend" abgreifen
# * Das legend-Element das "Herr"/"Frau" enthält zum dictionary hinzufügen.
#
# Die fertige Liste mit Pandas angucken und freuen.

# %%
# Sachen importieren

import requests
import json
from bs4 import BeautifulSoup
import pandas as pd

# %%
# Sachen vorbereiten

data = {'page': '1',
        'pageSize': '1593',
        'mainSearchText': '*'
       }

cookies = {'ASP.NET_SessionId': 'nt4pmcae3gesz4kk41h2lang'}

url = 'http://appl.fr.ch/ate/Person/FilterGridWithIds'


# Zugriff auf die Webseite

response = requests.post(url, data=data, cookies=cookies)

response_as_json = json.loads(response.text)

response_as_json
# Out:
# {'Data': [{'DisplayName': '--- ---',
#    'Email': '',
#    'FirstName': '---',
#    'Id': 96,
#    'LastName': '---',
#    'PhoneNumber': '+41 26 305 12 70',
#    'PublicationEnd': '/Date(253402210800000)/',
#    'PublicationStart': '/Date(-2208992400000)/',
#    'PublicationTarget': '1,0',
#    'Roles': [{'DirectionName': "Chancellerie d'Etat",
#      'Email': '',
#      'Id': 1350,
#      'PhoneNumber': '+41 26 305 12 70',
#      'RoleName': 'Secrétariat',
#      'TitleName': None,
#      'UnitFullName': "CHA - Archives de l'Etat",
#      'UnitId': 318,
#      'RoleDenominationId': 1236,
#      'UnitName': "Archives de l'Etat",
#      'Position': 3,
#      'PublicationStart': '/Date(-2208992400000)/',
#      'PublicationEnd': '/Date(253402210800000)/',
#      'PublicationTarget': '1,0',
#      'WebDispatchingType': 0,
#      'UnitFullPath': None,
#      'UnitPath': None}],
#    'RolesDisplay': 'Secrétariat',
#    'UnitsDisplay': "CHA - Archives de l'Etat",
#    'UnitsExports': "Archives de l'Etat",
#    'UnitsFullNameExports': "CHA - Archives de l'Etat"},
#   {'DisplayName': 'Abeztout Abderrahim',
#    'Email': 'abderrahim.abeztout@fr.ch',
#    'FirstName': 'Abderrahim',
#    'Id': 4423,
#    'LastName': 'Abeztout',
#    'PhoneNumber': '+41 26 305 37 97',
#    'PublicationEnd': None,
#    'PublicationStart': '/Date(1463608800000)/',
#    'PublicationTarget': '1,0',
#    'Roles': [{'DirectionName': "Direction de l'aménagement, de l'environnement et des constructions",
#      'Email': 'abderrahim.abeztout@fr.ch',
#      'Id': 4703,
#      'PhoneNumber': '+41 26 305 37 97',
#      'RoleName': 'Architecte',
#      'TitleName': None,
#      'UnitFullName': 'DAEC - Service des bâtiments',
#      'UnitId': 235,
#      'RoleDenominationId': 121,
#      'UnitName': 'Section technique',
#      'Position': 0,
#      'PublicationStart': '/Date(1463608800000)/',
#      'PublicationEnd': None,
#      'PublicationTarget': '1,0',
#      'WebDispatchingType': 1,
#      'UnitFullPath': None,
#      'UnitPath': None}],
#    'RolesDisplay': 'Architecte',
#    'UnitsDisplay': 'DAEC - Service des bâtiments',
#    'UnitsExports': 'Section technique',
#    'UnitsFullNameExports': 'DAEC - Service des bâtiments'},
#   {'DisplayName': 'Ackermann Christophe',
#    'Email': 'christophe.ackermann@fr.ch',
#    'FirstName': 'Christophe',
#    'Id': 1544,
#    'LastName': 'Ackermann',
#    'PhoneNumber': '+41 26 305 31 38',
#    'PublicationEnd': '/Date(253402210800000)/',
#    'PublicationStart': '/Date(-2208992400000)/',
#    'PublicationTarget': '1,0',
#    'Roles': [{'DirectionName': 'Direction des finances',
#      'Email': 'christophe.ackermann@fr.ch',
#      'Id': 11,
#      'PhoneNumber': '+41 26 305 31 38',
#      'RoleName': 'Adjoint de la cheffe de service',
#      'TitleName': None,
#      'UnitFullName': 'DFIN - Inspection des finances',
#      'UnitId': 29,
#      'RoleDenominationId': 15,
#      'UnitName': 'Inspection des finances',
#      'Position': 2,
#      'PublicationStart': '/Date(-2208992400000)/',
#      'PublicationEnd': '/Date(253402210800000)/',
#      'PublicationTarget': '1,0',
#      'WebDispatchingType': 1,
#      'UnitFullPath': None,
#      'UnitPath': None}],
#    'RolesDisplay': 'Adjoint de la cheffe de service',
#    'UnitsDisplay': 'DFIN - Inspection des finances',
#    'UnitsExports': 'Inspection des finances',
#    'UnitsFullNameExports': 'DFIN - Inspection des finances'},
#   {'DisplayName': 'Ackermann Urs',
#    'Email': 'urs.ackermann@fr.ch',
#    'FirstName': 'Urs',
#    'Id': 3557,
#    'LastName': 'Ackermann',
#    'PhoneNumber': '+41 26 305 14 16',
#    'PublicationEnd': '/Date(253402210800000)/',
#    'PublicationStart': '/Date(-2208992400000)/',
#    'PublicationTarget': '1,0',
#    'Roles': [{'DirectionName': "Direction des institutions, de l'agriculture et des forêts",
#      'Email': 'urs.ackermann@fr.ch',
#      'Id': 1213,
#      'PhoneNumber': '+41 26 305 14 16',
#      'RoleName': 'Collaborateur administratif supérieur',
#      'TitleName': None,
#      'UnitFullName': "DIAF - Service des affaires institutionnelles, des naturalisations et de l'état civil",
#      'UnitId': 895,
#      'RoleDenominationId': 364,
#      'UnitName': 'Secteur des institutions et affaires juridiques',
#      'Position': 3,
#      'PublicationStart': '/Date(-2208992400000)/',
#      'PublicationEnd': '/Date(253402210800000)/',
#      'PublicationTarget': '1,0',
#      'WebDispatchingType': 1,
#      'UnitFullPath': None,
#      'UnitPath': None}],
#    'RolesDisplay': 'Collaborateur administratif supérieur',
#    'UnitsDisplay': "DIAF - Service des affaires institutionnelles, des naturalisations et de l'état civil",
#    'UnitsExports': 'Secteur des institutions et affaires juridiques',
#    'UnitsFullNameExports': "DIAF - Service des affaires institutionnelles, des naturalisations et de l'état civil"},
#   {'DisplayName': 'Adam Samuel',
#    'Email': '',
#    'FirstName': 'Samuel',
#    'Id': 2628,
#    'LastName': 'Adam',
#    'PhoneNumber': '+41 26 305 29 63',
#    'PublicationEnd': '/Date(253402210800000)/',
#    'PublicationStart': '/Date(-2208992400000)/',
#    'PublicationTarget': '1,0',
#    'Roles': [{'DirectionName': 'Direction de la santé et des affaires sociales',
#      'Email': '',
#      'Id': 1890,
#      'PhoneNumber': '+41 26 305 29 63',
#      'RoleName': 'Adjoint du chef de service',
#      'TitleName': None,
#      'UnitFullName': 'DSAS - Service du médecin cantonal',
#      'UnitId': 75,
#      'RoleDenominationId': 21,
#      'UnitName': 'Service du médecin cantonal',
#      'Position': 5,
#      'PublicationStart': '/Date(-2208992400000)/',
#      'PublicationEnd': '/Date(253402210800000)/',
#      'PublicationTarget': '1,0',
#      'WebDispatchingType': 0,
#      'UnitFullPath': None,
#      'UnitPath': None}],
#    'RolesDisplay': 'Adjoint du chef de service',
#    'UnitsDisplay': 'DSAS - Service du médecin cantonal',
#    'UnitsExports': 'Service du médecin cantonal',
#    'UnitsFullNameExports': 'DSAS - Service du médecin cantonal'},
#   {'DisplayName': 'Aebischer Adrian',
#    'Email': 'adrian.aebischer@fr.ch',
#    'FirstName': 'Adrian',
#    'Id': 1289,
#    'LastName': 'Aebischer',
#    'PhoneNumber': '+41 26 305 23 43',
#    'PublicationEnd': None,
#    'PublicationStart': '/Date(-2208992400000)/',
#    'PublicationTarget': '1,0',
#    'Roles': [{'DirectionName': "Direction des institutions, de l'agriculture et des forêts",
#      'Email': 'adrian.aebischer@fr.ch',
#      'Id': 3656,
#      'PhoneNumber': '+41 26 305 23 43',
#      'RoleName': 'Collaborateur scientifique, biodiversité en forêt',
#      'TitleName': None,
#      'UnitFullName': 'DIAF - Service des forêts et de la nature',
#      'UnitId': 794,
#      'RoleDenominationId': 392,
#      'UnitName': 'Secteur faune, biodiversité, chasse et pêche',
#      'Position': 0,
#      'PublicationStart': '/Date(-2208992400000)/',
#      'PublicationEnd': None,
#      'PublicationTarget': '1,0',
#      'WebDispatchingType': 1,
#      'UnitFullPath': None,
#      'UnitPath': None}],
#    'RolesDisplay': 'Collaborateur scientifique, biodiversité en forêt',
#    'UnitsDisplay': 'DIAF - Service des forêts et de la nature',
#    'UnitsExports': 'Secteur faune, biodiversité, chasse et pêche',
#    'UnitsFullNameExports': 'DIAF - Service des forêts et de la nature'},
#   {'DisplayName': 'Aebischer Christoph',
#    'Email': '',
#    'FirstName': 'Christoph',
#    'Id': 1580,
#    'LastName': 'Aebischer',
#    'PhoneNumber': '+41 26 304 14 04',
#    'PublicationEnd': '/Date(253402210800000)/',
#    'PublicationStart': '/Date(-2208992400000)/',
#    'PublicationTarget': '0,1',
#    'Roles': [{'DirectionName': "Direction de l'économie et de l'emploi",
#      'Email': '',
#      'Id': 44,
#      'PhoneNumber': '+41 26 304 14 04',
#      'RoleName': 'Chef de projets',
#      'TitleName': None,
#      'UnitFullName': 'DEE - Promotion économique du canton de Fribourg',
#      'UnitId': 36,
#      'RoleDenominationId': 237,
#      'UnitName': 'Promotion économique du canton de Fribourg',
#      'Position': 0,
#      'PublicationStart': '/Date(-2208992400000)/',
#      'PublicationEnd': '/Date(253402210800000)/',
#      'PublicationTarget': '0,1',
#      'WebDispatchingType': 0,
#      'UnitFullPath': None,
#      'UnitPath': None}],
#    'RolesDisplay': 'Chef de projets',
#    'UnitsDisplay': 'DEE - Promotion économique du canton de Fribourg',
#    'UnitsExports': 'Promotion économique du canton de Fribourg',
#    'UnitsFullNameExports': 'DEE - Promotion économique du canton de Fribourg'},
#   {'DisplayName': 'Aebischer Fernand',
#    'Email': 'Non renseigné',
#    'FirstName': 'Fernand',
#    'Id': 36,
#    'LastName': 'Aebischer',
#    'PhoneNumber': '',
#    'PublicationEnd': '/Date(253402210800000)/',
#    'PublicationStart': '/Date(-2208992400000)/',
#    'PublicationTarget': '0,1',
#    'Roles': [{'DirectionName': 'Divers',
#      'Email': 'Non renseigné',
#      'Id': 3997,
#      'PhoneNumber': None,
#      'RoleName': 'Quilles',
#      'TitleName': None,
#      'UnitFullName': "DIV - Groupement polysportif de l'Etat de Fribourg",
#      'UnitId': 344,
#      'RoleDenominationId': 1011,
#      'UnitName': 'Disciplines',
#      'Position': 0,
#      'PublicationStart': '/Date(-2208992400000)/',
#      'PublicationEnd': '/Date(253402210800000)/',
#      'PublicationTarget': '0,1',
#      'WebDispatchingType': 1,
#      'UnitFullPath': None,
#      'UnitPath': None}],
#    'RolesDisplay': 'Quilles',
#    'UnitsDisplay': "DIV - Groupement polysportif de l'Etat de Fribourg",
#    'UnitsExports': 'Disciplines',
#    'UnitsFullNameExports': "DIV - Groupement polysportif de l'Etat de Fribourg"},
#   {'DisplayName': 'Aebischer Florent',
#    'Email': 'florent.aebischer@fr.ch',
#    'FirstName': 'Florent',
#    'Id': 3328,
#    'LastName': 'Aebischer',
#    'PhoneNumber': '+41 26 305 44 89',
#    'PublicationEnd': '/Date(253402210800000)/',
#    'PublicationStart': '/Date(-2208992400000)/',
#    'PublicationTarget': '1,0',
#    'Roles': [{'DirectionName': "Direction de l'économie et de l'emploi",
#      'Email': 'florent.aebischer@fr.ch',
#      'Id': 981,
#      'PhoneNumber': '+41 26 305 44 89',
#      'RoleName': 'Secrétariat et guichet',
#      'TitleName': None,
#      'UnitFullName': 'DEE - Service du registre du commerce',
#      'UnitId': 38,
#      'RoleDenominationId': 1856,
#      'UnitName': 'Service du registre du commerce',
#      'Position': 0,
#      'PublicationStart': '/Date(-2208992400000)/',
#      'PublicationEnd': '/Date(253402210800000)/',
#      'PublicationTarget': '1,0',
#      'WebDispatchingType': 1,
#      'UnitFullPath': None,
#      'UnitPath': None}],
#    'RolesDisplay': 'Secrétariat et guichet',
#    'UnitsDisplay': 'DEE - Service du registre du commerce',
#    'UnitsExports': 'Service du registre du commerce',
#    'UnitsFullNameExports': 'DEE - Service du registre du commerce'},
#   {'DisplayName': 'Aebischer Jean-Marc',
#    'Email': '',
#    'FirstName': 'Jean-Marc',
#    'Id': 1038,
#    'LastName': 'Aebischer',
#    'PhoneNumber': '+41 26 305 12 61',
#    'PublicationEnd': None,
#    'PublicationStart': '/Date(1485385200000)/',
#    'PublicationTarget': '1,0',
#    'Roles': [{'DirectionName': "Direction de l'instruction publique, de la culture et du sport",
#      'Email': '',
#      'Id': 538,
#      'PhoneNumber': '+41 26 305 12 61',
#      'RoleName': 'Collaborateur pédagogique',
#      'TitleName': None,
#      'UnitFullName': 'DICS - Service du sport',
#      'UnitId': 81,
#      'RoleDenominationId': 381,
#      'UnitName': 'Service du sport',
#      'Position': 2,
#      'PublicationStart': '/Date(1485385200000)/',
#      'PublicationEnd': None,
#      'PublicationTarget': '1,0',
#      'WebDispatchingType': 0,
#      'UnitFullPath': None,
#      'UnitPath': None}],
#    'RolesDisplay': 'Collaborateur pédagogique',
#    'UnitsDisplay': 'DICS - Service du sport',
#    'UnitsExports': 'Service du sport',
#    'UnitsFullNameExports': 'DICS - Service du sport'},
#   {'DisplayName': 'Aebischer Jean-Marc',
#    'Email': 'jean-marc.aebischer@fr.ch',
#    'FirstName': 'Jean-Marc',
#    'Id': 4664,
#    'LastName': 'Aebischer',
#    'PhoneNumber': '+41 26 305 12 61',
#    'PublicationEnd': '/Date(253402210800000)/',
#    'PublicationStart': '/Date(-2208992400000)/',
#    'PublicationTarget': '1,0',
#    'Roles': [{'DirectionName': "Direction de l'instruction publique, de la culture et du sport",
#      'Email': 'jean-marc.aebischer@fr.ch',
#      'Id': 4959,
#      'PhoneNumber': '+41 26 305 12 61',
#      'RoleName': 'Corps et mouvement, cycles 1, 2 & 3',
#      'TitleName': None,
#      'UnitFullName': "DICS - Service de l'enseignement obligatoire de langue française",
#      'UnitId': 473,
#      'RoleDenominationId': 1606,
#      'UnitName': 'Collaborateurs/trices pédagogiques',
#      'Position': 0,
#      'PublicationStart': '/Date(-2208992400000)/',
#      'PublicationEnd': '/Date(253402210800000)/',
#      'PublicationTarget': '1,0',
#      'WebDispatchingType': 1,
#      'UnitFullPath': None,
#      'UnitPath': None}],
#    'RolesDisplay': 'Corps et mouvement, cycles 1, 2 & 3',
#    'UnitsDisplay': "DICS - Service de l'enseignement obligatoire de langue française",
#    'UnitsExports': 'Collaborateurs/trices pédagogiques',
#    'UnitsFullNameExports': "DICS - Service de l'enseignement obligatoire de langue française"},
#   {'DisplayName': 'Aebischer Jean-Marie',
#    'Email': 'jean-marie.aebischer@fr.oai.ch',
#    'FirstName': 'Jean-Marie',
#    'Id': 609,
#    'LastName': 'Aebischer',
#    'PhoneNumber': '+41 26 305 52 40',
#    'PublicationEnd': '/Date(253402210800000)/',
#    'PublicationStart': '/Date(-2208992400000)/',
#    'PublicationTarget': '0,1',
#    'Roles': [{'DirectionName': 'Direction de la santé et des affaires sociales',
#      'Email': 'jean-marie.aebischer@fr.oai.ch',
#      'Id': 1601,
#      'PhoneNumber': '+41 26 305 52 40',
#      'RoleName': 'Chef section Services généraux',
#      'TitleName': None,
#      'UnitFullName': 'DSAS - Etablissement cantonal des assurances sociales',
#      'UnitId': 220,
#      'RoleDenominationId': 312,
#      'UnitName': "Office cantonal de l'assurance-invalidité",
#      'Position': 0,
#      'PublicationStart': '/Date(-2208992400000)/',
#      'PublicationEnd': '/Date(253402210800000)/',
#      'PublicationTarget': '0,1',
#      'WebDispatchingType': 1,
#      'UnitFullPath': None,
#      'UnitPath': None}],
#    'RolesDisplay': 'Chef section Services généraux',
#    'UnitsDisplay': 'DSAS - Etablissement cantonal des assurances sociales',
#    'UnitsExports': "Office cantonal de l'assurance-invalidité",
#    'UnitsFullNameExports': 'DSAS - Etablissement cantonal des assurances sociales'},
#   {'DisplayName': 'Aebischer Maryse',
#    'Email': '',
#    'FirstName': 'Maryse',
#    'Id': 755,
#    'LastName': 'Aebischer',
#    'PhoneNumber': '+41 26 305 29 68',
#    'PublicationEnd': '/Date(253402210800000)/',
#    'PublicationStart': '/Date(-2208992400000)/',
#    'PublicationTarget': '0,1',
#    'Roles': [{'DirectionName': 'Direction de la santé et des affaires sociales',
#      'Email': '',
#      'Id': 318,
#      'PhoneNumber': '+41 26 305 29 68',
#      'RoleName': 'Cheffe de service',
#      'TitleName': None,
#      'UnitFullName': 'DSAS - Service de la prévoyance sociale',
#      'UnitId': 40,
#      'RoleDenominationId': 339,
#      'UnitName': 'Service de la prévoyance sociale',
#      'Position': 1,
#      'PublicationStart': '/Date(-2208992400000)/',
#      'PublicationEnd': '/Date(253402210800000)/',
#      'PublicationTarget': '0,1',
#      'WebDispatchingType': 0,
#      'UnitFullPath': None,
#      'UnitPath': None}],
#    'RolesDisplay': 'Cheffe de service',
#    'UnitsDisplay': 'DSAS - Service de la prévoyance sociale',
#    'UnitsExports': 'Service de la prévoyance sociale',
#    'UnitsFullNameExports': 'DSAS - Service de la prévoyance sociale'},
#   {'DisplayName': 'Aebischer Mélody',
#    'Email': 'melody.aebischer@fr.ch',
#    'FirstName': 'Mélody',
#    'Id': 4438,
#    'LastName': 'Aebischer',
#    'PhoneNumber': '+41 26 305 55 09',
#    'PublicationEnd': '/Date(253402210800000)/',
#    'PublicationStart': '/Date(-2208992400000)/',
#    'PublicationTarget': '1,0',
#    'Roles': [{'DirectionName': "Direction des institutions, de l'agriculture et des forêts",
#      'Email': 'melody.aebischer@fr.ch',
#      'Id': 4718,
#      'PhoneNumber': '+41 26 305 55 09',
#      'RoleName': 'Spécialiste RH',
#      'TitleName': None,
#      'UnitFullName': "DIAF - Institut agricole de l'Etat de Fribourg",
#      'UnitId': 606,
#      'RoleDenominationId': 1271,
#      'UnitName': 'Administration',
#      'Position': 0,
#      'PublicationStart': '/Date(-2208992400000)/',
#      'PublicationEnd': '/Date(253402210800000)/',
#      'PublicationTarget': '1,0',
#      'WebDispatchingType': 1,
#      'UnitFullPath': None,
#      'UnitPath': None}],
#    'RolesDisplay': 'Spécialiste RH',
#    'UnitsDisplay': "DIAF - Institut agricole de l'Etat de Fribourg",
#    'UnitsExports': 'Administration',
#    'UnitsFullNameExports': "DIAF - Institut agricole de l'Etat de Fribourg"},
#   {'DisplayName': 'Aebischer Nicolas',
#    'Email': 'nicolas.aebischer@ocms-fribourg.ch',
#    'FirstName': 'Nicolas',
#    'Id': 1035,
#    'LastName': 'Aebischer',
#    'PhoneNumber': '+41 26 305 13 90',
#    'PublicationEnd': '/Date(253402210800000)/',
#    'PublicationStart': '/Date(-2208992400000)/',
#    'PublicationTarget': '1,0',
#    'Roles': [{'DirectionName': "Direction de l'instruction publique, de la culture et du sport",
#      'Email': 'nicolas.aebischer@ocms-fribourg.ch',
#      'Id': 142,
#      'PhoneNumber': '+41 26 305 13 90',
#      'RoleName': 'Adjoint à la direction',
#      'TitleName': None,
#      'UnitFullName': 'DICS - Office cantonal du matériel scolaire',
#      'UnitId': 50,
#      'RoleDenominationId': 7,
#      'UnitName': 'Office cantonal du matériel scolaire',
#      'Position': 2,
#      'PublicationStart': '/Date(-2208992400000)/',
#      'PublicationEnd': '/Date(253402210800000)/',
#      'PublicationTarget': '1,0',
#      'WebDispatchingType': 1,
#      'UnitFullPath': None,
#      'UnitPath': None}],
#    'RolesDisplay': 'Adjoint à la direction',
#    'UnitsDisplay': 'DICS - Office cantonal du matériel scolaire',
#    'UnitsExports': 'Office cantonal du matériel scolaire',
#    'UnitsFullNameExports': 'DICS - Office cantonal du matériel scolaire'},
#   {'DisplayName': 'Aebischer Nicolas',
#    'Email': 'nicolas.aebischer@fr.ch',
#    'FirstName': 'Nicolas',
#    'Id': 1401,
#    'LastName': 'Aebischer',
#    'PhoneNumber': '+41 26 305 37 60',
#    'PublicationEnd': '/Date(253402210800000)/',
#    'PublicationStart': '/Date(-2208992400000)/',
#    'PublicationTarget': '1,0',
#    'Roles': [{'DirectionName': "Direction de l'aménagement, de l'environnement et des constructions",
#      'Email': 'nicolas.aebischer@fr.ch',
#      'Id': 1843,
#      'PhoneNumber': '+41 26 305 37 60',
#      'RoleName': 'Chef du secteur contrôle des eaux et produits chimiques',
#      'TitleName': None,
#      'UnitFullName': "DAEC - Service de l'environnement",
#      'UnitId': 241,
#      'RoleDenominationId': 1874,
#      'UnitName': 'Section laboratoire et substances',
#      'Position': 2,
#      'PublicationStart': '/Date(-2208992400000)/',
#      'PublicationEnd': '/Date(253402210800000)/',
#      'PublicationTarget': '1,0',
#      'WebDispatchingType': 1,
#      'UnitFullPath': None,
#      'UnitPath': None}],
#    'RolesDisplay': 'Chef du secteur contrôle des eaux et produits chimiques',
#    'UnitsDisplay': "DAEC - Service de l'environnement",
#    'UnitsExports': 'Section laboratoire et substances',
#    'UnitsFullNameExports': "DAEC - Service de l'environnement"},
#   {'DisplayName': 'Aebischer-Aeby Elisabeth',
#    'Email': 'aebischerel@edufr.ch',
#    'FirstName': 'Elisabeth',
#    'Id': 3119,
#    'LastName': 'Aebischer-Aeby',
#    'PhoneNumber': '+41 26 305 79 14',
#    'PublicationEnd': '/Date(253402210800000)/',
#    'PublicationStart': '/Date(-2208992400000)/',
#    'PublicationTarget': '1,0',
#    'Roles': [{'DirectionName': "Direction de l'instruction publique, de la culture et du sport",
#      'Email': 'aebischerel@edufr.ch',
#      'Id': 3758,
#      'PhoneNumber': '+41 26 305 79 14',
#      'RoleName': 'Proviseure',
#      'TitleName': None,
#      'UnitFullName': "DICS - Service de l'enseignement secondaire du deuxième degré",
#      'UnitId': 274,
#      'RoleDenominationId': 1005,
#      'UnitName': 'Collège de Gambach',
#      'Position': 2,
#      'PublicationStart': '/Date(-2208992400000)/',
#      'PublicationEnd': '/Date(253402210800000)/',
#      'PublicationTarget': '1,0',
#      'WebDispatchingType': 1,
#      'UnitFullPath': None,
#      'UnitPath': None}],
#    'RolesDisplay': 'Proviseure',
#    'UnitsDisplay': "DICS - Service de l'enseignement secondaire du deuxième degré",
#    'UnitsExports': 'Collège de Gambach',
#    'UnitsFullNameExports': "DICS - Service de l'enseignement secondaire du deuxième degré"},
#   {'DisplayName': 'Aebischer-Piller Christa',
#    'Email': 'christa.aebischer@fr.ch',
#    'FirstName': 'Christa',
#    'Id': 895,
#    'LastName': 'Aebischer-Piller',
#    'PhoneNumber': '+41 26 305 40 88',
#    'PublicationEnd': '/Date(253402210800000)/',
#    'PublicationStart': '/Date(-2208992400000)/',
#    'PublicationTarget': '1,0',
#    'Roles': [{'DirectionName': "Direction de l'instruction publique, de la culture et du sport",
#      'Email': 'christa.aebischer@fr.ch',
#      'Id': 2030,
#      'PhoneNumber': '+41 26 305 40 88',
#      'RoleName': 'Collaboratrice pédagogique; promotion des langues 1er cycle',
#      'TitleName': None,
#      'UnitFullName': "DICS - Service de l'enseignement obligatoire de langue allemande",
#      'UnitId': 485,
#      'RoleDenominationId': 445,
#      'UnitName': 'Collaboration pédagogique',
#      'Position': 1,
#      'PublicationStart': '/Date(-2208992400000)/',
#      'PublicationEnd': '/Date(253402210800000)/',
#      'PublicationTarget': '1,0',
#      'WebDispatchingType': 1,
#      'UnitFullPath': None,
#      'UnitPath': None},
#     {'DirectionName': "Direction de l'instruction publique, de la culture et du sport",
#      'Email': 'christa.aebischer@fr.ch',
#      'Id': 1763,
#      'PhoneNumber': '+41 26 305 40 88',
#      'RoleName': 'Inspectrice',
#      'TitleName': None,
#      'UnitFullName': "DICS - Service de l'enseignement obligatoire de langue allemande",
#      'UnitId': 405,
#      'RoleDenominationId': 839,
#      'UnitName': 'Inspection des écoles enfantines et primaires; Tavel',
#      'Position': 1,
#      'PublicationStart': '/Date(-2208992400000)/',
#      'PublicationEnd': '/Date(253402210800000)/',
#      'PublicationTarget': '1,0',
#      'WebDispatchingType': 1,
#      'UnitFullPath': None,
#      'UnitPath': None}],
#    'RolesDisplay': 'Collaboratrice pédagogique; promotion des langues 1er cycle, Inspectrice',
#    'UnitsDisplay': "DICS - Service de l'enseignement obligatoire de langue allemande, DICS - Service de l'enseignement obligatoire de langue allemande",
#    'UnitsExports': 'Collaboration pédagogique, Inspection des écoles enfantines et primaires; Tavel',
#    'UnitsFullNameExports': "DICS - Service de l'enseignement obligatoire de langue allemande, DICS - Service de l'enseignement obligatoire de langue allemande"},
#   {'DisplayName': 'Aeby Annabelle',
#    'Email': '',
#    'FirstName': 'Annabelle',
#    'Id': 1853,
#    'LastName': 'Aeby',
#    'PhoneNumber': '+41 26 305 79 89',
#    'PublicationEnd': '/Date(253402210800000)/',
#    'PublicationStart': '/Date(-2208992400000)/',
#    'PublicationTarget': '1,0',
#    'Roles': [{'DirectionName': 'Direction de la santé et des affaires sociales',
#      'Email': '',
#      'Id': 1160,
#      'PhoneNumber': '+41 26 305 79 89',
#      'RoleName': 'Infirmière',
#      'TitleName': None,
#      'UnitFullName': 'DSAS - Service du médecin cantonal',
#      'UnitId': 481,
#      'RoleDenominationId': 778,
#      'UnitName': 'Secteur infirmier',
#      'Position': 2,
#      'PublicationStart': '/Date(-2208992400000)/',
#      'PublicationEnd': '/Date(253402210800000)/',
#      'PublicationTarget': '1,0',
#      'WebDispatchingType': 0,
#      'UnitFullPath': None,
#      'UnitPath': None}],
#    'RolesDisplay': 'Infirmière',
#    'UnitsDisplay': 'DSAS - Service du médecin cantonal',
#    'UnitsExports': 'Secteur infirmier',
#    'UnitsFullNameExports': 'DSAS - Service du médecin cantonal'},
#   {'DisplayName': 'Aeby Frédéric',
#    'Email': '',
#    'FirstName': 'Frédéric',
#    'Id': 6508,
#    'LastName': 'Aeby',
#    'PhoneNumber': '+41 26 305 40 85',
#    'PublicationEnd': None,
#    'PublicationStart': '/Date(1536876000000)/',
#    'PublicationTarget': '1,0',
#    'Roles': [{'DirectionName': "Direction de l'instruction publique, de la culture et du sport",
#      'Email': '',
#      'Id': 6867,
#      'PhoneNumber': '+41 26 305 40 85',
#      'RoleName': 'Collaborateur pédagogique',
#      'TitleName': None,
#      'UnitFullName': "DICS - Service de l'enseignement obligatoire de langue allemande",
#      'UnitId': 485,
#      'RoleDenominationId': 381,
#      'UnitName': 'Collaboration pédagogique',
#      'Position': 7,
#      'PublicationStart': '/Date(1536876000000)/',
#      'PublicationEnd': None,
#      'PublicationTarget': '1,0',
#      'WebDispatchingType': 0,
#      'UnitFullPath': None,
#      'UnitPath': None}],
#    'RolesDisplay': 'Collaborateur pédagogique',
#    'UnitsDisplay': "DICS - Service de l'enseignement obligatoire de langue allemande",
#    'UnitsExports': 'Collaboration pédagogique',
#    'UnitsFullNameExports': "DICS - Service de l'enseignement obligatoire de langue allemande"},
#   {'DisplayName': 'Aeby Pascal',
#    'Email': 'pascal.aeby@fr.ch',
#    'FirstName': 'Pascal',
#    'Id': 1205,
#    'LastName': 'Aeby',
#    'PhoneNumber': '+41 26 305 31 03',
#    'PublicationEnd': '/Date(253402210800000)/',
#    'PublicationStart': '/Date(-2208992400000)/',
#    'PublicationTarget': '1,0',
#    'Roles': [{'DirectionName': 'Direction des finances',
#      'Email': 'pascal.aeby@fr.ch',
#      'Id': 776,
#      'PhoneNumber': '+41 26 305 31 03',
#      'RoleName': 'Secrétaire général',
#      'TitleName': None,
#      'UnitFullName': 'DFIN - Secrétariat général',
#      'UnitId': 16,
#      'RoleDenominationId': 1218,
#      'UnitName': 'Secrétariat général',
#      'Position': 2,
#      'PublicationStart': '/Date(-2208992400000)/',
#      'PublicationEnd': '/Date(253402210800000)/',
#      'PublicationTarget': '1,0',
#      'WebDispatchingType': 1,
#      'UnitFullPath': None,
#      'UnitPath': None}],
#    'RolesDisplay': 'Secrétaire général',
#    'UnitsDisplay': 'DFIN - Secrétariat général',
#    'UnitsExports': 'Secrétariat général',
#    'UnitsFullNameExports': 'DFIN - Secrétariat général'},
#   {'DisplayName': 'Aeby Pierre',
#    'Email': 'pierre.aeby@fr.ch',
#    'FirstName': 'Pierre',
#    'Id': 1106,
#    'LastName': 'Aeby',
#    'PhoneNumber': '+41 26 305 58 62',
#    'PublicationEnd': '/Date(253402210800000)/',
#    'PublicationStart': '/Date(-2208992400000)/',
#    'PublicationTarget': '0,1',
#    'Roles': [{'DirectionName': "Direction des institutions, de l'agriculture et des forêts",
#      'Email': 'pierre.aeby@fr.ch',
#      'Id': 3874,
#      'PhoneNumber': '+41 26 305 58 62',
#      'RoleName': 'Responsable production végétale',
#      'TitleName': None,
#      'UnitFullName': "DIAF - Institut agricole de l'Etat de Fribourg",
#      'UnitId': 800,
#      'RoleDenominationId': 1154,
#      'UnitName': 'Production végétale (PV)',
#      'Position': 1,
#      'PublicationStart': '/Date(-2208992400000)/',
#      'PublicationEnd': '/Date(253402210800000)/',
#      'PublicationTarget': '0,1',
#      'WebDispatchingType': 1,
#      'UnitFullPath': None,
#      'UnitPath': None}],
#    'RolesDisplay': 'Responsable production végétale',
#    'UnitsDisplay': "DIAF - Institut agricole de l'Etat de Fribourg",
#    'UnitsExports': 'Production végétale (PV)',
#    'UnitsFullNameExports': "DIAF - Institut agricole de l'Etat de Fribourg"},
#   {'DisplayName': 'Aeby-Barrat Eléonore',
#    'Email': 'eleonore.aeby-barrat@fr.oai.ch',
#    'FirstName': 'Eléonore',
#    'Id': 1895,
#    'LastName': 'Aeby-Barrat',
#    'PhoneNumber': '+41 26 305 52 12',
#    'PublicationEnd': '/Date(253402210800000)/',
#    'PublicationStart': '/Date(1533247200000)/',
#    'PublicationTarget': '1,0',
#    'Roles': [{'DirectionName': 'Direction de la santé et des affaires sociales',
#      'Email': 'eleonore.aeby-barrat@fr.oai.ch',
#      'Id': 2042,
#      'PhoneNumber': '+41 26 305 52 12',
#      'RoleName': 'Cheffe de section juridique',
#      'TitleName': None,
#      'UnitFullName': 'DSAS - Etablissement cantonal des assurances sociales',
#      'UnitId': 220,
#      'RoleDenominationId': 1788,
#      'UnitName': "Office cantonal de l'assurance-invalidité",
#      'Position': 0,
#      'PublicationStart': '/Date(1533247200000)/',
#      'PublicationEnd': '/Date(253402210800000)/',
#      'PublicationTarget': '1,0',
#      'WebDispatchingType': 1,
#      'UnitFullPath': None,
#      'UnitPath': None}],
#    'RolesDisplay': 'Cheffe de section juridique',
#    'UnitsDisplay': 'DSAS - Etablissement cantonal des assurances sociales',
#    'UnitsExports': "Office cantonal de l'assurance-invalidité",
#    'UnitsFullNameExports': 'DSAS - Etablissement cantonal des assurances sociales'},
#   {'DisplayName': 'Aellen-Rey Fabienne',
#    'Email': 'fabienne.aellen-rey@fr.ch',
#    'FirstName': 'Fabienne',
#    'Id': 1767,
#    'LastName': 'Aellen-Rey',
#    'PhoneNumber': '+41 26 305 22 68',
#    'PublicationEnd': '/Date(253402210800000)/',
#    'PublicationStart': '/Date(-2208992400000)/',
#    'PublicationTarget': '1,0',
#    'Roles': [{'DirectionName': "Direction des institutions, de l'agriculture et des forêts",
#      'Email': 'fabienne.aellen-rey@fr.ch',
#      'Id': 1511,
#      'PhoneNumber': '+41 26 305 22 68',
#      'RoleName': 'Collaboratrice administrative',
#      'TitleName': None,
#      'UnitFullName': "DIAF - Service de l'agriculture",
#      'UnitId': 393,
#      'RoleDenominationId': 424,
#      'UnitName': 'Services généraux',
#      'Position': 2,
#      'PublicationStart': '/Date(-2208992400000)/',
#      'PublicationEnd': '/Date(253402210800000)/',
#      'PublicationTarget': '1,0',
#      'WebDispatchingType': 1,
#      'UnitFullPath': None,
#      'UnitPath': None}],
#    'RolesDisplay': 'Collaboratrice administrative',
#    'UnitsDisplay': "DIAF - Service de l'agriculture",
#    'UnitsExports': 'Services généraux',
#    'UnitsFullNameExports': "DIAF - Service de l'agriculture"},
#   {'DisplayName': 'Aerne Myriam',
#    'Email': 'Myriam.Aerne@fr.ch',
#    'FirstName': 'Myriam',
#    'Id': 6987,
#    'LastName': 'Aerne',
#    'PhoneNumber': '',
#    'PublicationEnd': '/Date(4094143200000)/',
#    'PublicationStart': '/Date(1569448800000)/',
#    'PublicationTarget': '1,0',
#    'Roles': [{'DirectionName': "Direction de l'instruction publique, de la culture et du sport",
#      'Email': 'Myriam.Aerne@fr.ch',
#      'Id': 7386,
#      'PhoneNumber': None,
#      'RoleName': "Responsable de l'atelier de reliure et de conservation",
#      'TitleName': None,
#      'UnitFullName': 'DICS - Service de la culture',
#      'UnitId': 163,
#      'RoleDenominationId': 1917,
#      'UnitName': 'Bibliothèque cantonale et universitaire',
#      'Position': 0,
#      'PublicationStart': '/Date(1569448800000)/',
#      'PublicationEnd': '/Date(4094143200000)/',
#      'PublicationTarget': '1,0',
#      'WebDispatchingType': 1,
#      'UnitFullPath': None,
#      'UnitPath': None}],
#    'RolesDisplay': "Responsable de l'atelier de reliure et de conservation",
#    'UnitsDisplay': 'DICS - Service de la culture',
#    'UnitsExports': 'Bibliothèque cantonale et universitaire',
#    'UnitsFullNameExports': 'DICS - Service de la culture'},
#   {'DisplayName': 'Aeschlimann David',
#    'Email': 'david.aeschlimann.sagri@fr.ch',
#    'FirstName': 'David',
#    'Id': 2205,
#    'LastName': 'Aeschlimann',
#    'PhoneNumber': '+41 26 305 23 03',
#    'PublicationEnd': '/Date(253402210800000)/',
#    'PublicationStart': '/Date(-2208992400000)/',
#    'PublicationTarget': '1,0',
#    'Roles': [{'DirectionName': "Direction des institutions, de l'agriculture et des forêts",
#      'Email': 'david.aeschlimann.sagri@fr.ch',
#      'Id': 6587,
#      'PhoneNumber': '+41 26 305 23 03',
#      'RoleName': 'Responsable régional Basse Sarine',
#      'TitleName': None,
#      'UnitFullName': "DIAF - Service de l'agriculture",
#      'UnitId': 395,
#      'RoleDenominationId': 1725,
#      'UnitName': 'Paiements directs',
#      'Position': 2,
#      'PublicationStart': '/Date(1517439600000)/',
#      'PublicationEnd': None,
#      'PublicationTarget': '1,0',
#      'WebDispatchingType': 1,
#      'UnitFullPath': None,
#      'UnitPath': None},
#     {'DirectionName': "Direction des institutions, de l'agriculture et des forêts",
#      'Email': 'david.aeschlimann.sagri@fr.ch',
#      'Id': 2048,
#      'PhoneNumber': '+41 26 305 23 03',
#      'RoleName': 'Chef de section',
#      'TitleName': None,
#      'UnitFullName': "DIAF - Service de l'agriculture",
#      'UnitId': 393,
#      'RoleDenominationId': 259,
#      'UnitName': 'Services généraux',
#      'Position': 1,
#      'PublicationStart': '/Date(-2208992400000)/',
#      'PublicationEnd': '/Date(253402210800000)/',
#      'PublicationTarget': '1,0',
#      'WebDispatchingType': 1,
#      'UnitFullPath': None,
#      'UnitPath': None},
#     {'DirectionName': "Direction des institutions, de l'agriculture et des forêts",
#      'Email': 'david.aeschlimann.sagri@fr.ch',
#      'Id': 2237,
#      'PhoneNumber': '+41 26 305 23 03',
#      'RoleName': 'Conseiller scientifique',
#      'TitleName': None,
#      'UnitFullName': "DIAF - Service de l'agriculture",
#      'UnitId': 397,
#      'RoleDenominationId': 488,
#      'UnitName': 'Promotion des produits, élevage et viticulture',
#      'Position': 2,
#      'PublicationStart': '/Date(-2208992400000)/',
#      'PublicationEnd': '/Date(253402210800000)/',
#      'PublicationTarget': '1,0',
#      'WebDispatchingType': 1,
#      'UnitFullPath': None,
#      'UnitPath': None}],
#    'RolesDisplay': 'Responsable régional Basse Sarine, Chef de section, Conseiller scientifique',
#    'UnitsDisplay': "DIAF - Service de l'agriculture, DIAF - Service de l'agriculture, DIAF - Service de l'agriculture",
#    'UnitsExports': 'Paiements directs, Services généraux, Promotion des produits, élevage et viticulture',
#    'UnitsFullNameExports': "DIAF - Service de l'agriculture, DIAF - Service de l'agriculture, DIAF - Service de l'agriculture"},
#   {'DisplayName': 'Agustoni Clara',
#    'Email': 'clara.agustoni@fr.ch',
#    'FirstName': 'Clara',
#    'Id': 1077,
#    'LastName': 'Agustoni',
#    'PhoneNumber': '+41 26 667 97 96',
#    'PublicationEnd': '/Date(253402210800000)/',
#    'PublicationStart': '/Date(-2208992400000)/',
#    'PublicationTarget': '1,0',
#    'Roles': [{'DirectionName': "Direction de l'instruction publique, de la culture et du sport",
#      'Email': 'clara.agustoni@fr.ch',
#      'Id': 1924,
#      'PhoneNumber': '+41 26 667 97 96',
#      'RoleName': 'Conservatrice',
#      'TitleName': None,
#      'UnitFullName': 'DICS - Service archéologique',
#      'UnitId': 364,
#      'RoleDenominationId': 1381,
#      'UnitName': 'Musée romain de Vallon',
#      'Position': 0,
#      'PublicationStart': '/Date(-2208992400000)/',
#      'PublicationEnd': '/Date(253402210800000)/',
#      'PublicationTarget': '1,0',
#      'WebDispatchingType': 1,
#      'UnitFullPath': None,
#      'UnitPath': None}],
#    'RolesDisplay': 'Conservatrice',
#    'UnitsDisplay': 'DICS - Service archéologique',
#    'UnitsExports': 'Musée romain de Vallon',
#    'UnitsFullNameExports': 'DICS - Service archéologique'},
#   {'DisplayName': 'Ajeti Ismail',
#    'Email': 'Ismail.Ajeti@fr.ch',
#    'FirstName': 'Ismail',
#    'Id': 3416,
#    'LastName': 'Ajeti',
#    'PhoneNumber': '+41 26 305 35 55',
#    'PublicationEnd': '/Date(253402210800000)/',
#    'PublicationStart': '/Date(-2208992400000)/',
#    'PublicationTarget': '1,0',
#    'Roles': [{'DirectionName': 'Direction des finances',
#      'Email': 'Ismail.Ajeti@fr.ch',
#      'Id': 970,
#      'PhoneNumber': '+41 26 305 35 55',
#      'RoleName': 'Adjoint administratif',
#      'TitleName': None,
#      'UnitFullName': 'DFIN - Service du cadastre et de la géomatique',
#      'UnitId': 46,
#      'RoleDenominationId': 8,
#      'UnitName': 'Service du cadastre et de la géomatique',
#      'Position': 0,
#      'PublicationStart': '/Date(-2208992400000)/',
#      'PublicationEnd': '/Date(253402210800000)/',
#      'PublicationTarget': '1,0',
#      'WebDispatchingType': 1,
#      'UnitFullPath': None,
#      'UnitPath': None}],
#    'RolesDisplay': 'Adjoint administratif',
#    'UnitsDisplay': 'DFIN - Service du cadastre et de la géomatique',
#    'UnitsExports': 'Service du cadastre et de la géomatique',
#    'UnitsFullNameExports': 'DFIN - Service du cadastre et de la géomatique'},
#   {'DisplayName': 'Allemann Aude',
#    'Email': 'aude.allemann@fr.ch',
#    'FirstName': 'Aude',
#    'Id': 5101,
#    'LastName': 'Allemann',
#    'PhoneNumber': '+41 26 305 73 66',
#    'PublicationEnd': '/Date(253402210800000)/',
#    'PublicationStart': '/Date(1513897200000)/',
#    'PublicationTarget': '1,0',
#    'Roles': [{'DirectionName': "Direction de l'instruction publique, de la culture et du sport",
#      'Email': 'aude.allemann@fr.ch',
#      'Id': 5427,
#      'PhoneNumber': '+41 26 305 73 66',
#      'RoleName': 'Coordinatrice',
#      'TitleName': None,
#      'UnitFullName': "DICS - Service de l'enseignement obligatoire de langue française",
#      'UnitId': 384,
#      'RoleDenominationId': 1689,
#      'UnitName': 'Coordination des échanges scolaires du Canton de Fribourg',
#      'Position': 0,
#      'PublicationStart': '/Date(1513897200000)/',
#      'PublicationEnd': '/Date(253402210800000)/',
#      'PublicationTarget': '1,0',
#      'WebDispatchingType': 1,
#      'UnitFullPath': None,
#      'UnitPath': None}],
#    'RolesDisplay': 'Coordinatrice',
#    'UnitsDisplay': "DICS - Service de l'enseignement obligatoire de langue française",
#    'UnitsExports': 'Coordination des échanges scolaires du Canton de Fribourg',
#    'UnitsFullNameExports': "DICS - Service de l'enseignement obligatoire de langue française"},
#   {'DisplayName': 'Allemann Aude',
#    'Email': 'aude.allemann@fr.ch',
#    'FirstName': 'Aude',
#    'Id': 5102,
#    'LastName': 'Allemann',
#    'PhoneNumber': '+41 26 305 73 66',
#    'PublicationEnd': '/Date(253402210800000)/',
#    'PublicationStart': '/Date(1513897200000)/',
#    'PublicationTarget': '1,0',
#    'Roles': [{'DirectionName': "Direction de l'instruction publique, de la culture et du sport",
#      'Email': 'aude.allemann@fr.ch',
#      'Id': 5428,
#      'PhoneNumber': '+41 26 305 73 66',
#      'RoleName': 'Coordinatrice',
#      'TitleName': None,
#      'UnitFullName': "DICS - Service de l'enseignement obligatoire de langue allemande",
#      'UnitId': 382,
#      'RoleDenominationId': 1690,
#      'UnitName': 'Coordination des échanges scolaires du Canton de Fribourg',
#      'Position': 0,
#      'PublicationStart': '/Date(1513897200000)/',
#      'PublicationEnd': '/Date(253402210800000)/',
#      'PublicationTarget': '1,0',
#      'WebDispatchingType': 1,
#      'UnitFullPath': None,
#      'UnitPath': None}],
#    'RolesDisplay': 'Coordinatrice',
#    'UnitsDisplay': "DICS - Service de l'enseignement obligatoire de langue allemande",
#    'UnitsExports': 'Coordination des échanges scolaires du Canton de Fribourg',
#    'UnitsFullNameExports': "DICS - Service de l'enseignement obligatoire de langue allemande"},
#   {'DisplayName': 'Allemann Aude',
#    'Email': 'aude.allemann@fr.ch',
#    'FirstName': 'Aude',
#    'Id': 6885,
#    'LastName': 'Allemann',
#    'PhoneNumber': '+41 26 305 73 66',
#    'PublicationEnd': '/Date(253402210800000)/',
#    'PublicationStart': '/Date(-2208992400000)/',
#    'PublicationTarget': '1,0',
#    'Roles': [{'DirectionName': "Direction de l'instruction publique, de la culture et du sport",
#      'Email': 'aude.allemann@fr.ch',
#      'Id': 7282,
#      'PhoneNumber': '+41 26 305 73 66',
#      'RoleName': 'Echanges scolaires',
#      'TitleName': None,
#      'UnitFullName': "DICS - Service de l'enseignement obligatoire de langue française",
#      'UnitId': 473,
#      'RoleDenominationId': 1895,
#      'UnitName': 'Collaborateurs/trices pédagogiques',
#      'Position': 0,
#      'PublicationStart': '/Date(-2208992400000)/',
#      'PublicationEnd': '/Date(253402210800000)/',
#      'PublicationTarget': '1,0',
#      'WebDispatchingType': 1,
#      'UnitFullPath': None,
#      'UnitPath': None}],
#    'RolesDisplay': 'Echanges scolaires',
#    'UnitsDisplay': "DICS - Service de l'enseignement obligatoire de langue française",
#    'UnitsExports': 'Collaborateurs/trices pédagogiques',
#    'UnitsFullNameExports': "DICS - Service de l'enseignement obligatoire de langue française"},
#   {'DisplayName': 'Allemann Vincent',
#    'Email': 'vincent.allemann@fr.ch',
#    'FirstName': 'Vincent',
#    'Id': 3726,
#    'LastName': 'Allemann',
#    'PhoneNumber': '+41 26 305 22 61',
#    'PublicationEnd': '/Date(253402210800000)/',
#    'PublicationStart': '/Date(-2208992400000)/',
#    'PublicationTarget': '1,0',
#    'Roles': [{'DirectionName': "Direction des institutions, de l'agriculture et des forêts",
#      'Email': 'vincent.allemann@fr.ch',
#      'Id': 2182,
#      'PhoneNumber': '+41 26 305 22 61',
#      'RoleName': "Responsable régional Gruyère et Veveyse Sud – Région d'estivage francophone",
#      'TitleName': None,
#      'UnitFullName': "DIAF - Service de l'agriculture",
#      'UnitId': 395,
#      'RoleDenominationId': 1736,
#      'UnitName': 'Paiements directs',
#      'Position': 3,
#      'PublicationStart': '/Date(-2208992400000)/',
#      'PublicationEnd': '/Date(253402210800000)/',
#      'PublicationTarget': '1,0',
#      'WebDispatchingType': 1,
#      'UnitFullPath': None,
#      'UnitPath': None}],
#    'RolesDisplay': "Responsable régional Gruyère et Veveyse Sud – Région d'estivage francophone",
#    'UnitsDisplay': "DIAF - Service de l'agriculture",
#    'UnitsExports': 'Paiements directs',
#    'UnitsFullNameExports': "DIAF - Service de l'agriculture"},
#   {'DisplayName': 'Amschwand Fabian Max Theodor',
#    'Email': 'fabian.amschwand@unifr.ch',
#    'FirstName': 'Fabian Max Theodor',
#    'Id': 3887,
#    'LastName': 'Amschwand',
#    'PhoneNumber': '+41 26 300 70 04',
#    'PublicationEnd': None,
#    'PublicationStart': '/Date(1550012400000)/',
#    'PublicationTarget': '1,0',
#    'Roles': [{'DirectionName': "Direction de l'instruction publique, de la culture et du sport",
#      'Email': 'fabian.amschwand@unifr.ch',
#      'Id': 2412,
#      'PhoneNumber': '+41 26 300 70 04',
#      'RoleName': 'Secrétaire général',
#      'TitleName': None,
#      'UnitFullName': 'DICS - Université',
#      'UnitId': 242,
#      'RoleDenominationId': 1218,
#      'UnitName': 'Rectorat',
#      'Position': 2,
#      'PublicationStart': '/Date(1550012400000)/',
#      'PublicationEnd': None,
#      'PublicationTarget': '1,0',
#      'WebDispatchingType': 1,
#      'UnitFullPath': None,
#      'UnitPath': None}],
#    'RolesDisplay': 'Secrétaire général',
#    'UnitsDisplay': 'DICS - Université',
#    'UnitsExports': 'Rectorat',
#    'UnitsFullNameExports': 'DICS - Université'},
#   {'DisplayName': 'Andenmatten Patrick',
#    'Email': 'patrick.andenmatten@fr.ch',
#    'FirstName': 'Patrick',
#    'Id': 1758,
#    'LastName': 'Andenmatten',
#    'PhoneNumber': '+41 26 305 52 75',
#    'PublicationEnd': '/Date(253402210800000)/',
#    'PublicationStart': '/Date(-2208992400000)/',
#    'PublicationTarget': '1,0',
#    'Roles': [{'DirectionName': 'Direction de la santé et des affaires sociales',
#      'Email': 'patrick.andenmatten@fr.ch',
#      'Id': 1566,
#      'PhoneNumber': '+41 26 305 52 75',
#      'RoleName': 'Conseiller économique, Chef de la section Finances',
#      'TitleName': None,
#      'UnitFullName': 'DSAS - Etablissement cantonal des assurances sociales',
#      'UnitId': 219,
#      'RoleDenominationId': 1889,
#      'UnitName': 'Caisse cantonale de compensation AVS/AI/APG',
#      'Position': 0,
#      'PublicationStart': '/Date(-2208992400000)/',
#      'PublicationEnd': '/Date(253402210800000)/',
#      'PublicationTarget': '1,0',
#      'WebDispatchingType': 1,
#      'UnitFullPath': None,
#      'UnitPath': None}],
#    'RolesDisplay': 'Conseiller économique, Chef de la section Finances',
#    'UnitsDisplay': 'DSAS - Etablissement cantonal des assurances sociales',
#    'UnitsExports': 'Caisse cantonale de compensation AVS/AI/APG',
#    'UnitsFullNameExports': 'DSAS - Etablissement cantonal des assurances sociales'},
#   {'DisplayName': 'Andrey Colette',
#    'Email': 'colette.andrey@fr.ch',
#    'FirstName': 'Colette',
#    'Id': 626,
#    'LastName': 'Andrey',
#    'PhoneNumber': '+41 26 305 58 53',
#    'PublicationEnd': '/Date(253402210800000)/',
#    'PublicationStart': '/Date(-2208992400000)/',
#    'PublicationTarget': '1,0',
#    'Roles': [{'DirectionName': "Direction des institutions, de l'agriculture et des forêts",
#      'Email': 'colette.andrey@fr.ch',
#      'Id': 3893,
#      'PhoneNumber': '+41 26 305 58 53',
#      'RoleName': 'Conseillère en économie familiale',
#      'TitleName': None,
#      'UnitFullName': "DIAF - Institut agricole de l'Etat de Fribourg",
#      'UnitId': 802,
#      'RoleDenominationId': 1623,
#      'UnitName': 'Formation continue en économie familiale',
#      'Position': 0,
#      'PublicationStart': '/Date(-2208992400000)/',
#      'PublicationEnd': '/Date(253402210800000)/',
#      'PublicationTarget': '1,0',
#      'WebDispatchingType': 1,
#      'UnitFullPath': None,
#      'UnitPath': None}],
#    'RolesDisplay': 'Conseillère en économie familiale',
#    'UnitsDisplay': "DIAF - Institut agricole de l'Etat de Fribourg",
#    'UnitsExports': 'Formation continue en économie familiale',
#    'UnitsFullNameExports': "DIAF - Institut agricole de l'Etat de Fribourg"},
#   {'DisplayName': 'Andrey Karin',
#    'Email': '',
#    'FirstName': 'Karin',
#    'Id': 1869,
#    'LastName': 'Andrey',
#    'PhoneNumber': '+41 26 305 22 04',
#    'PublicationEnd': '/Date(253402210800000)/',
#    'PublicationStart': '/Date(-2208992400000)/',
#    'PublicationTarget': '1,0',
#    'Roles': [{'DirectionName': "Direction des institutions, de l'agriculture et des forêts",
#      'Email': '',
#      'Id': 250,
#      'PhoneNumber': '+41 26 305 22 04',
#      'RoleName': 'Traductrice',
#      'TitleName': None,
#      'UnitFullName': 'DIAF - Secrétariat général',
#      'UnitId': 92,
#      'RoleDenominationId': 1313,
#      'UnitName': 'Secrétariat général',
#      'Position': 12,
#      'PublicationStart': '/Date(-2208992400000)/',
#      'PublicationEnd': '/Date(253402210800000)/',
#      'PublicationTarget': '1,0',
#      'WebDispatchingType': 0,
#      'UnitFullPath': None,
#      'UnitPath': None}],
#    'RolesDisplay': 'Traductrice',
#    'UnitsDisplay': 'DIAF - Secrétariat général',
#    'UnitsExports': 'Secrétariat général',
#    'UnitsFullNameExports': 'DIAF - Secrétariat général'},
#   {'DisplayName': 'Andrey Nicole',
#    'Email': 'nicole.andrey@fr.ch',
#    'FirstName': 'Nicole',
#    'Id': 3543,
#    'LastName': 'Andrey',
#    'PhoneNumber': '+41 26 305 23 43',
#    'PublicationEnd': None,
#    'PublicationStart': '/Date(-2208992400000)/',
#    'PublicationTarget': '1,0',
#    'Roles': [{'DirectionName': "Direction des institutions, de l'agriculture et des forêts",
#      'Email': 'nicole.andrey@fr.ch',
#      'Id': 3637,
#      'PhoneNumber': '+41 26 305 23 43',
#      'RoleName': 'Collaboratrice administrative',
#      'TitleName': None,
#      'UnitFullName': 'DIAF - Service des forêts et de la nature',
#      'UnitId': 790,
#      'RoleDenominationId': 424,
#      'UnitName': 'Secteur administration et finances',
#      'Position': 0,
#      'PublicationStart': '/Date(-2208992400000)/',
#      'PublicationEnd': None,
#      'PublicationTarget': '1,0',
#      'WebDispatchingType': 1,
#      'UnitFullPath': None,
#      'UnitPath': None}],
#    'RolesDisplay': 'Collaboratrice administrative',
#    'UnitsDisplay': 'DIAF - Service des forêts et de la nature',
#    'UnitsExports': 'Secteur administration et finances',
#    'UnitsFullNameExports': 'DIAF - Service des forêts et de la nature'},
#   {'DisplayName': 'Andrey Patrik',
#    'Email': 'patrik.andrey@fr.ch',
#    'FirstName': 'Patrik',
#    'Id': 6288,
#    'LastName': 'Andrey',
#    'PhoneNumber': '+41 26 304 16 21',
#    'PublicationEnd': None,
#    'PublicationStart': '/Date(1519858800000)/',
#    'PublicationTarget': '1,0',
#    'Roles': [{'DirectionName': "Direction de l'instruction publique, de la culture et du sport",
#      'Email': 'patrik.andrey@fr.ch',
#      'Id': 6630,
#      'PhoneNumber': '+41 26 304 16 21',
#      'RoleName': 'Gestionnaire',
#      'TitleName': None,
#      'UnitFullName': 'DICS - Service du sport',
#      'UnitId': 974,
#      'RoleDenominationId': 1743,
#      'UnitName': 'Campus Lac Noir',
#      'Position': 1,
#      'PublicationStart': '/Date(1519858800000)/',
#      'PublicationEnd': None,
#      'PublicationTarget': '1,0',
#      'WebDispatchingType': 1,
#      'UnitFullPath': None,
#      'UnitPath': None}],
#    'RolesDisplay': 'Gestionnaire',
#    'UnitsDisplay': 'DICS - Service du sport',
#    'UnitsExports': 'Campus Lac Noir',
#    'UnitsFullNameExports': 'DICS - Service du sport'},
#   {'DisplayName': 'Andric Josip',
#    'Email': '',
#    'FirstName': 'Josip',
#    'Id': 6502,
#    'LastName': 'Andric',
#    'PhoneNumber': '+41 26 305 46 24',
#    'PublicationEnd': '/Date(253402210800000)/',
# ...
#      'Email': 'direction.ep.salesvaulruz@fr.educanet2.ch',
#      'Id': 4332,
#      'PhoneNumber': '+41 26 913 04 10',
#      'RoleName': "Responsable d'établissement",
#      'TitleName': None,
#      'UnitFullName': "DICS - Service de l'enseignement obligatoire de langue française",
#      'UnitId': 875,
#      'RoleDenominationId': 1428,
#      'UnitName': 'EP Sâles, Vaulruz',
#      'Position': 0,
#      'PublicationStart': '/Date(1441922400000)/',
#      'PublicationEnd': None,
#      'PublicationTarget': '1,0',
#      'WebDispatchingType': 1,
#      'UnitFullPath': None,
#      'UnitPath': None}],
#    'RolesDisplay': "Responsable d'établissement",
#    'UnitsDisplay': "DICS - Service de l'enseignement obligatoire de langue française",
#    'UnitsExports': 'EP Sâles, Vaulruz',
#    'UnitsFullNameExports': "DICS - Service de l'enseignement obligatoire de langue française"},
#   {'DisplayName': 'Monney Pierre',
#    'Email': 'pierre.monney@fr.ch',
#    'FirstName': 'Pierre',
#    'Id': 1653,
#    'LastName': 'Monney',
#    'PhoneNumber': '+41 26 305 55 79',
#    'PublicationEnd': '/Date(253402210800000)/',
#    'PublicationStart': '/Date(-2208992400000)/',
#    'PublicationTarget': '0,1',
#    'Roles': [{'DirectionName': "Direction des institutions, de l'agriculture et des forêts",
#      'Email': 'pierre.monney@fr.ch',
#      'Id': 3906,
#      'PhoneNumber': '+41 26 305 55 79',
#      'RoleName': 'Enseignant branches générales',
#      'TitleName': None,
#      'UnitFullName': "DIAF - Institut agricole de l'Etat de Fribourg",
#      'UnitId': 804,
#      'RoleDenominationId': 673,
#      'UnitName': 'Formation en intendance dual',
#      'Position': 0,
#      'PublicationStart': '/Date(-2208992400000)/',
#      'PublicationEnd': '/Date(253402210800000)/',
#      'PublicationTarget': '0,1',
#      'WebDispatchingType': 1,
#      'UnitFullPath': None,
#      'UnitPath': None}],
#    'RolesDisplay': 'Enseignant branches générales',
#    'UnitsDisplay': "DIAF - Institut agricole de l'Etat de Fribourg",
#    'UnitsExports': 'Formation en intendance dual',
#    'UnitsFullNameExports': "DIAF - Institut agricole de l'Etat de Fribourg"},
#   {'DisplayName': 'Monney Regina',
#    'Email': 'regina.monney@fr.ch',
#    'FirstName': 'Regina',
#    'Id': 1777,
#    'LastName': 'Monney',
#    'PhoneNumber': '+41 26 305 23 43',
#    'PublicationEnd': None,
#    'PublicationStart': '/Date(-2208992400000)/',
#    'PublicationTarget': '1,0',
#    'Roles': [{'DirectionName': "Direction des institutions, de l'agriculture et des forêts",
#      'Email': 'regina.monney@fr.ch',
#      'Id': 3640,
#      'PhoneNumber': '+41 26 305 23 43',
#      'RoleName': 'Secrétaire',
#      'TitleName': None,
#      'UnitFullName': 'DIAF - Service des forêts et de la nature',
#      'UnitId': 790,
#      'RoleDenominationId': 1200,
#      'UnitName': 'Secteur administration et finances',
#      'Position': 0,
#      'PublicationStart': '/Date(-2208992400000)/',
#      'PublicationEnd': None,
#      'PublicationTarget': '1,0',
#      'WebDispatchingType': 1,
#      'UnitFullPath': None,
#      'UnitPath': None}],
#    'RolesDisplay': 'Secrétaire',
#    'UnitsDisplay': 'DIAF - Service des forêts et de la nature',
#    'UnitsExports': 'Secteur administration et finances',
#    'UnitsFullNameExports': 'DIAF - Service des forêts et de la nature'},
#   {'DisplayName': 'Monney Sandrine',
#    'Email': '',
#    'FirstName': 'Sandrine',
#    'Id': 2173,
#    'LastName': 'Monney',
#    'PhoneNumber': '+41 26 305 98 00',
#    'PublicationEnd': '/Date(253402210800000)/',
#    'PublicationStart': '/Date(-2208992400000)/',
#    'PublicationTarget': '1,0',
#    'Roles': [{'DirectionName': 'Direction de la santé et des affaires sociales',
#      'Email': '',
#      'Id': 1362,
#      'PhoneNumber': '+41 26 305 98 00',
#      'RoleName': 'Assistante dentaire',
#      'TitleName': None,
#      'UnitFullName': 'DSAS - Service dentaire scolaire',
#      'UnitId': 304,
#      'RoleDenominationId': 146,
#      'UnitName': 'Clinique dentaire de Fribourg',
#      'Position': 2,
#      'PublicationStart': '/Date(-2208992400000)/',
#      'PublicationEnd': '/Date(253402210800000)/',
#      'PublicationTarget': '1,0',
#      'WebDispatchingType': 0,
#      'UnitFullPath': None,
#      'UnitPath': None}],
#    'RolesDisplay': 'Assistante dentaire',
#    'UnitsDisplay': 'DSAS - Service dentaire scolaire',
#    'UnitsExports': 'Clinique dentaire de Fribourg',
#    'UnitsFullNameExports': 'DSAS - Service dentaire scolaire'},
#   {'DisplayName': 'Monnier Jacques',
#    'Email': 'jacques.monnier@fr.ch',
#    'FirstName': 'Jacques',
#    'Id': 1587,
#    'LastName': 'Monnier',
#    'PhoneNumber': '+41 26 305 82 42',
#    'PublicationEnd': '/Date(253402210800000)/',
#    'PublicationStart': '/Date(-2208992400000)/',
#    'PublicationTarget': '1,0',
#    'Roles': [{'DirectionName': "Direction de l'instruction publique, de la culture et du sport",
#      'Email': 'jacques.monnier@fr.ch',
#      'Id': 1617,
#      'PhoneNumber': '+41 26 305 82 42',
#      'RoleName': 'Chef de secteur, époque gallo-romaine',
#      'TitleName': None,
#      'UnitFullName': 'DICS - Service archéologique',
#      'UnitId': 346,
#      'RoleDenominationId': 250,
#      'UnitName': 'Fouilles, recherches et publications',
#      'Position': 3,
#      'PublicationStart': '/Date(-2208992400000)/',
#      'PublicationEnd': '/Date(253402210800000)/',
#      'PublicationTarget': '1,0',
#      'WebDispatchingType': 1,
#      'UnitFullPath': None,
#      'UnitPath': None}],
#    'RolesDisplay': 'Chef de secteur, époque gallo-romaine',
#    'UnitsDisplay': 'DICS - Service archéologique',
#    'UnitsExports': 'Fouilles, recherches et publications',
#    'UnitsFullNameExports': 'DICS - Service archéologique'},
#   {'DisplayName': 'Monpays Christine',
#    'Email': 'direction.ep.granges-paccot@fr.educanet2.ch',
#    'FirstName': 'Christine',
#    'Id': 6419,
#    'LastName': 'Monpays',
#    'PhoneNumber': '+41 26 460 68 41',
#    'PublicationEnd': None,
#    'PublicationStart': '/Date(1441922400000)/',
#    'PublicationTarget': '1,0',
#    'Roles': [{'DirectionName': "Direction de l'instruction publique, de la culture et du sport",
#      'Email': 'direction.ep.granges-paccot@fr.educanet2.ch',
#      'Id': 6772,
#      'PhoneNumber': '+41 26 460 68 41',
#      'RoleName': "Responsable d'établissement",
#      'TitleName': None,
#      'UnitFullName': "DICS - Service de l'enseignement obligatoire de langue française",
#      'UnitId': 848,
#      'RoleDenominationId': 1428,
#      'UnitName': 'EP Granges-Paccot - La Sonnaz',
#      'Position': 0,
#      'PublicationStart': '/Date(1441922400000)/',
#      'PublicationEnd': None,
#      'PublicationTarget': '1,0',
#      'WebDispatchingType': 1,
#      'UnitFullPath': None,
#      'UnitPath': None}],
#    'RolesDisplay': "Responsable d'établissement",
#    'UnitsDisplay': "DICS - Service de l'enseignement obligatoire de langue française",
#    'UnitsExports': 'EP Granges-Paccot - La Sonnaz',
#    'UnitsFullNameExports': "DICS - Service de l'enseignement obligatoire de langue française"},
#   {'DisplayName': 'Monterrubio Leu Cristina',
#    'Email': '',
#    'FirstName': 'Cristina',
#    'Id': 4418,
#    'LastName': 'Monterrubio Leu',
#    'PhoneNumber': '+41 26 305 79 92',
#    'PublicationEnd': None,
#    'PublicationStart': '/Date(1463004000000)/',
#    'PublicationTarget': '1,0',
#    'Roles': [{'DirectionName': 'Direction de la santé et des affaires sociales',
#      'Email': '',
#      'Id': 4697,
#      'PhoneNumber': '+41 26 305 79 92',
#      'RoleName': 'Collaboratrice scientifique',
#      'TitleName': None,
#      'UnitFullName': 'DSAS - Service du médecin cantonal',
#      'UnitId': 483,
#      'RoleDenominationId': 448,
#      'UnitName': 'Secteur collaboration scientifique',
#      'Position': 2,
#      'PublicationStart': '/Date(1463004000000)/',
#      'PublicationEnd': None,
#      'PublicationTarget': '1,0',
#      'WebDispatchingType': 0,
#      'UnitFullPath': None,
#      'UnitPath': None}],
#    'RolesDisplay': 'Collaboratrice scientifique',
#    'UnitsDisplay': 'DSAS - Service du médecin cantonal',
#    'UnitsExports': 'Secteur collaboration scientifique',
#    'UnitsFullNameExports': 'DSAS - Service du médecin cantonal'},
#   {'DisplayName': 'Mooser Coumba',
#    'Email': 'coumba.mooser@fr.ch',
#    'FirstName': 'Coumba',
#    'Id': 6289,
#    'LastName': 'Mooser',
#    'PhoneNumber': '+41 26 304 16 27',
#    'PublicationEnd': None,
#    'PublicationStart': '/Date(1519858800000)/',
#    'PublicationTarget': '1,0',
#    'Roles': [{'DirectionName': "Direction de l'instruction publique, de la culture et du sport",
#      'Email': 'coumba.mooser@fr.ch',
#      'Id': 6631,
#      'PhoneNumber': '+41 26 304 16 27',
#      'RoleName': "Employée d'administration",
#      'TitleName': None,
#      'UnitFullName': 'DICS - Service du sport',
#      'UnitId': 974,
#      'RoleDenominationId': 1593,
#      'UnitName': 'Campus Lac Noir',
#      'Position': 2,
#      'PublicationStart': '/Date(1519858800000)/',
#      'PublicationEnd': None,
#      'PublicationTarget': '1,0',
#      'WebDispatchingType': 1,
#      'UnitFullPath': None,
#      'UnitPath': None}],
#    'RolesDisplay': "Employée d'administration",
#    'UnitsDisplay': 'DICS - Service du sport',
#    'UnitsExports': 'Campus Lac Noir',
#    'UnitsFullNameExports': 'DICS - Service du sport'},
#   {'DisplayName': 'Morand Monique',
#    'Email': 'Monique.Morand@fr.ch',
#    'FirstName': 'Monique',
#    'Id': 829,
#    'LastName': 'Morand',
#    'PhoneNumber': '+41 26 305 36 41',
#    'PublicationEnd': '/Date(253402210800000)/',
#    'PublicationStart': '/Date(-2208992400000)/',
#    'PublicationTarget': '1,0',
#    'Roles': [{'DirectionName': "Direction de l'aménagement, de l'environnement et des constructions",
#      'Email': 'Monique.Morand@fr.ch',
#      'Id': 2469,
#      'PhoneNumber': '+41 26 305 36 41',
#      'RoleName': 'Cheffe de section',
#      'TitleName': None,
#      'UnitFullName': 'DAEC - Service des ponts et chaussées',
#      'UnitId': 690,
#      'RoleDenominationId': 335,
#      'UnitName': 'Ressources humaines',
#      'Position': 1,
#      'PublicationStart': '/Date(-2208992400000)/',
#      'PublicationEnd': '/Date(253402210800000)/',
#      'PublicationTarget': '1,0',
#      'WebDispatchingType': 1,
#      'UnitFullPath': None,
#      'UnitPath': None},
#     {'DirectionName': "Direction de l'aménagement, de l'environnement et des constructions",
#      'Email': 'Monique.Morand@fr.ch',
#      'Id': 1626,
#      'PhoneNumber': '+41 26 305 36 41',
#      'RoleName': 'Cheffe de section',
#      'TitleName': None,
#      'UnitFullName': 'DAEC - Service des ponts et chaussées',
#      'UnitId': 210,
#      'RoleDenominationId': 335,
#      'UnitName': 'Administration (Adm)',
#      'Position': 1,
#      'PublicationStart': '/Date(-2208992400000)/',
#      'PublicationEnd': '/Date(253402210800000)/',
#      'PublicationTarget': '1,0',
#      'WebDispatchingType': 1,
#      'UnitFullPath': None,
#      'UnitPath': None}],
#    'RolesDisplay': 'Cheffe de section, Cheffe de section',
#    'UnitsDisplay': 'DAEC - Service des ponts et chaussées, DAEC - Service des ponts et chaussées',
#    'UnitsExports': 'Ressources humaines, Administration (Adm)',
#    'UnitsFullNameExports': 'DAEC - Service des ponts et chaussées, DAEC - Service des ponts et chaussées'},
#   {'DisplayName': 'Morel Bernard',
#    'Email': 'bernard.morel@fr.ch',
#    'FirstName': 'Bernard',
#    'Id': 1811,
#    'LastName': 'Morel',
#    'PhoneNumber': '+41 26 305 55 10',
#    'PublicationEnd': '/Date(253402210800000)/',
#    'PublicationStart': '/Date(-2208992400000)/',
#    'PublicationTarget': '1,0',
#    'Roles': [{'DirectionName': "Direction des institutions, de l'agriculture et des forêts",
#      'Email': 'bernard.morel@fr.ch',
#      'Id': 2552,
#      'PhoneNumber': '+41 26 305 55 10',
#      'RoleName': 'Chef comptable',
#      'TitleName': None,
#      'UnitFullName': "DIAF - Institut agricole de l'Etat de Fribourg",
#      'UnitId': 514,
#      'RoleDenominationId': 194,
#      'UnitName': 'Comptabilité',
#      'Position': 1,
#      'PublicationStart': '/Date(-2208992400000)/',
#      'PublicationEnd': '/Date(253402210800000)/',
#      'PublicationTarget': '1,0',
#      'WebDispatchingType': 1,
#      'UnitFullPath': None,
#      'UnitPath': None}],
#    'RolesDisplay': 'Chef comptable',
#    'UnitsDisplay': "DIAF - Institut agricole de l'Etat de Fribourg",
#    'UnitsExports': 'Comptabilité',
#    'UnitsFullNameExports': "DIAF - Institut agricole de l'Etat de Fribourg"},
#   {'DisplayName': 'Morel Fanny-Iona',
#    'Email': 'fanny-iona.morel@fr.ch',
#    'FirstName': 'Fanny-Iona',
#    'Id': 2968,
#    'LastName': 'Morel',
#    'PhoneNumber': '+41 26 305 12 96',
#    'PublicationEnd': '/Date(253402210800000)/',
#    'PublicationStart': '/Date(-2208992400000)/',
#    'PublicationTarget': '1,0',
#    'Roles': [{'DirectionName': "Direction de l'instruction publique, de la culture et du sport",
#      'Email': 'fanny-iona.morel@fr.ch',
#      'Id': 3689,
#      'PhoneNumber': '+41 26 305 12 96',
#      'RoleName': 'Documentation, archivage',
#      'TitleName': None,
#      'UnitFullName': 'DICS - Service des biens culturels',
#      'UnitId': 253,
#      'RoleDenominationId': 610,
#      'UnitName': 'Recensement des biens culturels',
#      'Position': 0,
#      'PublicationStart': '/Date(-2208992400000)/',
#      'PublicationEnd': '/Date(253402210800000)/',
#      'PublicationTarget': '1,0',
#      'WebDispatchingType': 1,
#      'UnitFullPath': None,
#      'UnitPath': None}],
#    'RolesDisplay': 'Documentation, archivage',
#    'UnitsDisplay': 'DICS - Service des biens culturels',
#    'UnitsExports': 'Recensement des biens culturels',
#    'UnitsFullNameExports': 'DICS - Service des biens culturels'},
#   {'DisplayName': 'Morel Géraldine',
#    'Email': 'geraldine.morel@ocms-fribourg.ch',
#    'FirstName': 'Géraldine',
#    'Id': 1512,
#    'LastName': 'Morel',
#    'PhoneNumber': '+41 26 305 13 98',
#    'PublicationEnd': '/Date(253402210800000)/',
#    'PublicationStart': '/Date(-2208992400000)/',
#    'PublicationTarget': '1,0',
#    'Roles': [{'DirectionName': "Direction de l'instruction publique, de la culture et du sport",
#      'Email': 'geraldine.morel@ocms-fribourg.ch',
#      'Id': 484,
#      'PhoneNumber': '+41 26 305 13 98',
#      'RoleName': 'Moyens d´enseignement et fournitures scolaires',
#      'TitleName': None,
#      'UnitFullName': 'DICS - Office cantonal du matériel scolaire',
#      'UnitId': 50,
#      'RoleDenominationId': 941,
#      'UnitName': 'Office cantonal du matériel scolaire',
#      'Position': 5,
#      'PublicationStart': '/Date(-2208992400000)/',
#      'PublicationEnd': '/Date(253402210800000)/',
#      'PublicationTarget': '1,0',
#      'WebDispatchingType': 1,
#      'UnitFullPath': None,
#      'UnitPath': None}],
#    'RolesDisplay': 'Moyens d´enseignement et fournitures scolaires',
#    'UnitsDisplay': 'DICS - Office cantonal du matériel scolaire',
#    'UnitsExports': 'Office cantonal du matériel scolaire',
#    'UnitsFullNameExports': 'DICS - Office cantonal du matériel scolaire'},
#   {'DisplayName': 'Morel Géraldine',
#    'Email': 'geraldine.morel@fr.ch',
#    'FirstName': 'Géraldine',
#    'Id': 4296,
#    'LastName': 'Morel',
#    'PhoneNumber': '+41 26 305 23 73',
#    'PublicationEnd': None,
#    'PublicationStart': '/Date(1452121200000)/',
#    'PublicationTarget': '1,0',
#    'Roles': [{'DirectionName': 'Direction de la santé et des affaires sociales',
#      'Email': 'geraldine.morel@fr.ch',
#      'Id': 4562,
#      'PhoneNumber': '+41 26 305 23 73',
#      'RoleName': 'Collaboratrice scientifique universitaire',
#      'TitleName': None,
#      'UnitFullName': "DSAS - Bureau de l'égalité hommes-femmes et de la famille",
#      'UnitId': 64,
#      'RoleDenominationId': 451,
#      'UnitName': "Bureau de l'égalité hommes-femmes et de la famille",
#      'Position': 0,
#      'PublicationStart': '/Date(1452121200000)/',
#      'PublicationEnd': None,
#      'PublicationTarget': '1,0',
#      'WebDispatchingType': 1,
#      'UnitFullPath': None,
#      'UnitPath': None}],
#    'RolesDisplay': 'Collaboratrice scientifique universitaire',
#    'UnitsDisplay': "DSAS - Bureau de l'égalité hommes-femmes et de la famille",
#    'UnitsExports': "Bureau de l'égalité hommes-femmes et de la famille",
#    'UnitsFullNameExports': "DSAS - Bureau de l'égalité hommes-femmes et de la famille"},
#   ...],
#  'Total': 1590,
#  'AggregateResults': None,
#  'Errors': None}

# %%
# Zugreifen auf 'Data'
response_as_json['Data']
# Out:
# [{'DisplayName': '--- ---',
#   'Email': '',
#   'FirstName': '---',
#   'Id': 96,
#   'LastName': '---',
#   'PhoneNumber': '+41 26 305 12 70',
#   'PublicationEnd': '/Date(253402210800000)/',
#   'PublicationStart': '/Date(-2208992400000)/',
#   'PublicationTarget': '1,0',
#   'Roles': [{'DirectionName': "Chancellerie d'Etat",
#     'Email': '',
#     'Id': 1350,
#     'PhoneNumber': '+41 26 305 12 70',
#     'RoleName': 'Secrétariat',
#     'TitleName': None,
#     'UnitFullName': "CHA - Archives de l'Etat",
#     'UnitId': 318,
#     'RoleDenominationId': 1236,
#     'UnitName': "Archives de l'Etat",
#     'Position': 3,
#     'PublicationStart': '/Date(-2208992400000)/',
#     'PublicationEnd': '/Date(253402210800000)/',
#     'PublicationTarget': '1,0',
#     'WebDispatchingType': 0,
#     'UnitFullPath': None,
#     'UnitPath': None}],
#   'RolesDisplay': 'Secrétariat',
#   'UnitsDisplay': "CHA - Archives de l'Etat",
#   'UnitsExports': "Archives de l'Etat",
#   'UnitsFullNameExports': "CHA - Archives de l'Etat"},
#  {'DisplayName': 'Abeztout Abderrahim',
#   'Email': 'abderrahim.abeztout@fr.ch',
#   'FirstName': 'Abderrahim',
#   'Id': 4423,
#   'LastName': 'Abeztout',
#   'PhoneNumber': '+41 26 305 37 97',
#   'PublicationEnd': None,
#   'PublicationStart': '/Date(1463608800000)/',
#   'PublicationTarget': '1,0',
#   'Roles': [{'DirectionName': "Direction de l'aménagement, de l'environnement et des constructions",
#     'Email': 'abderrahim.abeztout@fr.ch',
#     'Id': 4703,
#     'PhoneNumber': '+41 26 305 37 97',
#     'RoleName': 'Architecte',
#     'TitleName': None,
#     'UnitFullName': 'DAEC - Service des bâtiments',
#     'UnitId': 235,
#     'RoleDenominationId': 121,
#     'UnitName': 'Section technique',
#     'Position': 0,
#     'PublicationStart': '/Date(1463608800000)/',
#     'PublicationEnd': None,
#     'PublicationTarget': '1,0',
#     'WebDispatchingType': 1,
#     'UnitFullPath': None,
#     'UnitPath': None}],
#   'RolesDisplay': 'Architecte',
#   'UnitsDisplay': 'DAEC - Service des bâtiments',
#   'UnitsExports': 'Section technique',
#   'UnitsFullNameExports': 'DAEC - Service des bâtiments'},
#  {'DisplayName': 'Ackermann Christophe',
#   'Email': 'christophe.ackermann@fr.ch',
#   'FirstName': 'Christophe',
#   'Id': 1544,
#   'LastName': 'Ackermann',
#   'PhoneNumber': '+41 26 305 31 38',
#   'PublicationEnd': '/Date(253402210800000)/',
#   'PublicationStart': '/Date(-2208992400000)/',
#   'PublicationTarget': '1,0',
#   'Roles': [{'DirectionName': 'Direction des finances',
#     'Email': 'christophe.ackermann@fr.ch',
#     'Id': 11,
#     'PhoneNumber': '+41 26 305 31 38',
#     'RoleName': 'Adjoint de la cheffe de service',
#     'TitleName': None,
#     'UnitFullName': 'DFIN - Inspection des finances',
#     'UnitId': 29,
#     'RoleDenominationId': 15,
#     'UnitName': 'Inspection des finances',
#     'Position': 2,
#     'PublicationStart': '/Date(-2208992400000)/',
#     'PublicationEnd': '/Date(253402210800000)/',
#     'PublicationTarget': '1,0',
#     'WebDispatchingType': 1,
#     'UnitFullPath': None,
#     'UnitPath': None}],
#   'RolesDisplay': 'Adjoint de la cheffe de service',
#   'UnitsDisplay': 'DFIN - Inspection des finances',
#   'UnitsExports': 'Inspection des finances',
#   'UnitsFullNameExports': 'DFIN - Inspection des finances'},
#  {'DisplayName': 'Ackermann Urs',
#   'Email': 'urs.ackermann@fr.ch',
#   'FirstName': 'Urs',
#   'Id': 3557,
#   'LastName': 'Ackermann',
#   'PhoneNumber': '+41 26 305 14 16',
#   'PublicationEnd': '/Date(253402210800000)/',
#   'PublicationStart': '/Date(-2208992400000)/',
#   'PublicationTarget': '1,0',
#   'Roles': [{'DirectionName': "Direction des institutions, de l'agriculture et des forêts",
#     'Email': 'urs.ackermann@fr.ch',
#     'Id': 1213,
#     'PhoneNumber': '+41 26 305 14 16',
#     'RoleName': 'Collaborateur administratif supérieur',
#     'TitleName': None,
#     'UnitFullName': "DIAF - Service des affaires institutionnelles, des naturalisations et de l'état civil",
#     'UnitId': 895,
#     'RoleDenominationId': 364,
#     'UnitName': 'Secteur des institutions et affaires juridiques',
#     'Position': 3,
#     'PublicationStart': '/Date(-2208992400000)/',
#     'PublicationEnd': '/Date(253402210800000)/',
#     'PublicationTarget': '1,0',
#     'WebDispatchingType': 1,
#     'UnitFullPath': None,
#     'UnitPath': None}],
#   'RolesDisplay': 'Collaborateur administratif supérieur',
#   'UnitsDisplay': "DIAF - Service des affaires institutionnelles, des naturalisations et de l'état civil",
#   'UnitsExports': 'Secteur des institutions et affaires juridiques',
#   'UnitsFullNameExports': "DIAF - Service des affaires institutionnelles, des naturalisations et de l'état civil"},
#  {'DisplayName': 'Adam Samuel',
#   'Email': '',
#   'FirstName': 'Samuel',
#   'Id': 2628,
#   'LastName': 'Adam',
#   'PhoneNumber': '+41 26 305 29 63',
#   'PublicationEnd': '/Date(253402210800000)/',
#   'PublicationStart': '/Date(-2208992400000)/',
#   'PublicationTarget': '1,0',
#   'Roles': [{'DirectionName': 'Direction de la santé et des affaires sociales',
#     'Email': '',
#     'Id': 1890,
#     'PhoneNumber': '+41 26 305 29 63',
#     'RoleName': 'Adjoint du chef de service',
#     'TitleName': None,
#     'UnitFullName': 'DSAS - Service du médecin cantonal',
#     'UnitId': 75,
#     'RoleDenominationId': 21,
#     'UnitName': 'Service du médecin cantonal',
#     'Position': 5,
#     'PublicationStart': '/Date(-2208992400000)/',
#     'PublicationEnd': '/Date(253402210800000)/',
#     'PublicationTarget': '1,0',
#     'WebDispatchingType': 0,
#     'UnitFullPath': None,
#     'UnitPath': None}],
#   'RolesDisplay': 'Adjoint du chef de service',
#   'UnitsDisplay': 'DSAS - Service du médecin cantonal',
#   'UnitsExports': 'Service du médecin cantonal',
#   'UnitsFullNameExports': 'DSAS - Service du médecin cantonal'},
#  {'DisplayName': 'Aebischer Adrian',
#   'Email': 'adrian.aebischer@fr.ch',
#   'FirstName': 'Adrian',
#   'Id': 1289,
#   'LastName': 'Aebischer',
#   'PhoneNumber': '+41 26 305 23 43',
#   'PublicationEnd': None,
#   'PublicationStart': '/Date(-2208992400000)/',
#   'PublicationTarget': '1,0',
#   'Roles': [{'DirectionName': "Direction des institutions, de l'agriculture et des forêts",
#     'Email': 'adrian.aebischer@fr.ch',
#     'Id': 3656,
#     'PhoneNumber': '+41 26 305 23 43',
#     'RoleName': 'Collaborateur scientifique, biodiversité en forêt',
#     'TitleName': None,
#     'UnitFullName': 'DIAF - Service des forêts et de la nature',
#     'UnitId': 794,
#     'RoleDenominationId': 392,
#     'UnitName': 'Secteur faune, biodiversité, chasse et pêche',
#     'Position': 0,
#     'PublicationStart': '/Date(-2208992400000)/',
#     'PublicationEnd': None,
#     'PublicationTarget': '1,0',
#     'WebDispatchingType': 1,
#     'UnitFullPath': None,
#     'UnitPath': None}],
#   'RolesDisplay': 'Collaborateur scientifique, biodiversité en forêt',
#   'UnitsDisplay': 'DIAF - Service des forêts et de la nature',
#   'UnitsExports': 'Secteur faune, biodiversité, chasse et pêche',
#   'UnitsFullNameExports': 'DIAF - Service des forêts et de la nature'},
#  {'DisplayName': 'Aebischer Christoph',
#   'Email': '',
#   'FirstName': 'Christoph',
#   'Id': 1580,
#   'LastName': 'Aebischer',
#   'PhoneNumber': '+41 26 304 14 04',
#   'PublicationEnd': '/Date(253402210800000)/',
#   'PublicationStart': '/Date(-2208992400000)/',
#   'PublicationTarget': '0,1',
#   'Roles': [{'DirectionName': "Direction de l'économie et de l'emploi",
#     'Email': '',
#     'Id': 44,
#     'PhoneNumber': '+41 26 304 14 04',
#     'RoleName': 'Chef de projets',
#     'TitleName': None,
#     'UnitFullName': 'DEE - Promotion économique du canton de Fribourg',
#     'UnitId': 36,
#     'RoleDenominationId': 237,
#     'UnitName': 'Promotion économique du canton de Fribourg',
#     'Position': 0,
#     'PublicationStart': '/Date(-2208992400000)/',
#     'PublicationEnd': '/Date(253402210800000)/',
#     'PublicationTarget': '0,1',
#     'WebDispatchingType': 0,
#     'UnitFullPath': None,
#     'UnitPath': None}],
#   'RolesDisplay': 'Chef de projets',
#   'UnitsDisplay': 'DEE - Promotion économique du canton de Fribourg',
#   'UnitsExports': 'Promotion économique du canton de Fribourg',
#   'UnitsFullNameExports': 'DEE - Promotion économique du canton de Fribourg'},
#  {'DisplayName': 'Aebischer Fernand',
#   'Email': 'Non renseigné',
#   'FirstName': 'Fernand',
#   'Id': 36,
#   'LastName': 'Aebischer',
#   'PhoneNumber': '',
#   'PublicationEnd': '/Date(253402210800000)/',
#   'PublicationStart': '/Date(-2208992400000)/',
#   'PublicationTarget': '0,1',
#   'Roles': [{'DirectionName': 'Divers',
#     'Email': 'Non renseigné',
#     'Id': 3997,
#     'PhoneNumber': None,
#     'RoleName': 'Quilles',
#     'TitleName': None,
#     'UnitFullName': "DIV - Groupement polysportif de l'Etat de Fribourg",
#     'UnitId': 344,
#     'RoleDenominationId': 1011,
#     'UnitName': 'Disciplines',
#     'Position': 0,
#     'PublicationStart': '/Date(-2208992400000)/',
#     'PublicationEnd': '/Date(253402210800000)/',
#     'PublicationTarget': '0,1',
#     'WebDispatchingType': 1,
#     'UnitFullPath': None,
#     'UnitPath': None}],
#   'RolesDisplay': 'Quilles',
#   'UnitsDisplay': "DIV - Groupement polysportif de l'Etat de Fribourg",
#   'UnitsExports': 'Disciplines',
#   'UnitsFullNameExports': "DIV - Groupement polysportif de l'Etat de Fribourg"},
#  {'DisplayName': 'Aebischer Florent',
#   'Email': 'florent.aebischer@fr.ch',
#   'FirstName': 'Florent',
#   'Id': 3328,
#   'LastName': 'Aebischer',
#   'PhoneNumber': '+41 26 305 44 89',
#   'PublicationEnd': '/Date(253402210800000)/',
#   'PublicationStart': '/Date(-2208992400000)/',
#   'PublicationTarget': '1,0',
#   'Roles': [{'DirectionName': "Direction de l'économie et de l'emploi",
#     'Email': 'florent.aebischer@fr.ch',
#     'Id': 981,
#     'PhoneNumber': '+41 26 305 44 89',
#     'RoleName': 'Secrétariat et guichet',
#     'TitleName': None,
#     'UnitFullName': 'DEE - Service du registre du commerce',
#     'UnitId': 38,
#     'RoleDenominationId': 1856,
#     'UnitName': 'Service du registre du commerce',
#     'Position': 0,
#     'PublicationStart': '/Date(-2208992400000)/',
#     'PublicationEnd': '/Date(253402210800000)/',
#     'PublicationTarget': '1,0',
#     'WebDispatchingType': 1,
#     'UnitFullPath': None,
#     'UnitPath': None}],
#   'RolesDisplay': 'Secrétariat et guichet',
#   'UnitsDisplay': 'DEE - Service du registre du commerce',
#   'UnitsExports': 'Service du registre du commerce',
#   'UnitsFullNameExports': 'DEE - Service du registre du commerce'},
#  {'DisplayName': 'Aebischer Jean-Marc',
#   'Email': '',
#   'FirstName': 'Jean-Marc',
#   'Id': 1038,
#   'LastName': 'Aebischer',
#   'PhoneNumber': '+41 26 305 12 61',
#   'PublicationEnd': None,
#   'PublicationStart': '/Date(1485385200000)/',
#   'PublicationTarget': '1,0',
#   'Roles': [{'DirectionName': "Direction de l'instruction publique, de la culture et du sport",
#     'Email': '',
#     'Id': 538,
#     'PhoneNumber': '+41 26 305 12 61',
#     'RoleName': 'Collaborateur pédagogique',
#     'TitleName': None,
#     'UnitFullName': 'DICS - Service du sport',
#     'UnitId': 81,
#     'RoleDenominationId': 381,
#     'UnitName': 'Service du sport',
#     'Position': 2,
#     'PublicationStart': '/Date(1485385200000)/',
#     'PublicationEnd': None,
#     'PublicationTarget': '1,0',
#     'WebDispatchingType': 0,
#     'UnitFullPath': None,
#     'UnitPath': None}],
#   'RolesDisplay': 'Collaborateur pédagogique',
#   'UnitsDisplay': 'DICS - Service du sport',
#   'UnitsExports': 'Service du sport',
#   'UnitsFullNameExports': 'DICS - Service du sport'},
#  {'DisplayName': 'Aebischer Jean-Marc',
#   'Email': 'jean-marc.aebischer@fr.ch',
#   'FirstName': 'Jean-Marc',
#   'Id': 4664,
#   'LastName': 'Aebischer',
#   'PhoneNumber': '+41 26 305 12 61',
#   'PublicationEnd': '/Date(253402210800000)/',
#   'PublicationStart': '/Date(-2208992400000)/',
#   'PublicationTarget': '1,0',
#   'Roles': [{'DirectionName': "Direction de l'instruction publique, de la culture et du sport",
#     'Email': 'jean-marc.aebischer@fr.ch',
#     'Id': 4959,
#     'PhoneNumber': '+41 26 305 12 61',
#     'RoleName': 'Corps et mouvement, cycles 1, 2 & 3',
#     'TitleName': None,
#     'UnitFullName': "DICS - Service de l'enseignement obligatoire de langue française",
#     'UnitId': 473,
#     'RoleDenominationId': 1606,
#     'UnitName': 'Collaborateurs/trices pédagogiques',
#     'Position': 0,
#     'PublicationStart': '/Date(-2208992400000)/',
#     'PublicationEnd': '/Date(253402210800000)/',
#     'PublicationTarget': '1,0',
#     'WebDispatchingType': 1,
#     'UnitFullPath': None,
#     'UnitPath': None}],
#   'RolesDisplay': 'Corps et mouvement, cycles 1, 2 & 3',
#   'UnitsDisplay': "DICS - Service de l'enseignement obligatoire de langue française",
#   'UnitsExports': 'Collaborateurs/trices pédagogiques',
#   'UnitsFullNameExports': "DICS - Service de l'enseignement obligatoire de langue française"},
#  {'DisplayName': 'Aebischer Jean-Marie',
#   'Email': 'jean-marie.aebischer@fr.oai.ch',
#   'FirstName': 'Jean-Marie',
#   'Id': 609,
#   'LastName': 'Aebischer',
#   'PhoneNumber': '+41 26 305 52 40',
#   'PublicationEnd': '/Date(253402210800000)/',
#   'PublicationStart': '/Date(-2208992400000)/',
#   'PublicationTarget': '0,1',
#   'Roles': [{'DirectionName': 'Direction de la santé et des affaires sociales',
#     'Email': 'jean-marie.aebischer@fr.oai.ch',
#     'Id': 1601,
#     'PhoneNumber': '+41 26 305 52 40',
#     'RoleName': 'Chef section Services généraux',
#     'TitleName': None,
#     'UnitFullName': 'DSAS - Etablissement cantonal des assurances sociales',
#     'UnitId': 220,
#     'RoleDenominationId': 312,
#     'UnitName': "Office cantonal de l'assurance-invalidité",
#     'Position': 0,
#     'PublicationStart': '/Date(-2208992400000)/',
#     'PublicationEnd': '/Date(253402210800000)/',
#     'PublicationTarget': '0,1',
#     'WebDispatchingType': 1,
#     'UnitFullPath': None,
#     'UnitPath': None}],
#   'RolesDisplay': 'Chef section Services généraux',
#   'UnitsDisplay': 'DSAS - Etablissement cantonal des assurances sociales',
#   'UnitsExports': "Office cantonal de l'assurance-invalidité",
#   'UnitsFullNameExports': 'DSAS - Etablissement cantonal des assurances sociales'},
#  {'DisplayName': 'Aebischer Maryse',
#   'Email': '',
#   'FirstName': 'Maryse',
#   'Id': 755,
#   'LastName': 'Aebischer',
#   'PhoneNumber': '+41 26 305 29 68',
#   'PublicationEnd': '/Date(253402210800000)/',
#   'PublicationStart': '/Date(-2208992400000)/',
#   'PublicationTarget': '0,1',
#   'Roles': [{'DirectionName': 'Direction de la santé et des affaires sociales',
#     'Email': '',
#     'Id': 318,
#     'PhoneNumber': '+41 26 305 29 68',
#     'RoleName': 'Cheffe de service',
#     'TitleName': None,
#     'UnitFullName': 'DSAS - Service de la prévoyance sociale',
#     'UnitId': 40,
#     'RoleDenominationId': 339,
#     'UnitName': 'Service de la prévoyance sociale',
#     'Position': 1,
#     'PublicationStart': '/Date(-2208992400000)/',
#     'PublicationEnd': '/Date(253402210800000)/',
#     'PublicationTarget': '0,1',
#     'WebDispatchingType': 0,
#     'UnitFullPath': None,
#     'UnitPath': None}],
#   'RolesDisplay': 'Cheffe de service',
#   'UnitsDisplay': 'DSAS - Service de la prévoyance sociale',
#   'UnitsExports': 'Service de la prévoyance sociale',
#   'UnitsFullNameExports': 'DSAS - Service de la prévoyance sociale'},
#  {'DisplayName': 'Aebischer Mélody',
#   'Email': 'melody.aebischer@fr.ch',
#   'FirstName': 'Mélody',
#   'Id': 4438,
#   'LastName': 'Aebischer',
#   'PhoneNumber': '+41 26 305 55 09',
#   'PublicationEnd': '/Date(253402210800000)/',
#   'PublicationStart': '/Date(-2208992400000)/',
#   'PublicationTarget': '1,0',
#   'Roles': [{'DirectionName': "Direction des institutions, de l'agriculture et des forêts",
#     'Email': 'melody.aebischer@fr.ch',
#     'Id': 4718,
#     'PhoneNumber': '+41 26 305 55 09',
#     'RoleName': 'Spécialiste RH',
#     'TitleName': None,
#     'UnitFullName': "DIAF - Institut agricole de l'Etat de Fribourg",
#     'UnitId': 606,
#     'RoleDenominationId': 1271,
#     'UnitName': 'Administration',
#     'Position': 0,
#     'PublicationStart': '/Date(-2208992400000)/',
#     'PublicationEnd': '/Date(253402210800000)/',
#     'PublicationTarget': '1,0',
#     'WebDispatchingType': 1,
#     'UnitFullPath': None,
#     'UnitPath': None}],
#   'RolesDisplay': 'Spécialiste RH',
#   'UnitsDisplay': "DIAF - Institut agricole de l'Etat de Fribourg",
#   'UnitsExports': 'Administration',
#   'UnitsFullNameExports': "DIAF - Institut agricole de l'Etat de Fribourg"},
#  {'DisplayName': 'Aebischer Nicolas',
#   'Email': 'nicolas.aebischer@ocms-fribourg.ch',
#   'FirstName': 'Nicolas',
#   'Id': 1035,
#   'LastName': 'Aebischer',
#   'PhoneNumber': '+41 26 305 13 90',
#   'PublicationEnd': '/Date(253402210800000)/',
#   'PublicationStart': '/Date(-2208992400000)/',
#   'PublicationTarget': '1,0',
#   'Roles': [{'DirectionName': "Direction de l'instruction publique, de la culture et du sport",
#     'Email': 'nicolas.aebischer@ocms-fribourg.ch',
#     'Id': 142,
#     'PhoneNumber': '+41 26 305 13 90',
#     'RoleName': 'Adjoint à la direction',
#     'TitleName': None,
#     'UnitFullName': 'DICS - Office cantonal du matériel scolaire',
#     'UnitId': 50,
#     'RoleDenominationId': 7,
#     'UnitName': 'Office cantonal du matériel scolaire',
#     'Position': 2,
#     'PublicationStart': '/Date(-2208992400000)/',
#     'PublicationEnd': '/Date(253402210800000)/',
#     'PublicationTarget': '1,0',
#     'WebDispatchingType': 1,
#     'UnitFullPath': None,
#     'UnitPath': None}],
#   'RolesDisplay': 'Adjoint à la direction',
#   'UnitsDisplay': 'DICS - Office cantonal du matériel scolaire',
#   'UnitsExports': 'Office cantonal du matériel scolaire',
#   'UnitsFullNameExports': 'DICS - Office cantonal du matériel scolaire'},
#  {'DisplayName': 'Aebischer Nicolas',
#   'Email': 'nicolas.aebischer@fr.ch',
#   'FirstName': 'Nicolas',
#   'Id': 1401,
#   'LastName': 'Aebischer',
#   'PhoneNumber': '+41 26 305 37 60',
#   'PublicationEnd': '/Date(253402210800000)/',
#   'PublicationStart': '/Date(-2208992400000)/',
#   'PublicationTarget': '1,0',
#   'Roles': [{'DirectionName': "Direction de l'aménagement, de l'environnement et des constructions",
#     'Email': 'nicolas.aebischer@fr.ch',
#     'Id': 1843,
#     'PhoneNumber': '+41 26 305 37 60',
#     'RoleName': 'Chef du secteur contrôle des eaux et produits chimiques',
#     'TitleName': None,
#     'UnitFullName': "DAEC - Service de l'environnement",
#     'UnitId': 241,
#     'RoleDenominationId': 1874,
#     'UnitName': 'Section laboratoire et substances',
#     'Position': 2,
#     'PublicationStart': '/Date(-2208992400000)/',
#     'PublicationEnd': '/Date(253402210800000)/',
#     'PublicationTarget': '1,0',
#     'WebDispatchingType': 1,
#     'UnitFullPath': None,
#     'UnitPath': None}],
#   'RolesDisplay': 'Chef du secteur contrôle des eaux et produits chimiques',
#   'UnitsDisplay': "DAEC - Service de l'environnement",
#   'UnitsExports': 'Section laboratoire et substances',
#   'UnitsFullNameExports': "DAEC - Service de l'environnement"},
#  {'DisplayName': 'Aebischer-Aeby Elisabeth',
#   'Email': 'aebischerel@edufr.ch',
#   'FirstName': 'Elisabeth',
#   'Id': 3119,
#   'LastName': 'Aebischer-Aeby',
#   'PhoneNumber': '+41 26 305 79 14',
#   'PublicationEnd': '/Date(253402210800000)/',
#   'PublicationStart': '/Date(-2208992400000)/',
#   'PublicationTarget': '1,0',
#   'Roles': [{'DirectionName': "Direction de l'instruction publique, de la culture et du sport",
#     'Email': 'aebischerel@edufr.ch',
#     'Id': 3758,
#     'PhoneNumber': '+41 26 305 79 14',
#     'RoleName': 'Proviseure',
#     'TitleName': None,
#     'UnitFullName': "DICS - Service de l'enseignement secondaire du deuxième degré",
#     'UnitId': 274,
#     'RoleDenominationId': 1005,
#     'UnitName': 'Collège de Gambach',
#     'Position': 2,
#     'PublicationStart': '/Date(-2208992400000)/',
#     'PublicationEnd': '/Date(253402210800000)/',
#     'PublicationTarget': '1,0',
#     'WebDispatchingType': 1,
#     'UnitFullPath': None,
#     'UnitPath': None}],
#   'RolesDisplay': 'Proviseure',
#   'UnitsDisplay': "DICS - Service de l'enseignement secondaire du deuxième degré",
#   'UnitsExports': 'Collège de Gambach',
#   'UnitsFullNameExports': "DICS - Service de l'enseignement secondaire du deuxième degré"},
#  {'DisplayName': 'Aebischer-Piller Christa',
#   'Email': 'christa.aebischer@fr.ch',
#   'FirstName': 'Christa',
#   'Id': 895,
#   'LastName': 'Aebischer-Piller',
#   'PhoneNumber': '+41 26 305 40 88',
#   'PublicationEnd': '/Date(253402210800000)/',
#   'PublicationStart': '/Date(-2208992400000)/',
#   'PublicationTarget': '1,0',
#   'Roles': [{'DirectionName': "Direction de l'instruction publique, de la culture et du sport",
#     'Email': 'christa.aebischer@fr.ch',
#     'Id': 2030,
#     'PhoneNumber': '+41 26 305 40 88',
#     'RoleName': 'Collaboratrice pédagogique; promotion des langues 1er cycle',
#     'TitleName': None,
#     'UnitFullName': "DICS - Service de l'enseignement obligatoire de langue allemande",
#     'UnitId': 485,
#     'RoleDenominationId': 445,
#     'UnitName': 'Collaboration pédagogique',
#     'Position': 1,
#     'PublicationStart': '/Date(-2208992400000)/',
#     'PublicationEnd': '/Date(253402210800000)/',
#     'PublicationTarget': '1,0',
#     'WebDispatchingType': 1,
#     'UnitFullPath': None,
#     'UnitPath': None},
#    {'DirectionName': "Direction de l'instruction publique, de la culture et du sport",
#     'Email': 'christa.aebischer@fr.ch',
#     'Id': 1763,
#     'PhoneNumber': '+41 26 305 40 88',
#     'RoleName': 'Inspectrice',
#     'TitleName': None,
#     'UnitFullName': "DICS - Service de l'enseignement obligatoire de langue allemande",
#     'UnitId': 405,
#     'RoleDenominationId': 839,
#     'UnitName': 'Inspection des écoles enfantines et primaires; Tavel',
#     'Position': 1,
#     'PublicationStart': '/Date(-2208992400000)/',
#     'PublicationEnd': '/Date(253402210800000)/',
#     'PublicationTarget': '1,0',
#     'WebDispatchingType': 1,
#     'UnitFullPath': None,
#     'UnitPath': None}],
#   'RolesDisplay': 'Collaboratrice pédagogique; promotion des langues 1er cycle, Inspectrice',
#   'UnitsDisplay': "DICS - Service de l'enseignement obligatoire de langue allemande, DICS - Service de l'enseignement obligatoire de langue allemande",
#   'UnitsExports': 'Collaboration pédagogique, Inspection des écoles enfantines et primaires; Tavel',
#   'UnitsFullNameExports': "DICS - Service de l'enseignement obligatoire de langue allemande, DICS - Service de l'enseignement obligatoire de langue allemande"},
#  {'DisplayName': 'Aeby Annabelle',
#   'Email': '',
#   'FirstName': 'Annabelle',
#   'Id': 1853,
#   'LastName': 'Aeby',
#   'PhoneNumber': '+41 26 305 79 89',
#   'PublicationEnd': '/Date(253402210800000)/',
#   'PublicationStart': '/Date(-2208992400000)/',
#   'PublicationTarget': '1,0',
#   'Roles': [{'DirectionName': 'Direction de la santé et des affaires sociales',
#     'Email': '',
#     'Id': 1160,
#     'PhoneNumber': '+41 26 305 79 89',
#     'RoleName': 'Infirmière',
#     'TitleName': None,
#     'UnitFullName': 'DSAS - Service du médecin cantonal',
#     'UnitId': 481,
#     'RoleDenominationId': 778,
#     'UnitName': 'Secteur infirmier',
#     'Position': 2,
#     'PublicationStart': '/Date(-2208992400000)/',
#     'PublicationEnd': '/Date(253402210800000)/',
#     'PublicationTarget': '1,0',
#     'WebDispatchingType': 0,
#     'UnitFullPath': None,
#     'UnitPath': None}],
#   'RolesDisplay': 'Infirmière',
#   'UnitsDisplay': 'DSAS - Service du médecin cantonal',
#   'UnitsExports': 'Secteur infirmier',
#   'UnitsFullNameExports': 'DSAS - Service du médecin cantonal'},
#  {'DisplayName': 'Aeby Frédéric',
#   'Email': '',
#   'FirstName': 'Frédéric',
#   'Id': 6508,
#   'LastName': 'Aeby',
#   'PhoneNumber': '+41 26 305 40 85',
#   'PublicationEnd': None,
#   'PublicationStart': '/Date(1536876000000)/',
#   'PublicationTarget': '1,0',
#   'Roles': [{'DirectionName': "Direction de l'instruction publique, de la culture et du sport",
#     'Email': '',
#     'Id': 6867,
#     'PhoneNumber': '+41 26 305 40 85',
#     'RoleName': 'Collaborateur pédagogique',
#     'TitleName': None,
#     'UnitFullName': "DICS - Service de l'enseignement obligatoire de langue allemande",
#     'UnitId': 485,
#     'RoleDenominationId': 381,
#     'UnitName': 'Collaboration pédagogique',
#     'Position': 7,
#     'PublicationStart': '/Date(1536876000000)/',
#     'PublicationEnd': None,
#     'PublicationTarget': '1,0',
#     'WebDispatchingType': 0,
#     'UnitFullPath': None,
#     'UnitPath': None}],
#   'RolesDisplay': 'Collaborateur pédagogique',
#   'UnitsDisplay': "DICS - Service de l'enseignement obligatoire de langue allemande",
#   'UnitsExports': 'Collaboration pédagogique',
#   'UnitsFullNameExports': "DICS - Service de l'enseignement obligatoire de langue allemande"},
#  {'DisplayName': 'Aeby Pascal',
#   'Email': 'pascal.aeby@fr.ch',
#   'FirstName': 'Pascal',
#   'Id': 1205,
#   'LastName': 'Aeby',
#   'PhoneNumber': '+41 26 305 31 03',
#   'PublicationEnd': '/Date(253402210800000)/',
#   'PublicationStart': '/Date(-2208992400000)/',
#   'PublicationTarget': '1,0',
#   'Roles': [{'DirectionName': 'Direction des finances',
#     'Email': 'pascal.aeby@fr.ch',
#     'Id': 776,
#     'PhoneNumber': '+41 26 305 31 03',
#     'RoleName': 'Secrétaire général',
#     'TitleName': None,
#     'UnitFullName': 'DFIN - Secrétariat général',
#     'UnitId': 16,
#     'RoleDenominationId': 1218,
#     'UnitName': 'Secrétariat général',
#     'Position': 2,
#     'PublicationStart': '/Date(-2208992400000)/',
#     'PublicationEnd': '/Date(253402210800000)/',
#     'PublicationTarget': '1,0',
#     'WebDispatchingType': 1,
#     'UnitFullPath': None,
#     'UnitPath': None}],
#   'RolesDisplay': 'Secrétaire général',
#   'UnitsDisplay': 'DFIN - Secrétariat général',
#   'UnitsExports': 'Secrétariat général',
#   'UnitsFullNameExports': 'DFIN - Secrétariat général'},
#  {'DisplayName': 'Aeby Pierre',
#   'Email': 'pierre.aeby@fr.ch',
#   'FirstName': 'Pierre',
#   'Id': 1106,
#   'LastName': 'Aeby',
#   'PhoneNumber': '+41 26 305 58 62',
#   'PublicationEnd': '/Date(253402210800000)/',
#   'PublicationStart': '/Date(-2208992400000)/',
#   'PublicationTarget': '0,1',
#   'Roles': [{'DirectionName': "Direction des institutions, de l'agriculture et des forêts",
#     'Email': 'pierre.aeby@fr.ch',
#     'Id': 3874,
#     'PhoneNumber': '+41 26 305 58 62',
#     'RoleName': 'Responsable production végétale',
#     'TitleName': None,
#     'UnitFullName': "DIAF - Institut agricole de l'Etat de Fribourg",
#     'UnitId': 800,
#     'RoleDenominationId': 1154,
#     'UnitName': 'Production végétale (PV)',
#     'Position': 1,
#     'PublicationStart': '/Date(-2208992400000)/',
#     'PublicationEnd': '/Date(253402210800000)/',
#     'PublicationTarget': '0,1',
#     'WebDispatchingType': 1,
#     'UnitFullPath': None,
#     'UnitPath': None}],
#   'RolesDisplay': 'Responsable production végétale',
#   'UnitsDisplay': "DIAF - Institut agricole de l'Etat de Fribourg",
#   'UnitsExports': 'Production végétale (PV)',
#   'UnitsFullNameExports': "DIAF - Institut agricole de l'Etat de Fribourg"},
#  {'DisplayName': 'Aeby-Barrat Eléonore',
#   'Email': 'eleonore.aeby-barrat@fr.oai.ch',
#   'FirstName': 'Eléonore',
#   'Id': 1895,
#   'LastName': 'Aeby-Barrat',
#   'PhoneNumber': '+41 26 305 52 12',
#   'PublicationEnd': '/Date(253402210800000)/',
#   'PublicationStart': '/Date(1533247200000)/',
#   'PublicationTarget': '1,0',
#   'Roles': [{'DirectionName': 'Direction de la santé et des affaires sociales',
#     'Email': 'eleonore.aeby-barrat@fr.oai.ch',
#     'Id': 2042,
#     'PhoneNumber': '+41 26 305 52 12',
#     'RoleName': 'Cheffe de section juridique',
#     'TitleName': None,
#     'UnitFullName': 'DSAS - Etablissement cantonal des assurances sociales',
#     'UnitId': 220,
#     'RoleDenominationId': 1788,
#     'UnitName': "Office cantonal de l'assurance-invalidité",
#     'Position': 0,
#     'PublicationStart': '/Date(1533247200000)/',
#     'PublicationEnd': '/Date(253402210800000)/',
#     'PublicationTarget': '1,0',
#     'WebDispatchingType': 1,
#     'UnitFullPath': None,
#     'UnitPath': None}],
#   'RolesDisplay': 'Cheffe de section juridique',
#   'UnitsDisplay': 'DSAS - Etablissement cantonal des assurances sociales',
#   'UnitsExports': "Office cantonal de l'assurance-invalidité",
#   'UnitsFullNameExports': 'DSAS - Etablissement cantonal des assurances sociales'},
#  {'DisplayName': 'Aellen-Rey Fabienne',
#   'Email': 'fabienne.aellen-rey@fr.ch',
#   'FirstName': 'Fabienne',
#   'Id': 1767,
#   'LastName': 'Aellen-Rey',
#   'PhoneNumber': '+41 26 305 22 68',
#   'PublicationEnd': '/Date(253402210800000)/',
#   'PublicationStart': '/Date(-2208992400000)/',
#   'PublicationTarget': '1,0',
#   'Roles': [{'DirectionName': "Direction des institutions, de l'agriculture et des forêts",
#     'Email': 'fabienne.aellen-rey@fr.ch',
#     'Id': 1511,
#     'PhoneNumber': '+41 26 305 22 68',
#     'RoleName': 'Collaboratrice administrative',
#     'TitleName': None,
#     'UnitFullName': "DIAF - Service de l'agriculture",
#     'UnitId': 393,
#     'RoleDenominationId': 424,
#     'UnitName': 'Services généraux',
#     'Position': 2,
#     'PublicationStart': '/Date(-2208992400000)/',
#     'PublicationEnd': '/Date(253402210800000)/',
#     'PublicationTarget': '1,0',
#     'WebDispatchingType': 1,
#     'UnitFullPath': None,
#     'UnitPath': None}],
#   'RolesDisplay': 'Collaboratrice administrative',
#   'UnitsDisplay': "DIAF - Service de l'agriculture",
#   'UnitsExports': 'Services généraux',
#   'UnitsFullNameExports': "DIAF - Service de l'agriculture"},
#  {'DisplayName': 'Aerne Myriam',
#   'Email': 'Myriam.Aerne@fr.ch',
#   'FirstName': 'Myriam',
#   'Id': 6987,
#   'LastName': 'Aerne',
#   'PhoneNumber': '',
#   'PublicationEnd': '/Date(4094143200000)/',
#   'PublicationStart': '/Date(1569448800000)/',
#   'PublicationTarget': '1,0',
#   'Roles': [{'DirectionName': "Direction de l'instruction publique, de la culture et du sport",
#     'Email': 'Myriam.Aerne@fr.ch',
#     'Id': 7386,
#     'PhoneNumber': None,
#     'RoleName': "Responsable de l'atelier de reliure et de conservation",
#     'TitleName': None,
#     'UnitFullName': 'DICS - Service de la culture',
#     'UnitId': 163,
#     'RoleDenominationId': 1917,
#     'UnitName': 'Bibliothèque cantonale et universitaire',
#     'Position': 0,
#     'PublicationStart': '/Date(1569448800000)/',
#     'PublicationEnd': '/Date(4094143200000)/',
#     'PublicationTarget': '1,0',
#     'WebDispatchingType': 1,
#     'UnitFullPath': None,
#     'UnitPath': None}],
#   'RolesDisplay': "Responsable de l'atelier de reliure et de conservation",
#   'UnitsDisplay': 'DICS - Service de la culture',
#   'UnitsExports': 'Bibliothèque cantonale et universitaire',
#   'UnitsFullNameExports': 'DICS - Service de la culture'},
#  {'DisplayName': 'Aeschlimann David',
#   'Email': 'david.aeschlimann.sagri@fr.ch',
#   'FirstName': 'David',
#   'Id': 2205,
#   'LastName': 'Aeschlimann',
#   'PhoneNumber': '+41 26 305 23 03',
#   'PublicationEnd': '/Date(253402210800000)/',
#   'PublicationStart': '/Date(-2208992400000)/',
#   'PublicationTarget': '1,0',
#   'Roles': [{'DirectionName': "Direction des institutions, de l'agriculture et des forêts",
#     'Email': 'david.aeschlimann.sagri@fr.ch',
#     'Id': 6587,
#     'PhoneNumber': '+41 26 305 23 03',
#     'RoleName': 'Responsable régional Basse Sarine',
#     'TitleName': None,
#     'UnitFullName': "DIAF - Service de l'agriculture",
#     'UnitId': 395,
#     'RoleDenominationId': 1725,
#     'UnitName': 'Paiements directs',
#     'Position': 2,
#     'PublicationStart': '/Date(1517439600000)/',
#     'PublicationEnd': None,
#     'PublicationTarget': '1,0',
#     'WebDispatchingType': 1,
#     'UnitFullPath': None,
#     'UnitPath': None},
#    {'DirectionName': "Direction des institutions, de l'agriculture et des forêts",
#     'Email': 'david.aeschlimann.sagri@fr.ch',
#     'Id': 2048,
#     'PhoneNumber': '+41 26 305 23 03',
#     'RoleName': 'Chef de section',
#     'TitleName': None,
#     'UnitFullName': "DIAF - Service de l'agriculture",
#     'UnitId': 393,
#     'RoleDenominationId': 259,
#     'UnitName': 'Services généraux',
#     'Position': 1,
#     'PublicationStart': '/Date(-2208992400000)/',
#     'PublicationEnd': '/Date(253402210800000)/',
#     'PublicationTarget': '1,0',
#     'WebDispatchingType': 1,
#     'UnitFullPath': None,
#     'UnitPath': None},
#    {'DirectionName': "Direction des institutions, de l'agriculture et des forêts",
#     'Email': 'david.aeschlimann.sagri@fr.ch',
#     'Id': 2237,
#     'PhoneNumber': '+41 26 305 23 03',
#     'RoleName': 'Conseiller scientifique',
#     'TitleName': None,
#     'UnitFullName': "DIAF - Service de l'agriculture",
#     'UnitId': 397,
#     'RoleDenominationId': 488,
#     'UnitName': 'Promotion des produits, élevage et viticulture',
#     'Position': 2,
#     'PublicationStart': '/Date(-2208992400000)/',
#     'PublicationEnd': '/Date(253402210800000)/',
#     'PublicationTarget': '1,0',
#     'WebDispatchingType': 1,
#     'UnitFullPath': None,
#     'UnitPath': None}],
#   'RolesDisplay': 'Responsable régional Basse Sarine, Chef de section, Conseiller scientifique',
#   'UnitsDisplay': "DIAF - Service de l'agriculture, DIAF - Service de l'agriculture, DIAF - Service de l'agriculture",
#   'UnitsExports': 'Paiements directs, Services généraux, Promotion des produits, élevage et viticulture',
#   'UnitsFullNameExports': "DIAF - Service de l'agriculture, DIAF - Service de l'agriculture, DIAF - Service de l'agriculture"},
#  {'DisplayName': 'Agustoni Clara',
#   'Email': 'clara.agustoni@fr.ch',
#   'FirstName': 'Clara',
#   'Id': 1077,
#   'LastName': 'Agustoni',
#   'PhoneNumber': '+41 26 667 97 96',
#   'PublicationEnd': '/Date(253402210800000)/',
#   'PublicationStart': '/Date(-2208992400000)/',
#   'PublicationTarget': '1,0',
#   'Roles': [{'DirectionName': "Direction de l'instruction publique, de la culture et du sport",
#     'Email': 'clara.agustoni@fr.ch',
#     'Id': 1924,
#     'PhoneNumber': '+41 26 667 97 96',
#     'RoleName': 'Conservatrice',
#     'TitleName': None,
#     'UnitFullName': 'DICS - Service archéologique',
#     'UnitId': 364,
#     'RoleDenominationId': 1381,
#     'UnitName': 'Musée romain de Vallon',
#     'Position': 0,
#     'PublicationStart': '/Date(-2208992400000)/',
#     'PublicationEnd': '/Date(253402210800000)/',
#     'PublicationTarget': '1,0',
#     'WebDispatchingType': 1,
#     'UnitFullPath': None,
#     'UnitPath': None}],
#   'RolesDisplay': 'Conservatrice',
#   'UnitsDisplay': 'DICS - Service archéologique',
#   'UnitsExports': 'Musée romain de Vallon',
#   'UnitsFullNameExports': 'DICS - Service archéologique'},
#  {'DisplayName': 'Ajeti Ismail',
#   'Email': 'Ismail.Ajeti@fr.ch',
#   'FirstName': 'Ismail',
#   'Id': 3416,
#   'LastName': 'Ajeti',
#   'PhoneNumber': '+41 26 305 35 55',
#   'PublicationEnd': '/Date(253402210800000)/',
#   'PublicationStart': '/Date(-2208992400000)/',
#   'PublicationTarget': '1,0',
#   'Roles': [{'DirectionName': 'Direction des finances',
#     'Email': 'Ismail.Ajeti@fr.ch',
#     'Id': 970,
#     'PhoneNumber': '+41 26 305 35 55',
#     'RoleName': 'Adjoint administratif',
#     'TitleName': None,
#     'UnitFullName': 'DFIN - Service du cadastre et de la géomatique',
#     'UnitId': 46,
#     'RoleDenominationId': 8,
#     'UnitName': 'Service du cadastre et de la géomatique',
#     'Position': 0,
#     'PublicationStart': '/Date(-2208992400000)/',
#     'PublicationEnd': '/Date(253402210800000)/',
#     'PublicationTarget': '1,0',
#     'WebDispatchingType': 1,
#     'UnitFullPath': None,
#     'UnitPath': None}],
#   'RolesDisplay': 'Adjoint administratif',
#   'UnitsDisplay': 'DFIN - Service du cadastre et de la géomatique',
#   'UnitsExports': 'Service du cadastre et de la géomatique',
#   'UnitsFullNameExports': 'DFIN - Service du cadastre et de la géomatique'},
#  {'DisplayName': 'Allemann Aude',
#   'Email': 'aude.allemann@fr.ch',
#   'FirstName': 'Aude',
#   'Id': 5101,
#   'LastName': 'Allemann',
#   'PhoneNumber': '+41 26 305 73 66',
#   'PublicationEnd': '/Date(253402210800000)/',
#   'PublicationStart': '/Date(1513897200000)/',
#   'PublicationTarget': '1,0',
#   'Roles': [{'DirectionName': "Direction de l'instruction publique, de la culture et du sport",
#     'Email': 'aude.allemann@fr.ch',
#     'Id': 5427,
#     'PhoneNumber': '+41 26 305 73 66',
#     'RoleName': 'Coordinatrice',
#     'TitleName': None,
#     'UnitFullName': "DICS - Service de l'enseignement obligatoire de langue française",
#     'UnitId': 384,
#     'RoleDenominationId': 1689,
#     'UnitName': 'Coordination des échanges scolaires du Canton de Fribourg',
#     'Position': 0,
#     'PublicationStart': '/Date(1513897200000)/',
#     'PublicationEnd': '/Date(253402210800000)/',
#     'PublicationTarget': '1,0',
#     'WebDispatchingType': 1,
#     'UnitFullPath': None,
#     'UnitPath': None}],
#   'RolesDisplay': 'Coordinatrice',
#   'UnitsDisplay': "DICS - Service de l'enseignement obligatoire de langue française",
#   'UnitsExports': 'Coordination des échanges scolaires du Canton de Fribourg',
#   'UnitsFullNameExports': "DICS - Service de l'enseignement obligatoire de langue française"},
#  {'DisplayName': 'Allemann Aude',
#   'Email': 'aude.allemann@fr.ch',
#   'FirstName': 'Aude',
#   'Id': 5102,
#   'LastName': 'Allemann',
#   'PhoneNumber': '+41 26 305 73 66',
#   'PublicationEnd': '/Date(253402210800000)/',
#   'PublicationStart': '/Date(1513897200000)/',
#   'PublicationTarget': '1,0',
#   'Roles': [{'DirectionName': "Direction de l'instruction publique, de la culture et du sport",
#     'Email': 'aude.allemann@fr.ch',
#     'Id': 5428,
#     'PhoneNumber': '+41 26 305 73 66',
#     'RoleName': 'Coordinatrice',
#     'TitleName': None,
#     'UnitFullName': "DICS - Service de l'enseignement obligatoire de langue allemande",
#     'UnitId': 382,
#     'RoleDenominationId': 1690,
#     'UnitName': 'Coordination des échanges scolaires du Canton de Fribourg',
#     'Position': 0,
#     'PublicationStart': '/Date(1513897200000)/',
#     'PublicationEnd': '/Date(253402210800000)/',
#     'PublicationTarget': '1,0',
#     'WebDispatchingType': 1,
#     'UnitFullPath': None,
#     'UnitPath': None}],
#   'RolesDisplay': 'Coordinatrice',
#   'UnitsDisplay': "DICS - Service de l'enseignement obligatoire de langue allemande",
#   'UnitsExports': 'Coordination des échanges scolaires du Canton de Fribourg',
#   'UnitsFullNameExports': "DICS - Service de l'enseignement obligatoire de langue allemande"},
#  {'DisplayName': 'Allemann Aude',
#   'Email': 'aude.allemann@fr.ch',
#   'FirstName': 'Aude',
#   'Id': 6885,
#   'LastName': 'Allemann',
#   'PhoneNumber': '+41 26 305 73 66',
#   'PublicationEnd': '/Date(253402210800000)/',
#   'PublicationStart': '/Date(-2208992400000)/',
#   'PublicationTarget': '1,0',
#   'Roles': [{'DirectionName': "Direction de l'instruction publique, de la culture et du sport",
#     'Email': 'aude.allemann@fr.ch',
#     'Id': 7282,
#     'PhoneNumber': '+41 26 305 73 66',
#     'RoleName': 'Echanges scolaires',
#     'TitleName': None,
#     'UnitFullName': "DICS - Service de l'enseignement obligatoire de langue française",
#     'UnitId': 473,
#     'RoleDenominationId': 1895,
#     'UnitName': 'Collaborateurs/trices pédagogiques',
#     'Position': 0,
#     'PublicationStart': '/Date(-2208992400000)/',
#     'PublicationEnd': '/Date(253402210800000)/',
#     'PublicationTarget': '1,0',
#     'WebDispatchingType': 1,
#     'UnitFullPath': None,
#     'UnitPath': None}],
#   'RolesDisplay': 'Echanges scolaires',
#   'UnitsDisplay': "DICS - Service de l'enseignement obligatoire de langue française",
#   'UnitsExports': 'Collaborateurs/trices pédagogiques',
#   'UnitsFullNameExports': "DICS - Service de l'enseignement obligatoire de langue française"},
#  {'DisplayName': 'Allemann Vincent',
#   'Email': 'vincent.allemann@fr.ch',
#   'FirstName': 'Vincent',
#   'Id': 3726,
#   'LastName': 'Allemann',
#   'PhoneNumber': '+41 26 305 22 61',
#   'PublicationEnd': '/Date(253402210800000)/',
#   'PublicationStart': '/Date(-2208992400000)/',
#   'PublicationTarget': '1,0',
#   'Roles': [{'DirectionName': "Direction des institutions, de l'agriculture et des forêts",
#     'Email': 'vincent.allemann@fr.ch',
#     'Id': 2182,
#     'PhoneNumber': '+41 26 305 22 61',
#     'RoleName': "Responsable régional Gruyère et Veveyse Sud – Région d'estivage francophone",
#     'TitleName': None,
#     'UnitFullName': "DIAF - Service de l'agriculture",
#     'UnitId': 395,
#     'RoleDenominationId': 1736,
#     'UnitName': 'Paiements directs',
#     'Position': 3,
#     'PublicationStart': '/Date(-2208992400000)/',
#     'PublicationEnd': '/Date(253402210800000)/',
#     'PublicationTarget': '1,0',
#     'WebDispatchingType': 1,
#     'UnitFullPath': None,
#     'UnitPath': None}],
#   'RolesDisplay': "Responsable régional Gruyère et Veveyse Sud – Région d'estivage francophone",
#   'UnitsDisplay': "DIAF - Service de l'agriculture",
#   'UnitsExports': 'Paiements directs',
#   'UnitsFullNameExports': "DIAF - Service de l'agriculture"},
#  {'DisplayName': 'Amschwand Fabian Max Theodor',
#   'Email': 'fabian.amschwand@unifr.ch',
#   'FirstName': 'Fabian Max Theodor',
#   'Id': 3887,
#   'LastName': 'Amschwand',
#   'PhoneNumber': '+41 26 300 70 04',
#   'PublicationEnd': None,
#   'PublicationStart': '/Date(1550012400000)/',
#   'PublicationTarget': '1,0',
#   'Roles': [{'DirectionName': "Direction de l'instruction publique, de la culture et du sport",
#     'Email': 'fabian.amschwand@unifr.ch',
#     'Id': 2412,
#     'PhoneNumber': '+41 26 300 70 04',
#     'RoleName': 'Secrétaire général',
#     'TitleName': None,
#     'UnitFullName': 'DICS - Université',
#     'UnitId': 242,
#     'RoleDenominationId': 1218,
#     'UnitName': 'Rectorat',
#     'Position': 2,
#     'PublicationStart': '/Date(1550012400000)/',
#     'PublicationEnd': None,
#     'PublicationTarget': '1,0',
#     'WebDispatchingType': 1,
#     'UnitFullPath': None,
#     'UnitPath': None}],
#   'RolesDisplay': 'Secrétaire général',
#   'UnitsDisplay': 'DICS - Université',
#   'UnitsExports': 'Rectorat',
#   'UnitsFullNameExports': 'DICS - Université'},
#  {'DisplayName': 'Andenmatten Patrick',
#   'Email': 'patrick.andenmatten@fr.ch',
#   'FirstName': 'Patrick',
#   'Id': 1758,
#   'LastName': 'Andenmatten',
#   'PhoneNumber': '+41 26 305 52 75',
#   'PublicationEnd': '/Date(253402210800000)/',
#   'PublicationStart': '/Date(-2208992400000)/',
#   'PublicationTarget': '1,0',
#   'Roles': [{'DirectionName': 'Direction de la santé et des affaires sociales',
#     'Email': 'patrick.andenmatten@fr.ch',
#     'Id': 1566,
#     'PhoneNumber': '+41 26 305 52 75',
#     'RoleName': 'Conseiller économique, Chef de la section Finances',
#     'TitleName': None,
#     'UnitFullName': 'DSAS - Etablissement cantonal des assurances sociales',
#     'UnitId': 219,
#     'RoleDenominationId': 1889,
#     'UnitName': 'Caisse cantonale de compensation AVS/AI/APG',
#     'Position': 0,
#     'PublicationStart': '/Date(-2208992400000)/',
#     'PublicationEnd': '/Date(253402210800000)/',
#     'PublicationTarget': '1,0',
#     'WebDispatchingType': 1,
#     'UnitFullPath': None,
#     'UnitPath': None}],
#   'RolesDisplay': 'Conseiller économique, Chef de la section Finances',
#   'UnitsDisplay': 'DSAS - Etablissement cantonal des assurances sociales',
#   'UnitsExports': 'Caisse cantonale de compensation AVS/AI/APG',
#   'UnitsFullNameExports': 'DSAS - Etablissement cantonal des assurances sociales'},
#  {'DisplayName': 'Andrey Colette',
#   'Email': 'colette.andrey@fr.ch',
#   'FirstName': 'Colette',
#   'Id': 626,
#   'LastName': 'Andrey',
#   'PhoneNumber': '+41 26 305 58 53',
#   'PublicationEnd': '/Date(253402210800000)/',
#   'PublicationStart': '/Date(-2208992400000)/',
#   'PublicationTarget': '1,0',
#   'Roles': [{'DirectionName': "Direction des institutions, de l'agriculture et des forêts",
#     'Email': 'colette.andrey@fr.ch',
#     'Id': 3893,
#     'PhoneNumber': '+41 26 305 58 53',
#     'RoleName': 'Conseillère en économie familiale',
#     'TitleName': None,
#     'UnitFullName': "DIAF - Institut agricole de l'Etat de Fribourg",
#     'UnitId': 802,
#     'RoleDenominationId': 1623,
#     'UnitName': 'Formation continue en économie familiale',
#     'Position': 0,
#     'PublicationStart': '/Date(-2208992400000)/',
#     'PublicationEnd': '/Date(253402210800000)/',
#     'PublicationTarget': '1,0',
#     'WebDispatchingType': 1,
#     'UnitFullPath': None,
#     'UnitPath': None}],
#   'RolesDisplay': 'Conseillère en économie familiale',
#   'UnitsDisplay': "DIAF - Institut agricole de l'Etat de Fribourg",
#   'UnitsExports': 'Formation continue en économie familiale',
#   'UnitsFullNameExports': "DIAF - Institut agricole de l'Etat de Fribourg"},
#  {'DisplayName': 'Andrey Karin',
#   'Email': '',
#   'FirstName': 'Karin',
#   'Id': 1869,
#   'LastName': 'Andrey',
#   'PhoneNumber': '+41 26 305 22 04',
#   'PublicationEnd': '/Date(253402210800000)/',
#   'PublicationStart': '/Date(-2208992400000)/',
#   'PublicationTarget': '1,0',
#   'Roles': [{'DirectionName': "Direction des institutions, de l'agriculture et des forêts",
#     'Email': '',
#     'Id': 250,
#     'PhoneNumber': '+41 26 305 22 04',
#     'RoleName': 'Traductrice',
#     'TitleName': None,
#     'UnitFullName': 'DIAF - Secrétariat général',
#     'UnitId': 92,
#     'RoleDenominationId': 1313,
#     'UnitName': 'Secrétariat général',
#     'Position': 12,
#     'PublicationStart': '/Date(-2208992400000)/',
#     'PublicationEnd': '/Date(253402210800000)/',
#     'PublicationTarget': '1,0',
#     'WebDispatchingType': 0,
#     'UnitFullPath': None,
#     'UnitPath': None}],
#   'RolesDisplay': 'Traductrice',
#   'UnitsDisplay': 'DIAF - Secrétariat général',
#   'UnitsExports': 'Secrétariat général',
#   'UnitsFullNameExports': 'DIAF - Secrétariat général'},
#  {'DisplayName': 'Andrey Nicole',
#   'Email': 'nicole.andrey@fr.ch',
#   'FirstName': 'Nicole',
#   'Id': 3543,
#   'LastName': 'Andrey',
#   'PhoneNumber': '+41 26 305 23 43',
#   'PublicationEnd': None,
#   'PublicationStart': '/Date(-2208992400000)/',
#   'PublicationTarget': '1,0',
#   'Roles': [{'DirectionName': "Direction des institutions, de l'agriculture et des forêts",
#     'Email': 'nicole.andrey@fr.ch',
#     'Id': 3637,
#     'PhoneNumber': '+41 26 305 23 43',
#     'RoleName': 'Collaboratrice administrative',
#     'TitleName': None,
#     'UnitFullName': 'DIAF - Service des forêts et de la nature',
#     'UnitId': 790,
#     'RoleDenominationId': 424,
#     'UnitName': 'Secteur administration et finances',
#     'Position': 0,
#     'PublicationStart': '/Date(-2208992400000)/',
#     'PublicationEnd': None,
#     'PublicationTarget': '1,0',
#     'WebDispatchingType': 1,
#     'UnitFullPath': None,
#     'UnitPath': None}],
#   'RolesDisplay': 'Collaboratrice administrative',
#   'UnitsDisplay': 'DIAF - Service des forêts et de la nature',
#   'UnitsExports': 'Secteur administration et finances',
#   'UnitsFullNameExports': 'DIAF - Service des forêts et de la nature'},
#  {'DisplayName': 'Andrey Patrik',
#   'Email': 'patrik.andrey@fr.ch',
#   'FirstName': 'Patrik',
#   'Id': 6288,
#   'LastName': 'Andrey',
#   'PhoneNumber': '+41 26 304 16 21',
#   'PublicationEnd': None,
#   'PublicationStart': '/Date(1519858800000)/',
#   'PublicationTarget': '1,0',
#   'Roles': [{'DirectionName': "Direction de l'instruction publique, de la culture et du sport",
#     'Email': 'patrik.andrey@fr.ch',
#     'Id': 6630,
#     'PhoneNumber': '+41 26 304 16 21',
#     'RoleName': 'Gestionnaire',
#     'TitleName': None,
#     'UnitFullName': 'DICS - Service du sport',
#     'UnitId': 974,
#     'RoleDenominationId': 1743,
#     'UnitName': 'Campus Lac Noir',
#     'Position': 1,
#     'PublicationStart': '/Date(1519858800000)/',
#     'PublicationEnd': None,
#     'PublicationTarget': '1,0',
#     'WebDispatchingType': 1,
#     'UnitFullPath': None,
#     'UnitPath': None}],
#   'RolesDisplay': 'Gestionnaire',
#   'UnitsDisplay': 'DICS - Service du sport',
#   'UnitsExports': 'Campus Lac Noir',
#   'UnitsFullNameExports': 'DICS - Service du sport'},
#  {'DisplayName': 'Andric Josip',
#   'Email': '',
#   'FirstName': 'Josip',
#   'Id': 6502,
#   'LastName': 'Andric',
#   'PhoneNumber': '+41 26 305 46 24',
#   'PublicationEnd': '/Date(253402210800000)/',
#   'PublicationStart': '/Date(1535925600000)/',
#   'PublicationTarget': '1,0',
#   'Roles': [{'DirectionName': 'Direction de la santé et des affaires sociales',
#     'Email': '',
#     'Id': 6860,
#     'PhoneNumber': '+41 26 305 46 24',
#     'RoleName': 'Economiste',
#     'TitleName': None,
#     'UnitFullName': 'DSAS - Service de la prévoyance sociale',
#     'UnitId': 221,
#     'RoleDenominationId': 1804,
#     'UnitName': 'Institutions spécialisées',
#     'Position': 0,
#     'PublicationStart': '/Date(1535925600000)/',
#     'PublicationEnd': '/Date(253402210800000)/',
#     'PublicationTarget': '1,0',
#     'WebDispatchingType': 0,
#     'UnitFullPath': None,
#     'UnitPath': None}],
#   'RolesDisplay': 'Economiste',
#   'UnitsDisplay': 'DSAS - Service de la prévoyance sociale',
#   'UnitsExports': 'Institutions spécialisées',
#   'UnitsFullNameExports': 'DSAS - Service de la prévoyance sociale'},
#  {'DisplayName': 'Angéloz Carole',
#   'Email': 'carole.angeloz@fr.ch',
#   'FirstName': 'Carole',
#   'Id': 1537,
#   'LastName': 'Angéloz',
#   'PhoneNumber': '+41 26 305 73 68',
#   'PublicationEnd': '/Date(253402210800000)/',
#   'PublicationStart': '/Date(-2208992400000)/',
#   'PublicationTarget': '1,0',
# ...
#   'UnitsFullNameExports': 'DAEC - Service des ponts et chaussées'},
#  {'DisplayName': 'Monney Maria-Elena',
#   'Email': 'direction.ep.salesvaulruz@fr.educanet2.ch',
#   'FirstName': 'Maria-Elena',
#   'Id': 4090,
#   'LastName': 'Monney',
#   'PhoneNumber': '+41 26 913 04 10',
#   'PublicationEnd': None,
#   'PublicationStart': '/Date(1441922400000)/',
#   'PublicationTarget': '1,0',
#   'Roles': [{'DirectionName': "Direction de l'instruction publique, de la culture et du sport",
#     'Email': 'direction.ep.salesvaulruz@fr.educanet2.ch',
#     'Id': 4332,
#     'PhoneNumber': '+41 26 913 04 10',
#     'RoleName': "Responsable d'établissement",
#     'TitleName': None,
#     'UnitFullName': "DICS - Service de l'enseignement obligatoire de langue française",
#     'UnitId': 875,
#     'RoleDenominationId': 1428,
#     'UnitName': 'EP Sâles, Vaulruz',
#     'Position': 0,
#     'PublicationStart': '/Date(1441922400000)/',
#     'PublicationEnd': None,
#     'PublicationTarget': '1,0',
#     'WebDispatchingType': 1,
#     'UnitFullPath': None,
#     'UnitPath': None}],
#   'RolesDisplay': "Responsable d'établissement",
#   'UnitsDisplay': "DICS - Service de l'enseignement obligatoire de langue française",
#   'UnitsExports': 'EP Sâles, Vaulruz',
#   'UnitsFullNameExports': "DICS - Service de l'enseignement obligatoire de langue française"},
#  {'DisplayName': 'Monney Pierre',
#   'Email': 'pierre.monney@fr.ch',
#   'FirstName': 'Pierre',
#   'Id': 1653,
#   'LastName': 'Monney',
#   'PhoneNumber': '+41 26 305 55 79',
#   'PublicationEnd': '/Date(253402210800000)/',
#   'PublicationStart': '/Date(-2208992400000)/',
#   'PublicationTarget': '0,1',
#   'Roles': [{'DirectionName': "Direction des institutions, de l'agriculture et des forêts",
#     'Email': 'pierre.monney@fr.ch',
#     'Id': 3906,
#     'PhoneNumber': '+41 26 305 55 79',
#     'RoleName': 'Enseignant branches générales',
#     'TitleName': None,
#     'UnitFullName': "DIAF - Institut agricole de l'Etat de Fribourg",
#     'UnitId': 804,
#     'RoleDenominationId': 673,
#     'UnitName': 'Formation en intendance dual',
#     'Position': 0,
#     'PublicationStart': '/Date(-2208992400000)/',
#     'PublicationEnd': '/Date(253402210800000)/',
#     'PublicationTarget': '0,1',
#     'WebDispatchingType': 1,
#     'UnitFullPath': None,
#     'UnitPath': None}],
#   'RolesDisplay': 'Enseignant branches générales',
#   'UnitsDisplay': "DIAF - Institut agricole de l'Etat de Fribourg",
#   'UnitsExports': 'Formation en intendance dual',
#   'UnitsFullNameExports': "DIAF - Institut agricole de l'Etat de Fribourg"},
#  {'DisplayName': 'Monney Regina',
#   'Email': 'regina.monney@fr.ch',
#   'FirstName': 'Regina',
#   'Id': 1777,
#   'LastName': 'Monney',
#   'PhoneNumber': '+41 26 305 23 43',
#   'PublicationEnd': None,
#   'PublicationStart': '/Date(-2208992400000)/',
#   'PublicationTarget': '1,0',
#   'Roles': [{'DirectionName': "Direction des institutions, de l'agriculture et des forêts",
#     'Email': 'regina.monney@fr.ch',
#     'Id': 3640,
#     'PhoneNumber': '+41 26 305 23 43',
#     'RoleName': 'Secrétaire',
#     'TitleName': None,
#     'UnitFullName': 'DIAF - Service des forêts et de la nature',
#     'UnitId': 790,
#     'RoleDenominationId': 1200,
#     'UnitName': 'Secteur administration et finances',
#     'Position': 0,
#     'PublicationStart': '/Date(-2208992400000)/',
#     'PublicationEnd': None,
#     'PublicationTarget': '1,0',
#     'WebDispatchingType': 1,
#     'UnitFullPath': None,
#     'UnitPath': None}],
#   'RolesDisplay': 'Secrétaire',
#   'UnitsDisplay': 'DIAF - Service des forêts et de la nature',
#   'UnitsExports': 'Secteur administration et finances',
#   'UnitsFullNameExports': 'DIAF - Service des forêts et de la nature'},
#  {'DisplayName': 'Monney Sandrine',
#   'Email': '',
#   'FirstName': 'Sandrine',
#   'Id': 2173,
#   'LastName': 'Monney',
#   'PhoneNumber': '+41 26 305 98 00',
#   'PublicationEnd': '/Date(253402210800000)/',
#   'PublicationStart': '/Date(-2208992400000)/',
#   'PublicationTarget': '1,0',
#   'Roles': [{'DirectionName': 'Direction de la santé et des affaires sociales',
#     'Email': '',
#     'Id': 1362,
#     'PhoneNumber': '+41 26 305 98 00',
#     'RoleName': 'Assistante dentaire',
#     'TitleName': None,
#     'UnitFullName': 'DSAS - Service dentaire scolaire',
#     'UnitId': 304,
#     'RoleDenominationId': 146,
#     'UnitName': 'Clinique dentaire de Fribourg',
#     'Position': 2,
#     'PublicationStart': '/Date(-2208992400000)/',
#     'PublicationEnd': '/Date(253402210800000)/',
#     'PublicationTarget': '1,0',
#     'WebDispatchingType': 0,
#     'UnitFullPath': None,
#     'UnitPath': None}],
#   'RolesDisplay': 'Assistante dentaire',
#   'UnitsDisplay': 'DSAS - Service dentaire scolaire',
#   'UnitsExports': 'Clinique dentaire de Fribourg',
#   'UnitsFullNameExports': 'DSAS - Service dentaire scolaire'},
#  {'DisplayName': 'Monnier Jacques',
#   'Email': 'jacques.monnier@fr.ch',
#   'FirstName': 'Jacques',
#   'Id': 1587,
#   'LastName': 'Monnier',
#   'PhoneNumber': '+41 26 305 82 42',
#   'PublicationEnd': '/Date(253402210800000)/',
#   'PublicationStart': '/Date(-2208992400000)/',
#   'PublicationTarget': '1,0',
#   'Roles': [{'DirectionName': "Direction de l'instruction publique, de la culture et du sport",
#     'Email': 'jacques.monnier@fr.ch',
#     'Id': 1617,
#     'PhoneNumber': '+41 26 305 82 42',
#     'RoleName': 'Chef de secteur, époque gallo-romaine',
#     'TitleName': None,
#     'UnitFullName': 'DICS - Service archéologique',
#     'UnitId': 346,
#     'RoleDenominationId': 250,
#     'UnitName': 'Fouilles, recherches et publications',
#     'Position': 3,
#     'PublicationStart': '/Date(-2208992400000)/',
#     'PublicationEnd': '/Date(253402210800000)/',
#     'PublicationTarget': '1,0',
#     'WebDispatchingType': 1,
#     'UnitFullPath': None,
#     'UnitPath': None}],
#   'RolesDisplay': 'Chef de secteur, époque gallo-romaine',
#   'UnitsDisplay': 'DICS - Service archéologique',
#   'UnitsExports': 'Fouilles, recherches et publications',
#   'UnitsFullNameExports': 'DICS - Service archéologique'},
#  {'DisplayName': 'Monpays Christine',
#   'Email': 'direction.ep.granges-paccot@fr.educanet2.ch',
#   'FirstName': 'Christine',
#   'Id': 6419,
#   'LastName': 'Monpays',
#   'PhoneNumber': '+41 26 460 68 41',
#   'PublicationEnd': None,
#   'PublicationStart': '/Date(1441922400000)/',
#   'PublicationTarget': '1,0',
#   'Roles': [{'DirectionName': "Direction de l'instruction publique, de la culture et du sport",
#     'Email': 'direction.ep.granges-paccot@fr.educanet2.ch',
#     'Id': 6772,
#     'PhoneNumber': '+41 26 460 68 41',
#     'RoleName': "Responsable d'établissement",
#     'TitleName': None,
#     'UnitFullName': "DICS - Service de l'enseignement obligatoire de langue française",
#     'UnitId': 848,
#     'RoleDenominationId': 1428,
#     'UnitName': 'EP Granges-Paccot - La Sonnaz',
#     'Position': 0,
#     'PublicationStart': '/Date(1441922400000)/',
#     'PublicationEnd': None,
#     'PublicationTarget': '1,0',
#     'WebDispatchingType': 1,
#     'UnitFullPath': None,
#     'UnitPath': None}],
#   'RolesDisplay': "Responsable d'établissement",
#   'UnitsDisplay': "DICS - Service de l'enseignement obligatoire de langue française",
#   'UnitsExports': 'EP Granges-Paccot - La Sonnaz',
#   'UnitsFullNameExports': "DICS - Service de l'enseignement obligatoire de langue française"},
#  {'DisplayName': 'Monterrubio Leu Cristina',
#   'Email': '',
#   'FirstName': 'Cristina',
#   'Id': 4418,
#   'LastName': 'Monterrubio Leu',
#   'PhoneNumber': '+41 26 305 79 92',
#   'PublicationEnd': None,
#   'PublicationStart': '/Date(1463004000000)/',
#   'PublicationTarget': '1,0',
#   'Roles': [{'DirectionName': 'Direction de la santé et des affaires sociales',
#     'Email': '',
#     'Id': 4697,
#     'PhoneNumber': '+41 26 305 79 92',
#     'RoleName': 'Collaboratrice scientifique',
#     'TitleName': None,
#     'UnitFullName': 'DSAS - Service du médecin cantonal',
#     'UnitId': 483,
#     'RoleDenominationId': 448,
#     'UnitName': 'Secteur collaboration scientifique',
#     'Position': 2,
#     'PublicationStart': '/Date(1463004000000)/',
#     'PublicationEnd': None,
#     'PublicationTarget': '1,0',
#     'WebDispatchingType': 0,
#     'UnitFullPath': None,
#     'UnitPath': None}],
#   'RolesDisplay': 'Collaboratrice scientifique',
#   'UnitsDisplay': 'DSAS - Service du médecin cantonal',
#   'UnitsExports': 'Secteur collaboration scientifique',
#   'UnitsFullNameExports': 'DSAS - Service du médecin cantonal'},
#  {'DisplayName': 'Mooser Coumba',
#   'Email': 'coumba.mooser@fr.ch',
#   'FirstName': 'Coumba',
#   'Id': 6289,
#   'LastName': 'Mooser',
#   'PhoneNumber': '+41 26 304 16 27',
#   'PublicationEnd': None,
#   'PublicationStart': '/Date(1519858800000)/',
#   'PublicationTarget': '1,0',
#   'Roles': [{'DirectionName': "Direction de l'instruction publique, de la culture et du sport",
#     'Email': 'coumba.mooser@fr.ch',
#     'Id': 6631,
#     'PhoneNumber': '+41 26 304 16 27',
#     'RoleName': "Employée d'administration",
#     'TitleName': None,
#     'UnitFullName': 'DICS - Service du sport',
#     'UnitId': 974,
#     'RoleDenominationId': 1593,
#     'UnitName': 'Campus Lac Noir',
#     'Position': 2,
#     'PublicationStart': '/Date(1519858800000)/',
#     'PublicationEnd': None,
#     'PublicationTarget': '1,0',
#     'WebDispatchingType': 1,
#     'UnitFullPath': None,
#     'UnitPath': None}],
#   'RolesDisplay': "Employée d'administration",
#   'UnitsDisplay': 'DICS - Service du sport',
#   'UnitsExports': 'Campus Lac Noir',
#   'UnitsFullNameExports': 'DICS - Service du sport'},
#  {'DisplayName': 'Morand Monique',
#   'Email': 'Monique.Morand@fr.ch',
#   'FirstName': 'Monique',
#   'Id': 829,
#   'LastName': 'Morand',
#   'PhoneNumber': '+41 26 305 36 41',
#   'PublicationEnd': '/Date(253402210800000)/',
#   'PublicationStart': '/Date(-2208992400000)/',
#   'PublicationTarget': '1,0',
#   'Roles': [{'DirectionName': "Direction de l'aménagement, de l'environnement et des constructions",
#     'Email': 'Monique.Morand@fr.ch',
#     'Id': 2469,
#     'PhoneNumber': '+41 26 305 36 41',
#     'RoleName': 'Cheffe de section',
#     'TitleName': None,
#     'UnitFullName': 'DAEC - Service des ponts et chaussées',
#     'UnitId': 690,
#     'RoleDenominationId': 335,
#     'UnitName': 'Ressources humaines',
#     'Position': 1,
#     'PublicationStart': '/Date(-2208992400000)/',
#     'PublicationEnd': '/Date(253402210800000)/',
#     'PublicationTarget': '1,0',
#     'WebDispatchingType': 1,
#     'UnitFullPath': None,
#     'UnitPath': None},
#    {'DirectionName': "Direction de l'aménagement, de l'environnement et des constructions",
#     'Email': 'Monique.Morand@fr.ch',
#     'Id': 1626,
#     'PhoneNumber': '+41 26 305 36 41',
#     'RoleName': 'Cheffe de section',
#     'TitleName': None,
#     'UnitFullName': 'DAEC - Service des ponts et chaussées',
#     'UnitId': 210,
#     'RoleDenominationId': 335,
#     'UnitName': 'Administration (Adm)',
#     'Position': 1,
#     'PublicationStart': '/Date(-2208992400000)/',
#     'PublicationEnd': '/Date(253402210800000)/',
#     'PublicationTarget': '1,0',
#     'WebDispatchingType': 1,
#     'UnitFullPath': None,
#     'UnitPath': None}],
#   'RolesDisplay': 'Cheffe de section, Cheffe de section',
#   'UnitsDisplay': 'DAEC - Service des ponts et chaussées, DAEC - Service des ponts et chaussées',
#   'UnitsExports': 'Ressources humaines, Administration (Adm)',
#   'UnitsFullNameExports': 'DAEC - Service des ponts et chaussées, DAEC - Service des ponts et chaussées'},
#  {'DisplayName': 'Morel Bernard',
#   'Email': 'bernard.morel@fr.ch',
#   'FirstName': 'Bernard',
#   'Id': 1811,
#   'LastName': 'Morel',
#   'PhoneNumber': '+41 26 305 55 10',
#   'PublicationEnd': '/Date(253402210800000)/',
#   'PublicationStart': '/Date(-2208992400000)/',
#   'PublicationTarget': '1,0',
#   'Roles': [{'DirectionName': "Direction des institutions, de l'agriculture et des forêts",
#     'Email': 'bernard.morel@fr.ch',
#     'Id': 2552,
#     'PhoneNumber': '+41 26 305 55 10',
#     'RoleName': 'Chef comptable',
#     'TitleName': None,
#     'UnitFullName': "DIAF - Institut agricole de l'Etat de Fribourg",
#     'UnitId': 514,
#     'RoleDenominationId': 194,
#     'UnitName': 'Comptabilité',
#     'Position': 1,
#     'PublicationStart': '/Date(-2208992400000)/',
#     'PublicationEnd': '/Date(253402210800000)/',
#     'PublicationTarget': '1,0',
#     'WebDispatchingType': 1,
#     'UnitFullPath': None,
#     'UnitPath': None}],
#   'RolesDisplay': 'Chef comptable',
#   'UnitsDisplay': "DIAF - Institut agricole de l'Etat de Fribourg",
#   'UnitsExports': 'Comptabilité',
#   'UnitsFullNameExports': "DIAF - Institut agricole de l'Etat de Fribourg"},
#  {'DisplayName': 'Morel Fanny-Iona',
#   'Email': 'fanny-iona.morel@fr.ch',
#   'FirstName': 'Fanny-Iona',
#   'Id': 2968,
#   'LastName': 'Morel',
#   'PhoneNumber': '+41 26 305 12 96',
#   'PublicationEnd': '/Date(253402210800000)/',
#   'PublicationStart': '/Date(-2208992400000)/',
#   'PublicationTarget': '1,0',
#   'Roles': [{'DirectionName': "Direction de l'instruction publique, de la culture et du sport",
#     'Email': 'fanny-iona.morel@fr.ch',
#     'Id': 3689,
#     'PhoneNumber': '+41 26 305 12 96',
#     'RoleName': 'Documentation, archivage',
#     'TitleName': None,
#     'UnitFullName': 'DICS - Service des biens culturels',
#     'UnitId': 253,
#     'RoleDenominationId': 610,
#     'UnitName': 'Recensement des biens culturels',
#     'Position': 0,
#     'PublicationStart': '/Date(-2208992400000)/',
#     'PublicationEnd': '/Date(253402210800000)/',
#     'PublicationTarget': '1,0',
#     'WebDispatchingType': 1,
#     'UnitFullPath': None,
#     'UnitPath': None}],
#   'RolesDisplay': 'Documentation, archivage',
#   'UnitsDisplay': 'DICS - Service des biens culturels',
#   'UnitsExports': 'Recensement des biens culturels',
#   'UnitsFullNameExports': 'DICS - Service des biens culturels'},
#  {'DisplayName': 'Morel Géraldine',
#   'Email': 'geraldine.morel@ocms-fribourg.ch',
#   'FirstName': 'Géraldine',
#   'Id': 1512,
#   'LastName': 'Morel',
#   'PhoneNumber': '+41 26 305 13 98',
#   'PublicationEnd': '/Date(253402210800000)/',
#   'PublicationStart': '/Date(-2208992400000)/',
#   'PublicationTarget': '1,0',
#   'Roles': [{'DirectionName': "Direction de l'instruction publique, de la culture et du sport",
#     'Email': 'geraldine.morel@ocms-fribourg.ch',
#     'Id': 484,
#     'PhoneNumber': '+41 26 305 13 98',
#     'RoleName': 'Moyens d´enseignement et fournitures scolaires',
#     'TitleName': None,
#     'UnitFullName': 'DICS - Office cantonal du matériel scolaire',
#     'UnitId': 50,
#     'RoleDenominationId': 941,
#     'UnitName': 'Office cantonal du matériel scolaire',
#     'Position': 5,
#     'PublicationStart': '/Date(-2208992400000)/',
#     'PublicationEnd': '/Date(253402210800000)/',
#     'PublicationTarget': '1,0',
#     'WebDispatchingType': 1,
#     'UnitFullPath': None,
#     'UnitPath': None}],
#   'RolesDisplay': 'Moyens d´enseignement et fournitures scolaires',
#   'UnitsDisplay': 'DICS - Office cantonal du matériel scolaire',
#   'UnitsExports': 'Office cantonal du matériel scolaire',
#   'UnitsFullNameExports': 'DICS - Office cantonal du matériel scolaire'},
#  {'DisplayName': 'Morel Géraldine',
#   'Email': 'geraldine.morel@fr.ch',
#   'FirstName': 'Géraldine',
#   'Id': 4296,
#   'LastName': 'Morel',
#   'PhoneNumber': '+41 26 305 23 73',
#   'PublicationEnd': None,
#   'PublicationStart': '/Date(1452121200000)/',
#   'PublicationTarget': '1,0',
#   'Roles': [{'DirectionName': 'Direction de la santé et des affaires sociales',
#     'Email': 'geraldine.morel@fr.ch',
#     'Id': 4562,
#     'PhoneNumber': '+41 26 305 23 73',
#     'RoleName': 'Collaboratrice scientifique universitaire',
#     'TitleName': None,
#     'UnitFullName': "DSAS - Bureau de l'égalité hommes-femmes et de la famille",
#     'UnitId': 64,
#     'RoleDenominationId': 451,
#     'UnitName': "Bureau de l'égalité hommes-femmes et de la famille",
#     'Position': 0,
#     'PublicationStart': '/Date(1452121200000)/',
#     'PublicationEnd': None,
#     'PublicationTarget': '1,0',
#     'WebDispatchingType': 1,
#     'UnitFullPath': None,
#     'UnitPath': None}],
#   'RolesDisplay': 'Collaboratrice scientifique universitaire',
#   'UnitsDisplay': "DSAS - Bureau de l'égalité hommes-femmes et de la famille",
#   'UnitsExports': "Bureau de l'égalité hommes-femmes et de la famille",
#   'UnitsFullNameExports': "DSAS - Bureau de l'égalité hommes-femmes et de la famille"},
#  ...]

# %%
# Zugreifen auf das zweite Element von 'Data' <- Das zweite, weil der Erste Eintrag von den folgenden abweicht
response_as_json['Data'][1]
# Out:
# {'DisplayName': 'Abeztout Abderrahim',
#  'Email': 'abderrahim.abeztout@fr.ch',
#  'FirstName': 'Abderrahim',
#  'Id': 4423,
#  'LastName': 'Abeztout',
#  'PhoneNumber': '+41 26 305 37 97',
#  'PublicationEnd': None,
#  'PublicationStart': '/Date(1463608800000)/',
#  'PublicationTarget': '1,0',
#  'Roles': [{'DirectionName': "Direction de l'aménagement, de l'environnement et des constructions",
#    'Email': 'abderrahim.abeztout@fr.ch',
#    'Id': 4703,
#    'PhoneNumber': '+41 26 305 37 97',
#    'RoleName': 'Architecte',
#    'TitleName': None,
#    'UnitFullName': 'DAEC - Service des bâtiments',
#    'UnitId': 235,
#    'RoleDenominationId': 121,
#    'UnitName': 'Section technique',
#    'Position': 0,
#    'PublicationStart': '/Date(1463608800000)/',
#    'PublicationEnd': None,
#    'PublicationTarget': '1,0',
#    'WebDispatchingType': 1,
#    'UnitFullPath': None,
#    'UnitPath': None}],
#  'RolesDisplay': 'Architecte',
#  'UnitsDisplay': 'DAEC - Service des bâtiments',
#  'UnitsExports': 'Section technique',
#  'UnitsFullNameExports': 'DAEC - Service des bâtiments'}

# %% [markdown]
# So schön. Aus dem baue ich jetzt eine For-Loop mit dictionary. <- Aus diesen Zeilen besteht danch mein DataFrame.

# %%
# For Loop

verzeichnis = []

for person in response_as_json['Data']:
    thisperson = {}
    thisperson['1 Name'] = person['DisplayName'] if not person['DisplayName'] is None else ''
    thisperson['2 ID'] = person['Id'] if not person['Id'] is None else ''
    thisperson['3 Email'] = person['Email'] if not person['Email'] is None else ''
    thisperson['4 Direktion'] = person['Roles'][0]['DirectionName'] if not person['Roles'] is None and len(person['Roles']) > 0 else ''
    thisperson['5 Sektion'] = person['UnitsDisplay'] if not person['UnitsDisplay'] is None else ''
    thisperson['6 Abteilung'] = person['UnitsExports'] if not person['UnitsExports'] is None else ''
    thisperson['7 Funktion'] = person['RolesDisplay'] if not person['RolesDisplay'] is None else ''
    
    verzeichnis.append(thisperson)
    
pd.DataFrame(verzeichnis)

# %% [markdown]
# ### Herr / Frau Zuordnung

# %% [markdown]
# Jetzt wird es erst richtig interessant: in meine Post-Request-Abfrage baue ich eine Abfrage mit BeautifulSoup ein.

# %%
# 1 Weil das alles sonst zu kompliziert ist, scrape ich erst einmal eine Sub-Page.


sub_url = 'http://appl.fr.ch/ate/Person/Detail/1544'

r = requests.get(sub_url)
soup = BeautifulSoup(r.content, 'lxml')

legend = soup.find_all('legend')[0].text

print(legend)
print(type(legend))

legend  # <- Das ist noch nicht schön. Weil im Dictionary brauche ich ja das Element an sich, nicht 
# was sich daraus printen lässt.

# %%
# 2 Das span-Tag tilgen:

legende = soup.find_all('legend')[0]

for span in legende('span'):
    span.decompose()

legende.text
# Bizli schöner

# %%
# Daraus eine Funktion bauen: 


sub_url = 'http://appl.fr.ch/ate/Person/Detail/1544'

def get_gender_attr (sub_url):
    r = requests.get(sub_url)
    soup = BeautifulSoup(r.content, 'lxml')
    legend = soup.find_all('legend')[0]
    for span in legende('span'):
        span.decompose()

# %% [markdown]
# ## Synthesis: Scraper mit Post-Request & BeautifulSoup:

# %% [markdown]
# Weil das oben so toll geklappt hat kopiere ich den Code von oben hierhin, damit ich oben nichts kaputt mache

# %%
# Sachen vorbereiten

data = {'page': '1',
        'pageSize': '50',   #'1593',  <- Für vollständigen Datensatz
        'mainSearchText': '*'
       }

cookies = {'ASP.NET_SessionId': 'nt4pmcae3gesz4kk41h2lang'}

url = 'http://appl.fr.ch/ate/Person/FilterGridWithIds'
sub_base = 'http://appl.fr.ch/ate/Person/Detail/'


# Zugriff auf die Webseite

response = requests.post(url, data=data, cookies=cookies)
response_as_json = json.loads(response.text)

# For Loop

verzeichnis = []

for person in response_as_json['Data']:
    thisperson = {}
    thisperson['1 Name'] = person['DisplayName'] if not person['DisplayName'] is None else ''
    thisperson['2 ID'] = person['Id'] if not person['Id'] is None else ''
    thisperson['3 Email'] = person['Email'] if not person['Email'] is None else ''
    thisperson['4 Direktion'] = person['Roles'][0]['DirectionName'] if not person['Roles'] is None and len(person['Roles']) > 0 else ''
    thisperson['5 Sektion'] = person['UnitsDisplay'] if not person['UnitsDisplay'] is None else ''
    thisperson['6 Abteilung'] = person['UnitsExports'] if not person['UnitsExports'] is None else ''
    thisperson['7 Funktion'] = person['RolesDisplay'] if not person['RolesDisplay'] is None else ''
    
    # Uuund das Sub-Page Aufrufen.
    sub_url = sub_base + str(person['Id'])
    
    r = requests.get(sub_url)
    soup = BeautifulSoup(r.content, 'lxml')
    legend = soup.find_all('legend')[0]
    for span in legend('span'):
        span.decompose()
    
    thisperson['8 Gender'] = legend
    
    verzeichnis.append(thisperson)
    
pd.DataFrame(verzeichnis)
# Out:
#                           1 Name  2 ID                             3 Email  \
# 0                        --- ---    96
# 1            Abeztout Abderrahim  4423           abderrahim.abeztout@fr.ch
# 2           Ackermann Christophe  1544          christophe.ackermann@fr.ch
# 3                  Ackermann Urs  3557                 urs.ackermann@fr.ch
# 4                    Adam Samuel  2628
# 5               Aebischer Adrian  1289              adrian.aebischer@fr.ch
# 6            Aebischer Christoph  1580
# 7              Aebischer Fernand    36                       Non renseigné
# 8              Aebischer Florent  3328             florent.aebischer@fr.ch
# 9            Aebischer Jean-Marc  1038
# 10           Aebischer Jean-Marc  4664           jean-marc.aebischer@fr.ch
# 11          Aebischer Jean-Marie   609      jean-marie.aebischer@fr.oai.ch
# 12              Aebischer Maryse   755
# 13              Aebischer Mélody  4438              melody.aebischer@fr.ch
# 14             Aebischer Nicolas  1035  nicolas.aebischer@ocms-fribourg.ch
# 15             Aebischer Nicolas  1401             nicolas.aebischer@fr.ch
# 16      Aebischer-Aeby Elisabeth  3119                aebischerel@edufr.ch
# 17      Aebischer-Piller Christa   895             christa.aebischer@fr.ch
# 18                Aeby Annabelle  1853
# 19                 Aeby Frédéric  6508
# 20                   Aeby Pascal  1205                   pascal.aeby@fr.ch
# 21                   Aeby Pierre  1106                   pierre.aeby@fr.ch
# 22          Aeby-Barrat Eléonore  1895      eleonore.aeby-barrat@fr.oai.ch
# 23           Aellen-Rey Fabienne  1767           fabienne.aellen-rey@fr.ch
# 24                  Aerne Myriam  6987                  Myriam.Aerne@fr.ch
# 25             Aeschlimann David  2205       david.aeschlimann.sagri@fr.ch
# 26                Agustoni Clara  1077                clara.agustoni@fr.ch
# 27                  Ajeti Ismail  3416                  Ismail.Ajeti@fr.ch
# 28                 Allemann Aude  5101                 aude.allemann@fr.ch
# 29                 Allemann Aude  5102                 aude.allemann@fr.ch
# 30                 Allemann Aude  6885                 aude.allemann@fr.ch
# 31              Allemann Vincent  3726              vincent.allemann@fr.ch
# 32  Amschwand Fabian Max Theodor  3887           fabian.amschwand@unifr.ch
# 33           Andenmatten Patrick  1758           patrick.andenmatten@fr.ch
# 34                Andrey Colette   626                colette.andrey@fr.ch
# 35                  Andrey Karin  1869
# 36                 Andrey Nicole  3543                 nicole.andrey@fr.ch
# 37                 Andrey Patrik  6288                 patrik.andrey@fr.ch
# 38                  Andric Josip  6502
# 39                Angéloz Carole  1537                carole.angeloz@fr.ch
# 40                 Angéloz Cindy  6412                 cindy.angeloz@fr.ch
# 41         Angéloz Marie-Bernard  4137                  angelozmb@edufr.ch
# 42              Angéloz Philippe  2081              philippe.angeloz@fr.ch
# 43                Anliker Tobias  2694                tobias.anliker@fr.ch
# 44  Antoniazza-Torche Christiane  1281
# 45               Antonin Maxence  3926                   antoninm@edufr.ch
# 46                   Apprenti-e   6334
# 47               Arnaud Frédéric  3712               frederic.arnaud@fr.ch
# 48                  Arrighi Marc  1755        marc.arrighi@fr.educanet2.ch
# 49                  Arrighi Marc  4483                  marc.arrighi@fr.ch
#
#                                           4 Direktion  \
# 0                                 Chancellerie d'Etat
# 1   Direction de l'aménagement, de l'environnement...
# 2                              Direction des finances
# 3   Direction des institutions, de l'agriculture e...
# 4      Direction de la santé et des affaires sociales
# 5   Direction des institutions, de l'agriculture e...
# 6              Direction de l'économie et de l'emploi
# 7                                              Divers
# 8              Direction de l'économie et de l'emploi
# 9   Direction de l'instruction publique, de la cul...
# 10  Direction de l'instruction publique, de la cul...
# 11     Direction de la santé et des affaires sociales
# 12     Direction de la santé et des affaires sociales
# 13  Direction des institutions, de l'agriculture e...
# 14  Direction de l'instruction publique, de la cul...
# 15  Direction de l'aménagement, de l'environnement...
# 16  Direction de l'instruction publique, de la cul...
# 17  Direction de l'instruction publique, de la cul...
# 18     Direction de la santé et des affaires sociales
# 19  Direction de l'instruction publique, de la cul...
# 20                             Direction des finances
# 21  Direction des institutions, de l'agriculture e...
# 22     Direction de la santé et des affaires sociales
# 23  Direction des institutions, de l'agriculture e...
# 24  Direction de l'instruction publique, de la cul...
# 25  Direction des institutions, de l'agriculture e...
# 26  Direction de l'instruction publique, de la cul...
# 27                             Direction des finances
# 28  Direction de l'instruction publique, de la cul...
# 29  Direction de l'instruction publique, de la cul...
# 30  Direction de l'instruction publique, de la cul...
# 31  Direction des institutions, de l'agriculture e...
# 32  Direction de l'instruction publique, de la cul...
# 33     Direction de la santé et des affaires sociales
# 34  Direction des institutions, de l'agriculture e...
# 35  Direction des institutions, de l'agriculture e...
# 36  Direction des institutions, de l'agriculture e...
# 37  Direction de l'instruction publique, de la cul...
# 38     Direction de la santé et des affaires sociales
# 39  Direction de l'instruction publique, de la cul...
# 40  Direction de l'instruction publique, de la cul...
# 41  Direction de l'instruction publique, de la cul...
# 42  Direction de l'aménagement, de l'environnement...
# 43  Direction des institutions, de l'agriculture e...
# 44  Direction de l'instruction publique, de la cul...
# 45  Direction de l'instruction publique, de la cul...
# 46  Direction de l'instruction publique, de la cul...
# 47  Direction de l'instruction publique, de la cul...
# 48  Direction de l'instruction publique, de la cul...
# 49  Direction de l'instruction publique, de la cul...
#
#                                             5 Sektion  \
# 0                            CHA - Archives de l'Etat
# 1                        DAEC - Service des bâtiments
# 2                      DFIN - Inspection des finances
# 3   DIAF - Service des affaires institutionnelles,...
# 4                  DSAS - Service du médecin cantonal
# 5           DIAF - Service des forêts et de la nature
# 6    DEE - Promotion économique du canton de Fribourg
# 7   DIV - Groupement polysportif de l'Etat de Frib...
# 8               DEE - Service du registre du commerce
# 9                             DICS - Service du sport
# 10  DICS - Service de l'enseignement obligatoire d...
# 11  DSAS - Etablissement cantonal des assurances s...
# 12            DSAS - Service de la prévoyance sociale
# 13     DIAF - Institut agricole de l'Etat de Fribourg
# 14        DICS - Office cantonal du matériel scolaire
# 15                  DAEC - Service de l'environnement
# 16  DICS - Service de l'enseignement secondaire du...
# 17  DICS - Service de l'enseignement obligatoire d...
# 18                 DSAS - Service du médecin cantonal
# 19  DICS - Service de l'enseignement obligatoire d...
# 20                         DFIN - Secrétariat général
# 21     DIAF - Institut agricole de l'Etat de Fribourg
# 22  DSAS - Etablissement cantonal des assurances s...
# 23                    DIAF - Service de l'agriculture
# 24                       DICS - Service de la culture
# 25  DIAF - Service de l'agriculture, DIAF - Servic...
# 26                       DICS - Service archéologique
# 27     DFIN - Service du cadastre et de la géomatique
# 28  DICS - Service de l'enseignement obligatoire d...
# 29  DICS - Service de l'enseignement obligatoire d...
# 30  DICS - Service de l'enseignement obligatoire d...
# 31                    DIAF - Service de l'agriculture
# 32                                  DICS - Université
# 33  DSAS - Etablissement cantonal des assurances s...
# 34     DIAF - Institut agricole de l'Etat de Fribourg
# 35                         DIAF - Secrétariat général
# 36          DIAF - Service des forêts et de la nature
# 37                            DICS - Service du sport
# 38            DSAS - Service de la prévoyance sociale
# 39  DICS - Service de l'enseignement obligatoire d...
# 40  DICS - Service de l'enseignement obligatoire d...
# 41  DICS - Service de l'enseignement obligatoire d...
# 42                       DAEC - Service des bâtiments
# 43     DIAF - Institut agricole de l'Etat de Fribourg
# 44                       DICS - Service de la culture
# 45  DICS - Service de l'enseignement secondaire du...
# 46        DICS - Office cantonal du matériel scolaire
# 47                 DICS - Service des biens culturels
# 48  DICS - Service de l'enseignement obligatoire d...
# 49  DICS - Service de l'enseignement obligatoire d...
#
#                                           6 Abteilung  \
# 0                                  Archives de l'Etat
# 1                                   Section technique
# 2                             Inspection des finances
# 3     Secteur des institutions et affaires juridiques
# 4                         Service du médecin cantonal
# 5        Secteur faune, biodiversité, chasse et pêche
# 6          Promotion économique du canton de Fribourg
# 7                                         Disciplines
# 8                     Service du registre du commerce
# 9                                    Service du sport
# 10                 Collaborateurs/trices pédagogiques
# 11          Office cantonal de l'assurance-invalidité
# 12                   Service de la prévoyance sociale
# 13                                     Administration
# 14               Office cantonal du matériel scolaire
# 15                  Section laboratoire et substances
# 16                                 Collège de Gambach
# 17  Collaboration pédagogique, Inspection des écol...
# 18                                  Secteur infirmier
# 19                          Collaboration pédagogique
# 20                                Secrétariat général
# 21                           Production végétale (PV)
# 22          Office cantonal de l'assurance-invalidité
# 23                                  Services généraux
# 24            Bibliothèque cantonale et universitaire
# 25  Paiements directs, Services généraux, Promotio...
# 26                             Musée romain de Vallon
# 27            Service du cadastre et de la géomatique
# 28  Coordination des échanges scolaires du Canton ...
# 29  Coordination des échanges scolaires du Canton ...
# 30                 Collaborateurs/trices pédagogiques
# 31                                  Paiements directs
# 32                                           Rectorat
# 33        Caisse cantonale de compensation AVS/AI/APG
# 34           Formation continue en économie familiale
# 35                                Secrétariat général
# 36                 Secteur administration et finances
# 37                                    Campus Lac Noir
# 38                          Institutions spécialisées
# 39                               Inspectorat scolaire
# 40                 Collaborateurs/trices pédagogiques
# 41                 Collaborateurs/trices pédagogiques
# 42                                  Section technique
# 43  Stratégie d'entreprise & projets collectifs (SEP)
# 44                                      Conservatoire
# 45                                          Direction
# 46               Office cantonal du matériel scolaire
# 47                    Recensement des biens culturels
# 48    Classes relais Fribourg, Classe relais Fribourg
# 49  Soutien aux établissements scolaires dans la p...
#
#                                            7 Funktion  \
# 0                                         Secrétariat
# 1                                          Architecte
# 2                     Adjoint de la cheffe de service
# 3               Collaborateur administratif supérieur
# 4                          Adjoint du chef de service
# 5   Collaborateur scientifique, biodiversité en forêt
# 6                                     Chef de projets
# 7                                             Quilles
# 8                              Secrétariat et guichet
# 9                           Collaborateur pédagogique
# 10                Corps et mouvement, cycles 1, 2 & 3
# 11                     Chef section Services généraux
# 12                                  Cheffe de service
# 13                                     Spécialiste RH
# 14                             Adjoint à la direction
# 15  Chef du secteur contrôle des eaux et produits ...
# 16                                         Proviseure
# 17  Collaboratrice pédagogique; promotion des lang...
# 18                                         Infirmière
# 19                          Collaborateur pédagogique
# 20                                 Secrétaire général
# 21                    Responsable production végétale
# 22                        Cheffe de section juridique
# 23                      Collaboratrice administrative
# 24  Responsable de l'atelier de reliure et de cons...
# 25  Responsable régional Basse Sarine, Chef de sec...
# 26                                      Conservatrice
# 27                              Adjoint administratif
# 28                                      Coordinatrice
# 29                                      Coordinatrice
# 30                                 Echanges scolaires
# 31  Responsable régional Gruyère et Veveyse Sud – ...
# 32                                 Secrétaire général
# 33  Conseiller économique, Chef de la section Fina...
# 34                  Conseillère en économie familiale
# 35                                        Traductrice
# 36                      Collaboratrice administrative
# 37                                       Gestionnaire
# 38                                         Economiste
# 39                 Inspectrice du 8ème arrondissement
# 40                                   Français cycle 1
# 41                      Ethique et culture religieuse
# 42                            Collaborateur technique
# 43                                Conseiller agricole
# 44                                     Bibliothécaire
# 45                                          Proviseur
# 46                 Arrivage, stockage et distribution
# 47    Responsable PBC, IVS, rédacteur de l’inventaire
# 48  Directeur des mesures SED, Directeur des mesur...
# 49                          Directeur des mesures SED
#
#                                              8 Gender
# 0             <legend>
# Madame
# ---
# ---    </legend>
# 1   <legend>
# Monsieur
# Abderrahim
# Abeztout    </...
# 2   <legend>
# Monsieur
# Christophe
# Ackermann    <...
# 3     <legend>
# Monsieur
# Urs
# Ackermann    </legend>
# 4       <legend>
# Monsieur
# Samuel
# Adam    </legend>
# 5   <legend>
# Monsieur
# Adrian
# Aebischer    </leg...
# 6   <legend>
# Monsieur
# Christoph
# Aebischer    </...
# 7   <legend>
# Monsieur
# Fernand
# Aebischer    </le...
# 8   <legend>
# Monsieur
# Florent
# Aebischer    </le...
# 9   <legend>
# Monsieur
# Jean-Marc
# Aebischer    </...
# 10  <legend>
# Monsieur
# Jean-Marc
# Aebischer    </...
# 11  <legend>
# Monsieur
# Jean-Marie
# Aebischer    <...
# 12   <legend>
# Madame
# Maryse
# Aebischer    </legend>
# 13   <legend>
# Madame
# Mélody
# Aebischer    </legend>
# 14  <legend>
# Monsieur
# Nicolas
# Aebischer    </le...
# 15  <legend>
# Monsieur
# Nicolas
# Aebischer    </le...
# 16  <legend>
# Madame
# Elisabeth
# Aebischer-Aeby   ...
# 17  <legend>
# Madame
# Christa
# Aebischer-Piller   ...
# 18     <legend>
# Madame
# Annabelle
# Aeby    </legend>
# 19    <legend>
# Monsieur
# Frédéric
# Aeby    </legend>
# 20      <legend>
# Monsieur
# Pascal
# Aeby    </legend>
# 21      <legend>
# Monsieur
# Pierre
# Aeby    </legend>
# 22  <legend>
# Madame
# Eléonore
# Aeby-Barrat    </l...
# 23  <legend>
# Madame
# Fabienne
# Aellen-Rey    </le...
# 24       <legend>
# Madame
# Myriam
# Aerne    </legend>
# 25  <legend>
# Monsieur
# David
# Aeschlimann    </le...
# 26     <legend>
# Madame
# Clara
# Agustoni    </legend>
# 27     <legend>
# Monsieur
# Ismail
# Ajeti    </legend>
# 28      <legend>
# Madame
# Aude
# Allemann    </legend>
# 29      <legend>
# Madame
# Aude
# Allemann    </legend>
# 30      <legend>
# Madame
# Aude
# Allemann    </legend>
# 31  <legend>
# Monsieur
# Vincent
# Allemann    </leg...
# 32  <legend>
# Monsieur
# Fabian Max Theodor
# Amschw...
# 33  <legend>
# Monsieur
# Patrick
# Andenmatten    </...
# 34     <legend>
# Madame
# Colette
# Andrey    </legend>
# 35       <legend>
# Madame
# Karin
# Andrey    </legend>
# 36      <legend>
# Madame
# Nicole
# Andrey    </legend>
# 37    <legend>
# Monsieur
# Patrik
# Andrey    </legend>
# 38     <legend>
# Monsieur
# Josip
# Andric    </legend>
# 39     <legend>
# Madame
# Carole
# Angéloz    </legend>
# 40      <legend>
# Madame
# Cindy
# Angéloz    </legend>
# 41  <legend>
# Madame
# Marie-Bernard
# Angéloz    </...
# 42  <legend>
# Monsieur
# Philippe
# Angéloz    </leg...
# 43   <legend>
# Monsieur
# Tobias
# Anliker    </legend>
# 44  <legend>
# Madame
# Christiane
# Antoniazza-Torch...
# 45  <legend>
# Monsieur
# Maxence
# Antonin    </legend>
# 46                  <legend>
# Apprenti-e    </legend>
# 47  <legend>
# Monsieur
# Frédéric
# Arnaud    </legend>
# 48     <legend>
# Monsieur
# Marc
# Arrighi    </legend>
# 49     <legend>
# Monsieur
# Marc
# Arrighi    </legend>

# %%
pd.DataFrame(verzeichnis).to_csv('Verzeichnis_part.csv')
