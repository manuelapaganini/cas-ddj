# %% [markdown]
# # Pandas Shortlist

# %%
import pandas as pd

# %%
# mit tab kann der Pfad vervollständigt werden. 

path = "dataprojects/powerplants/global_power_plant_database.csv" 

# df steht für DataFrame
df = pd.read_csv(path)

# %%
#df.head? <- Mit Fragezeichen werden die Eigenschaften 
# einer Funktion angezigt.

# %%
df.head(5)
# Out:
#   country country_long                                               name  \
# 0     AFG  Afghanistan       Kajaki Hydroelectric Power Plant Afghanistan
# 1     AFG  Afghanistan      Mahipar Hydroelectric Power Plant Afghanistan
# 2     AFG  Afghanistan   Naghlu Dam Hydroelectric Power Plant Afghanistan
# 3     AFG  Afghanistan  Nangarhar (Darunta) Hydroelectric Power Plant ...
# 4     AFG  Afghanistan            Northwest Kabul Power Plant Afghanistan
#
#       gppd_idnr  capacity_mw  latitude  longitude primary_fuel other_fuel1  \
# 0  GEODB0040538        33.00   32.3220    65.1190        Hydro         NaN
# 1  GEODB0040541        66.00   34.5560    69.4787        Hydro         NaN
# 2  GEODB0040534       100.00   34.6410    69.7170        Hydro         NaN
# 3  GEODB0040536        11.55   34.4847    70.3633        Hydro         NaN
# 4  GEODB0040540        42.00   34.5638    69.1134          Gas         NaN
#
#   other_fuel2  ...                                 url  geolocation_source  \
# 0         NaN  ...  http://globalenergyobservatory.org               GEODB
# 1         NaN  ...  http://globalenergyobservatory.org               GEODB
# 2         NaN  ...  http://globalenergyobservatory.org               GEODB
# 3         NaN  ...  http://globalenergyobservatory.org               GEODB
# 4         NaN  ...  http://globalenergyobservatory.org               GEODB
#
#    wepp_id year_of_capacity_data generation_gwh_2013 generation_gwh_2014  \
# 0  1009793                2017.0                 NaN                 NaN
# 1  1009795                2017.0                 NaN                 NaN
# 2  1009797                2017.0                 NaN                 NaN
# 3  1009787                2017.0                 NaN                 NaN
# 4      NaN                2017.0                 NaN                 NaN
#
#   generation_gwh_2015  generation_gwh_2016  generation_gwh_2017  \
# 0                 NaN                  NaN                  NaN
# 1                 NaN                  NaN                  NaN
# 2                 NaN                  NaN                  NaN
# 3                 NaN                  NaN                  NaN
# 4                 NaN                  NaN                  NaN
#
#    estimated_generation_gwh
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
#
# [5 rows x 24 columns]

# %% [markdown]
# Erstelle ein Dataframe das den dritt- und den zweitletzten Eintrag beinhaltet

# %%
# df.sort_values('Spaltenname', ascending = False)

# %%
df_letzte3 = df.tail(3)
df_letzte3
# Out:
#       country country_long                                               name  \
# 29907     ZMB       Zambia                                     Victoria Falls
# 29908     ZWE     Zimbabwe                   Hwange Coal Power Plant Zimbabwe
# 29909     ZWE     Zimbabwe  Kariba Dam South Hydroelectric Power Station Z...
#
#           gppd_idnr  capacity_mw  latitude  longitude primary_fuel  \
# 29907    WRI1022380        108.0  -17.9167    25.8500        Hydro
# 29908  GEODB0040404        920.0  -18.3835    26.4700         Coal
# 29909  GEODB0003803        750.0  -16.5222    28.7619        Hydro
#
#       other_fuel1 other_fuel2  ...  \
# 29907         NaN         NaN  ...
# 29908         NaN         NaN  ...
# 29909         NaN         NaN  ...
#
#                                                      url  geolocation_source  \
# 29907  http://www.erb.org.zm/reports/EnergySectorRepo...        Power Africa
# 29908                 http://globalenergyobservatory.org               GEODB
# 29909                 http://globalenergyobservatory.org               GEODB
#
#        wepp_id year_of_capacity_data generation_gwh_2013 generation_gwh_2014  \
# 29907  1033763                   NaN                 NaN                 NaN
# 29908  1033856                2017.0                 NaN                 NaN
# 29909  1033857                2017.0                 NaN                 NaN
#
#       generation_gwh_2015  generation_gwh_2016  generation_gwh_2017  \
# 29907                 NaN                  NaN                  NaN
# 29908                 NaN                  NaN                  NaN
# 29909                 NaN                  NaN                  NaN
#
#        estimated_generation_gwh
# 29907                     702.1
# 29908                    4397.0
# 29909                    5431.0
#
# [3 rows x 24 columns]

# %%
res = df.tail(3).head(2)
res
# Out:
#       country country_long                              name     gppd_idnr  \
# 29907     ZMB       Zambia                    Victoria Falls    WRI1022380
# 29908     ZWE     Zimbabwe  Hwange Coal Power Plant Zimbabwe  GEODB0040404
#
#        capacity_mw  latitude  longitude primary_fuel other_fuel1 other_fuel2  \
# 29907        108.0  -17.9167      25.85        Hydro         NaN         NaN
# 29908        920.0  -18.3835      26.47         Coal         NaN         NaN
#
#        ...                                                url  \
# 29907  ...  http://www.erb.org.zm/reports/EnergySectorRepo...
# 29908  ...                 http://globalenergyobservatory.org
#
#        geolocation_source  wepp_id year_of_capacity_data generation_gwh_2013  \
# 29907        Power Africa  1033763                   NaN                 NaN
# 29908               GEODB  1033856                2017.0                 NaN
#
#       generation_gwh_2014 generation_gwh_2015  generation_gwh_2016  \
# 29907                 NaN                 NaN                  NaN
# 29908                 NaN                 NaN                  NaN
#
#        generation_gwh_2017  estimated_generation_gwh
# 29907                  NaN                     702.1
# 29908                  NaN                    4397.0
#
# [2 rows x 24 columns]
