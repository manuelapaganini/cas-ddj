# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
# Hier sind die Grundvorausetzungen
url = "https://kr-geschaefte.zug.ch/gast/geschaefte?commit=Filtern&geschaeft_filter[abgeschlossen_bis]=&geschaeft_filter[abgeschlossen_von]=&geschaeft_filter[arten_refs][]=&geschaeft_filter[eingereicht_bis]=&geschaeft_filter[eingereicht_von]=&geschaeft_filter[frist_bis]=&geschaeft_filter[historische_staende_refs][]=&geschaeft_filter[kommissionen_refs][]=&geschaeft_filter[staende_refs][]=&geschaeft_filter[status_ids][]=haengig&geschaeft_filter[status_ids][]=abgeschlossen&geschaeft_filter[status_ids][]=&geschaeft_filter[titel]=&geschaeft_filter[zustaendig_refs][]=&page="

alle_seiten = []

def create_mini_dict(row)
    sth_new = row[]
    "Link" = row[0]
    
   mini_var = 
#    return mini_var

#Hier kommt der scrape-block: wir loopen durch die übersichts-seiten

#for page_number in range(1, 41):
    
r = requests.get(url+str(1)) #page_number))
contents = r.text
soup = BeautifulSoup(contents, 'html.parser')
tr_list = soup.find_all("tr")[2:]

for line in tr_list:
    create_mini_dict(line)

#Dann loopen
# Out:
# [<tr>
#  <td><a href="/gast/geschaefte/1998">3010</a></td>
#  <td><a href="/gast/geschaefte/1998">Postulat von Ivo Egger, Stéphanie Vuichard, Hanni Schriber-Neiger und Andreas Lustenberger betreffend eines klimaneutralen, kantonalen Gebäudeparks des Kantons Zug</a></td>
#  <td class="hidden-xs">Einreichung</td>
#  <td class="hidden-xs">Baudirektion</td>
#  <td class="hidden-xs">Postulat</td>
#  <td class="hidden-xs">hängig</td>
#  </tr>, <tr>
#  <td><a href="/gast/geschaefte/1997">3009</a></td>
#  <td><a href="/gast/geschaefte/1997">Postulat von Stéphanie Vuichard, Mariann Hess und Rita Hofer betreffend Biodiversitätsförderung</a></td>
#  <td class="hidden-xs">Einreichung</td>
#  <td class="hidden-xs">Baudirektion</td>
#  <td class="hidden-xs">Postulat</td>
#  <td class="hidden-xs">hängig</td>
#  </tr>, <tr>
#  <td><a href="/gast/geschaefte/1996">3008</a></td>
# ...

# %%
# Hier teste ich Kram:
url = "https://kr-geschaefte.zug.ch/gast/geschaefte?commit=Filtern&geschaeft_filter[abgeschlossen_bis]=&geschaeft_filter[abgeschlossen_von]=&geschaeft_filter[arten_refs][]=&geschaeft_filter[eingereicht_bis]=&geschaeft_filter[eingereicht_von]=&geschaeft_filter[frist_bis]=&geschaeft_filter[historische_staende_refs][]=&geschaeft_filter[kommissionen_refs][]=&geschaeft_filter[staende_refs][]=&geschaeft_filter[status_ids][]=haengig&geschaeft_filter[status_ids][]=abgeschlossen&geschaeft_filter[status_ids][]=&geschaeft_filter[titel]=&geschaeft_filter[zustaendig_refs][]=&page="

r = requests.get(url+str(1)) #page_number))
contents = r.text
soup = BeautifulSoup(contents, 'html.parser')
tr_list = soup.find_all("tr")[2:]


tr_list
