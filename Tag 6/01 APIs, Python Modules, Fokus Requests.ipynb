# %% [markdown]
# # APIs, Modules und "Requests"
# Gezielt und automatisiert Daten im Web auslesen

# %% [markdown]
# Zuerst installieren wir pandas und requests. Das können wir von der Command line mit den Befehlen ```pip install requests``` und ```pip install pandas``` die beiden Module installieren. Oder direkt hier in Jupyter Notebook mit ```!pip install requests``` und ```!pip install pandas```.

# %% [markdown]
# Die Python-Library erlaubt es, automatisiert URLs zu besuchen und gezielt Inhalte herauszulesen. Der Untertitel in [der Dokumentation](http://docs.python-requests.org/en/master/) fasst eigentlich am besten zusammen, was ```requests``` ist: "HTTP for Humans." HTTP steht für Hyper Text Transfer Protocol und ist die Technologie, die Tim Berners-Lee im Jahr 1990 erfunden hat. Ohne HTTP kein Internet. Mit ```Requests```können wir Websites viel genauer befragen, als wir das mit Wget letzte Woche kennengelernt haben.

# %% [markdown]
# ### Unsere Imports

# %%
import requests
import pandas as pd #diese Library werdet ihr am Mittwoch und Donnerstag viel genauer anschauen

# %% [markdown]
# Zur Dokumentation von ```requests``` geht es [hier lang](http://docs.python-requests.org/en/master/).

# %% [markdown]
# ### Notes

# %% [markdown]
# In einer ersten Übung arbeiten wir mit [der API des USGS](https://earthquake.usgs.gov/fdsnws/event/1/#methods) arbeiten. Für die meisten API muss man sich heutezutage eine eigene API-Key kreieren. Das werden wir zu einem späteren Zeitpunkt tun. Diese API braucht keine Keys. Deshalb ist es ein gutes Kennenlernbeispiel.

# %% [markdown]
# Falls Probleme mit dem Output auftauchen, hier ein Work around für die Meldung, dass der Output limitiert wurde. [Reconfigure line output](https://stackoverflow.com/questions/43288550/iopub-data-rate-exceeded-when-viewing-image-in-jupyter-notebook) and [opening stuff from the command line](https://stackoverflow.com/questions/16344709/how-to-open-a-file-from-the-command-line-with-a-specified-program)

# %% [markdown]
# ### Dokumentation

# %% [markdown]
# Bevor man mit deiner API arbeitet, lohnt es sich immer zuerst, die [Dokumentation](https://earthquake.usgs.gov/fdsnws/event/1/#parameters) anzuschauen.

# %% [markdown]
# ### Erste Abfragen

# %% [markdown]
# Kleinere Abfrage. Wieviele Erdbeben hat es in einem bestimmten Zeitraum gegeben?

# %%
url = 'https://earthquake.usgs.gov/fdsnws/event/1/count?starttime=2018-09-01&endtime=2018-09-30'

# %%
response = requests.get(url)

# %%
response
# Out:
# <Response [200]>

# %%
response.text
# Out:
# '11436'

# %% [markdown]
# Wieviele hat es letzte Nacht von 22 bis 6 Uhr morgens gegeben? Dafür müssen wir in der Dokumentation Time nachfragen.

# %%
url = 'https://earthquake.usgs.gov/fdsnws/event/1/count?starttime=2018-09-26&endtime=2018-09-27'

# %%
response = requests.get(url)

# %%
response.text
# Out:
# '436'

# %% [markdown]
# Wegen Zeitverschiebung Zeit anpassen.

# %%
url = 'https://earthquake.usgs.gov/fdsnws/event/1/count?starttime=2018-09-20T24:00:00&endtime=2018-09-21T08:00:00'

# %%
response = requests.get(url)
response.text
# Out:
# '110'

# %% [markdown]
# ### Grosse, komibinierte Abfrage

# %% [markdown]
# Details zu allen Erbeben in den über drei Tage, 18-7-2017 bis 31-7-2017.

# %%
url1 = 'https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson'

# %%
urlzeit = '&starttime=2018-07-29T24:00:00&endtime=2018-07-31T08:00:00'

# %%
url1 + urlzeit
# Out:
# 'https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=2018-07-29T24:00:00&endtime=2018-07-31T08:00:00'

# %%
response = requests.get(url1+urlzeit)
response.text
# Out:
# '{"type":"FeatureCollection","metadata":{"generated":1569178079000,"url":"https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=2018-07-29T24:00:00&endtime=2018-07-31T08:00:00","title":"USGS Earthquakes","status":200,"api":"1.8.1","count":1475},"features":[{"type":"Feature","properties":{"mag":2.4500000000000002,"place":"5km SSW of Volcano, Hawaii","time":1533023876310,"updated":1533052838207,"tz":-600,"url":"https://earthquake.usgs.gov/earthquakes/eventpage/hv70501722","detail":"https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=hv70501722&format=geojson","felt":null,"cdi":null,"mmi":null,"alert":null,"status":"automatic","tsunami":0,"sig":92,"net":"hv","code":"70501722","ids":",hv70501722,","sources":",hv,","types":",geoserve,origin,phase-data,","nst":14,"dmin":0.011820000000000001,"rms":0.29999999999999999,"gap":95,"magType":"ml","type":"earthquake","title":"M 2.5 - 5km SSW of Volcano, Hawaii"},"geometry":{"type":"Point","coordinates":[-155.2603302,19.3876667,-0.14999999999999999]},"id":"hv70501722"},\n{"type":"Feature","properties":{"mag":0.28000000000000003,"place":"4km SW of Mammoth Lakes, CA","time":1533023810000,"updated":1533077215403,"tz":-480,"url":"https://earthquake.usgs.gov/earthquakes/eventpage/nc73061846","detail":"https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc73061846&format=geojson","felt":null,"cdi":null,"mmi":null,"alert":null,"status":"reviewed","tsunami":0,"sig":1,"net":"nc","code":"73061846","ids":",nc73061846,","sources":",nc,","types":",geoserve,nearby-cities,origin,phase-data,","nst":13,"dmin":0.0056849999999999999,"rms":0.029999999999999999,"gap":157,"magType":"md","type":"earthquake","title":"M 0.3 - 4km SW of Mammoth Lakes, CA"},"geometry":{"type":"Point","coordinates":[-119.0141667,37.613166700000001,0.95999999999999996]},"id":"nc73061846"},\n{"type":"Feature","properties":{"mag":2.8300000000000001,"place":"3km SW of Volcano, Hawaii","time":1533023693860,"updated":1533024043540,"tz":-600,"url":"https://earthquake.usgs.gov/earthquakes/eventpage/hv70501717","detail":"https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=hv70501717&format=geojson","felt":null,"cdi":null,"mmi":null,"alert":null,"status":"automatic","tsunami":0,"sig":123,"net":"hv","code":"70501717","ids":",hv70501717,","sources":",hv,","types":",geoserve,origin,phase-data,","nst":41,"dmin":0.0086409999999999994,"rms":0.25,"gap":43,"magType":"ml","type":"earthquake","title":"M 2.8 - 3km SW of Volcano, Hawaii"},"geometry":{"type":"Point","coordinates":[-155.25849909999999,19.4034996,-0.28000000000000003]},"id":"hv70501717"},\n{"type":"Feature","properties":{"mag":2.8399999999999999,"place":"5km SW of Volcano, Hawaii","time":1533023666030,"updated":1533024011850,"tz":-600,"url":"https://earthquake.usgs.gov/earthquakes/eventpage/hv70501712","detail":"https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=hv70501712&format=geojson","felt":null,"cdi":null,"mmi":null,"alert":null,"status":"automatic","tsunami":0,"sig":124,"net":"hv","code":"70501712","ids":",hv70501712,","sources":",hv,","types":",geoserve,origin,phase-data,","nst":10,"dmin":0.0035590000000000001,"rms":0.14000000000000001,"gap":89,"magType":"ml","type":"earthquake","title":"M 2.8 - 5km SW of Volcano, Hawaii"},"geometry":{"type":"Point","coordinates":[-155.27049260000001,19.397333100000001,0.93000000000000005]},"id":"hv70501712"},\n{"type":"Feature","properties":{"mag":2.3399999999999999,"place":"5km SW of Volcano, Hawaii","time":1533023616600,"updated":1533023958180,"tz":-600,"url":"https://earthquake.usgs.gov/earthquakes/eventpage/hv70501702","detail":"https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=hv70501702&format=geojson","felt":null,"cdi":null,"mmi":null,"alert":null,"status":"automatic","tsunami":0,"sig":84,"net":"hv","code":"70501702","ids":",hv70501702,","sources":",hv,","types":",geoserve,origin,phase-data,","nst":23,"dmin":0.0045300000000000002,"rms":0.20000000000000001,"gap":61,"magType":"ml","type":"earthquake ...

# %% [markdown]
# Alle Erbeben mit den ungefähren Koordinaten von Mexiko. [Hier könnte man die ungefähr nachschlagen.](http://www.latlong.net/)

# %%
urlloc = '&minlatitude=13&maxlatitude=33&minlongitude=-120&maxlongitude=-85'

# %%
url1+urlzeit+urlloc
# Out:
# 'https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=2018-07-29T24:00:00&endtime=2018-07-31T08:00:00&minlatitude=13&maxlatitude=33&minlongitude=-120&maxlongitude=-85'

# %%
response = requests.get(url1+urlzeit+urlloc)
response.text
# Out:
# '{"type":"FeatureCollection","metadata":{"generated":1569178144000,"url":"https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=2018-07-29T24:00:00&endtime=2018-07-31T08:00:00&minlatitude=13&maxlatitude=33&minlongitude=-120&maxlongitude=-85","title":"USGS Earthquakes","status":200,"api":"1.8.1","count":7},"features":[{"type":"Feature","properties":{"mag":4.0999999999999996,"place":"19km NE of San Jeronimo Ixtepec, Mexico","time":1533010343830,"updated":1539704053040,"tz":-360,"url":"https://earthquake.usgs.gov/earthquakes/eventpage/us2000ghw0","detail":"https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us2000ghw0&format=geojson","felt":1,"cdi":2,"mmi":null,"alert":null,"status":"reviewed","tsunami":0,"sig":259,"net":"us","code":"2000ghw0","ids":",us2000ghw0,","sources":",us,","types":",dyfi,geoserve,origin,phase-data,","nst":null,"dmin":2.7370000000000001,"rms":0.96999999999999997,"gap":161,"magType":"mb","type":"earthquake","title":"M 4.1 - 19km NE of San Jeronimo Ixtepec, Mexico"},"geometry":{"type":"Point","coordinates":[-94.958699999999993,16.687999999999999,73.310000000000002]},"id":"us2000ghw0"},\n{"type":"Feature","properties":{"mag":1.8600000000000001,"place":"34km NE of Ensenada, B.C., MX","time":1533008835490,"updated":1533058052742,"tz":-480,"url":"https://earthquake.usgs.gov/earthquakes/eventpage/ci38233848","detail":"https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci38233848&format=geojson","felt":null,"cdi":null,"mmi":null,"alert":null,"status":"reviewed","tsunami":0,"sig":53,"net":"ci","code":"38233848","ids":",ci38233848,","sources":",ci,","types":",geoserve,nearby-cities,origin,phase-data,scitech-link,","nst":20,"dmin":0.30030000000000001,"rms":0.20000000000000001,"gap":169,"magType":"ml","type":"earthquake","title":"M 1.9 - 34km NE of Ensenada, B.C., MX"},"geometry":{"type":"Point","coordinates":[-116.399,32.112833299999998,16.030000000000001]},"id":"ci38233848"},\n{"type":"Feature","properties":{"mag":1.8500000000000001,"place":"9km W of Progreso, B.C., MX","time":1532977028010,"updated":1533060562548,"tz":-480,"url":"https://earthquake.usgs.gov/earthquakes/eventpage/ci38233408","detail":"https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci38233408&format=geojson","felt":1,"cdi":3.1000000000000001,"mmi":null,"alert":null,"status":"reviewed","tsunami":0,"sig":53,"net":"ci","code":"38233408","ids":",ci38233408,","sources":",ci,","types":",dyfi,geoserve,nearby-cities,origin,phase-data,scitech-link,","nst":26,"dmin":0.085019999999999998,"rms":0.22,"gap":87,"magType":"ml","type":"earthquake","title":"M 1.9 - 9km W of Progreso, B.C., MX"},"geometry":{"type":"Point","coordinates":[-115.6803333,32.573500000000003,9.9199999999999999]},"id":"ci38233408"},\n{"type":"Feature","properties":{"mag":1.8200000000000001,"place":"26km ENE of Pine Valley, CA","time":1532964179630,"updated":1532965631270,"tz":-480,"url":"https://earthquake.usgs.gov/earthquakes/eventpage/ci38233160","detail":"https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci38233160&format=geojson","felt":null,"cdi":null,"mmi":null,"alert":null,"status":"reviewed","tsunami":0,"sig":51,"net":"ci","code":"38233160","ids":",ci38233160,","sources":",ci,","types":",focal-mechanism,geoserve,nearby-cities,origin,phase-data,scitech-link,","nst":38,"dmin":0.13109999999999999,"rms":0.20999999999999999,"gap":67,"magType":"ml","type":"earthquake","title":"M 1.8 - 26km ENE of Pine Valley, CA"},"geometry":{"type":"Point","coordinates":[-116.26649999999999,32.889000000000003,6.8899999999999997]},"id":"ci38233160"},\n{"type":"Feature","properties":{"mag":1.8600000000000001,"place":"6km WSW of Holtville, CA","time":1532953778000,"updated":1533051921620,"tz":-480,"url":"https://earthquake.usgs.gov/earthquakes/eventpage/ci38233112","detail":"https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci38233112&format=geojson","felt":null,"cdi":null,"mmi":null,"alert":null,"status":"reviewed","tsunami":0,"sig":53,"net":"ci","code":" ...

# %% [markdown]
# Dieser Wulst lässt sich aber ziemlich schwer lesen. Deshalb müssen wir das zuerst umformatieren und dann verstehen, wie das ganze strukturiert ist.

# %%
response.json()
# Out:
# {'type': 'FeatureCollection',
#  'metadata': {'generated': 1569178144000,
#   'url': 'https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=2018-07-29T24:00:00&endtime=2018-07-31T08:00:00&minlatitude=13&maxlatitude=33&minlongitude=-120&maxlongitude=-85',
#   'title': 'USGS Earthquakes',
#   'status': 200,
#   'api': '1.8.1',
#   'count': 7},
#  'features': [{'type': 'Feature',
#    'properties': {'mag': 4.1,
#     'place': '19km NE of San Jeronimo Ixtepec, Mexico',
#     'time': 1533010343830,
#     'updated': 1539704053040,
#     'tz': -360,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us2000ghw0',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us2000ghw0&format=geojson',
#     'felt': 1,
#     'cdi': 2,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 259,
#     'net': 'us',
#     'code': '2000ghw0',
#     'ids': ',us2000ghw0,',
#     'sources': ',us,',
#     'types': ',dyfi,geoserve,origin,phase-data,',
#     'nst': None,
#     'dmin': 2.737,
#     'rms': 0.97,
#     'gap': 161,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.1 - 19km NE of San Jeronimo Ixtepec, Mexico'},
#    'geometry': {'type': 'Point', 'coordinates': [-94.9587, 16.688, 73.31]},
#    'id': 'us2000ghw0'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.86,
#     'place': '34km NE of Ensenada, B.C., MX',
#     'time': 1533008835490,
#     'updated': 1533058052742,
#     'tz': -480,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci38233848',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci38233848&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 53,
#     'net': 'ci',
#     'code': '38233848',
#     'ids': ',ci38233848,',
#     'sources': ',ci,',
#     'types': ',geoserve,nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 20,
#     'dmin': 0.3003,
#     'rms': 0.2,
#     'gap': 169,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.9 - 34km NE of Ensenada, B.C., MX'},
#    'geometry': {'type': 'Point', 'coordinates': [-116.399, 32.1128333, 16.03]},
#    'id': 'ci38233848'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.85,
#     'place': '9km W of Progreso, B.C., MX',
#     'time': 1532977028010,
#     'updated': 1533060562548,
#     'tz': -480,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci38233408',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci38233408&format=geojson',
#     'felt': 1,
#     'cdi': 3.1,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 53,
#     'net': 'ci',
#     'code': '38233408',
#     'ids': ',ci38233408,',
#     'sources': ',ci,',
#     'types': ',dyfi,geoserve,nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 26,
#     'dmin': 0.08502,
#     'rms': 0.22,
#     'gap': 87,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.9 - 9km W of Progreso, B.C., MX'},
#    'geometry': {'type': 'Point', 'coordinates': [-115.6803333, 32.5735, 9.92]},
#    'id': 'ci38233408'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.82,
#     'place': '26km ENE of Pine Valley, CA',
#     'time': 1532964179630,
#     'updated': 1532965631270,
#     'tz': -480,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci38233160',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci38233160&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 51,
#     'net': 'ci',
#     'code': '38233160',
#     'ids': ',ci38233160,',
#     'sources': ',ci,',
#     'types': ',focal-mechanism,geoserve,nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 38,
#     'dmin': 0.1311,
#     'rms': 0.21,
#     'gap': 67,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.8 - 26km ENE of Pine Valley, CA'},
#    'geometry': {'type': 'Point', 'coordinates': [-116.2665, 32.889, 6.89]},
#    'id': 'ci38233160'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.86,
#     'place': '6km WSW of Holtville, CA',
#     'time': 1532953778000,
#     'updated': 1533051921620,
#     'tz': -480,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci38233112',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci38233112&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 53,
#     'net': 'ci',
#     'code': '38233112',
#     'ids': ',ci38233112,',
#     'sources': ',ci,',
#     'types': ',geoserve,nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 34,
#     'dmin': 0.01344,
#     'rms': 0.22,
#     'gap': 33,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.9 - 6km WSW of Holtville, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-115.4395, 32.7933333, 11.89]},
#    'id': 'ci38233112'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.67,
#     'place': '70km WSW of Alberto Oviedo Mota, B.C., MX',
#     'time': 1532941201800,
#     'updated': 1532974980642,
#     'tz': -480,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci37408933',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci37408933&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 43,
#     'net': 'ci',
#     'code': '37408933',
#     'ids': ',ci37408933,',
#     'sources': ',ci,',
#     'types': ',geoserve,nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 14,
#     'dmin': 0.1601,
#     'rms': 0.22,
#     'gap': 172,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.7 - 70km WSW of Alberto Oviedo Mota, B.C., MX'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-115.8056667, 31.8996667, 7.06]},
#    'id': 'ci37408933'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.79,
#     'place': '72km WSW of Alberto Oviedo Mota, B.C., MX',
#     'time': 1532931837280,
#     'updated': 1533049838920,
#     'tz': -480,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci38233000',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci38233000&format=geojson',
#     'felt': 1,
#     'cdi': 2,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 120,
#     'net': 'ci',
#     'code': '38233000',
#     'ids': ',ci38233000,',
#     'sources': ',ci,',
#     'types': ',dyfi,geoserve,nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 14,
#     'dmin': 0.1449,
#     'rms': 0.22,
#     'gap': 118,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.8 - 72km WSW of Alberto Oviedo Mota, B.C., MX'},
#    'geometry': {'type': 'Point', 'coordinates': [-115.8281667, 31.9015, 8.26]},
#    'id': 'ci38233000'}],
#  'bbox': [-116.399, 16.688, 6.89, -94.9587, 32.889, 73.31]}

# %%
dct = response.json()

# %% [markdown]
# Um sicher zu gehen, prüfen wir nochmals den Datentyp.

# %%
type(dct)
# Out:
# dict

# %%
len(dct)
# Out:
# 4

# %% [markdown]
# Schauen wir uns alle keys und values an

# %%
for key in dct:
    print(key)
# Out:
# type
# metadata
# features
# bbox

# %% [markdown]
# Features interessiert uns.

# %%
dct['features']
# Out:
# [{'type': 'Feature',
#   'properties': {'mag': 4.1,
#    'place': '19km NE of San Jeronimo Ixtepec, Mexico',
#    'time': 1533010343830,
#    'updated': 1539704053040,
#    'tz': -360,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us2000ghw0',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us2000ghw0&format=geojson',
#    'felt': 1,
#    'cdi': 2,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 259,
#    'net': 'us',
#    'code': '2000ghw0',
#    'ids': ',us2000ghw0,',
#    'sources': ',us,',
#    'types': ',dyfi,geoserve,origin,phase-data,',
#    'nst': None,
#    'dmin': 2.737,
#    'rms': 0.97,
#    'gap': 161,
#    'magType': 'mb',
#    'type': 'earthquake',
#    'title': 'M 4.1 - 19km NE of San Jeronimo Ixtepec, Mexico'},
#   'geometry': {'type': 'Point', 'coordinates': [-94.9587, 16.688, 73.31]},
#   'id': 'us2000ghw0'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.86,
#    'place': '34km NE of Ensenada, B.C., MX',
#    'time': 1533008835490,
#    'updated': 1533058052742,
#    'tz': -480,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci38233848',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci38233848&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 53,
#    'net': 'ci',
#    'code': '38233848',
#    'ids': ',ci38233848,',
#    'sources': ',ci,',
#    'types': ',geoserve,nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 20,
#    'dmin': 0.3003,
#    'rms': 0.2,
#    'gap': 169,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.9 - 34km NE of Ensenada, B.C., MX'},
#   'geometry': {'type': 'Point', 'coordinates': [-116.399, 32.1128333, 16.03]},
#   'id': 'ci38233848'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.85,
#    'place': '9km W of Progreso, B.C., MX',
#    'time': 1532977028010,
#    'updated': 1533060562548,
#    'tz': -480,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci38233408',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci38233408&format=geojson',
#    'felt': 1,
#    'cdi': 3.1,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 53,
#    'net': 'ci',
#    'code': '38233408',
#    'ids': ',ci38233408,',
#    'sources': ',ci,',
#    'types': ',dyfi,geoserve,nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 26,
#    'dmin': 0.08502,
#    'rms': 0.22,
#    'gap': 87,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.9 - 9km W of Progreso, B.C., MX'},
#   'geometry': {'type': 'Point', 'coordinates': [-115.6803333, 32.5735, 9.92]},
#   'id': 'ci38233408'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.82,
#    'place': '26km ENE of Pine Valley, CA',
#    'time': 1532964179630,
#    'updated': 1532965631270,
#    'tz': -480,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci38233160',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci38233160&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 51,
#    'net': 'ci',
#    'code': '38233160',
#    'ids': ',ci38233160,',
#    'sources': ',ci,',
#    'types': ',focal-mechanism,geoserve,nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 38,
#    'dmin': 0.1311,
#    'rms': 0.21,
#    'gap': 67,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.8 - 26km ENE of Pine Valley, CA'},
#   'geometry': {'type': 'Point', 'coordinates': [-116.2665, 32.889, 6.89]},
#   'id': 'ci38233160'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.86,
#    'place': '6km WSW of Holtville, CA',
#    'time': 1532953778000,
#    'updated': 1533051921620,
#    'tz': -480,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci38233112',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci38233112&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 53,
#    'net': 'ci',
#    'code': '38233112',
#    'ids': ',ci38233112,',
#    'sources': ',ci,',
#    'types': ',geoserve,nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 34,
#    'dmin': 0.01344,
#    'rms': 0.22,
#    'gap': 33,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.9 - 6km WSW of Holtville, CA'},
#   'geometry': {'type': 'Point', 'coordinates': [-115.4395, 32.7933333, 11.89]},
#   'id': 'ci38233112'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.67,
#    'place': '70km WSW of Alberto Oviedo Mota, B.C., MX',
#    'time': 1532941201800,
#    'updated': 1532974980642,
#    'tz': -480,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci37408933',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci37408933&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 43,
#    'net': 'ci',
#    'code': '37408933',
#    'ids': ',ci37408933,',
#    'sources': ',ci,',
#    'types': ',geoserve,nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 14,
#    'dmin': 0.1601,
#    'rms': 0.22,
#    'gap': 172,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.7 - 70km WSW of Alberto Oviedo Mota, B.C., MX'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-115.8056667, 31.8996667, 7.06]},
#   'id': 'ci37408933'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.79,
#    'place': '72km WSW of Alberto Oviedo Mota, B.C., MX',
#    'time': 1532931837280,
#    'updated': 1533049838920,
#    'tz': -480,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci38233000',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci38233000&format=geojson',
#    'felt': 1,
#    'cdi': 2,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 120,
#    'net': 'ci',
#    'code': '38233000',
#    'ids': ',ci38233000,',
#    'sources': ',ci,',
#    'types': ',dyfi,geoserve,nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 14,
#    'dmin': 0.1449,
#    'rms': 0.22,
#    'gap': 118,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 2.8 - 72km WSW of Alberto Oviedo Mota, B.C., MX'},
#   'geometry': {'type': 'Point', 'coordinates': [-115.8281667, 31.9015, 8.26]},
#   'id': 'ci38233000'}]

# %%
type(dct['features'])
# Out:
# list

# %%
dct['features'][0]
# Out:
# {'type': 'Feature',
#  'properties': {'mag': 4.1,
#   'place': '19km NE of San Jeronimo Ixtepec, Mexico',
#   'time': 1533010343830,
#   'updated': 1539704053040,
#   'tz': -360,
#   'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us2000ghw0',
#   'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us2000ghw0&format=geojson',
#   'felt': 1,
#   'cdi': 2,
#   'mmi': None,
#   'alert': None,
#   'status': 'reviewed',
#   'tsunami': 0,
#   'sig': 259,
#   'net': 'us',
#   'code': '2000ghw0',
#   'ids': ',us2000ghw0,',
#   'sources': ',us,',
#   'types': ',dyfi,geoserve,origin,phase-data,',
#   'nst': None,
#   'dmin': 2.737,
#   'rms': 0.97,
#   'gap': 161,
#   'magType': 'mb',
#   'type': 'earthquake',
#   'title': 'M 4.1 - 19km NE of San Jeronimo Ixtepec, Mexico'},
#  'geometry': {'type': 'Point', 'coordinates': [-94.9587, 16.688, 73.31]},
#  'id': 'us2000ghw0'}

# %%
dct['features'][0]
# Out:
# {'type': 'Feature',
#  'properties': {'mag': 4.1,
#   'place': '19km NE of San Jeronimo Ixtepec, Mexico',
#   'time': 1533010343830,
#   'updated': 1539704053040,
#   'tz': -360,
#   'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us2000ghw0',
#   'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us2000ghw0&format=geojson',
#   'felt': 1,
#   'cdi': 2,
#   'mmi': None,
#   'alert': None,
#   'status': 'reviewed',
#   'tsunami': 0,
#   'sig': 259,
#   'net': 'us',
#   'code': '2000ghw0',
#   'ids': ',us2000ghw0,',
#   'sources': ',us,',
#   'types': ',dyfi,geoserve,origin,phase-data,',
#   'nst': None,
#   'dmin': 2.737,
#   'rms': 0.97,
#   'gap': 161,
#   'magType': 'mb',
#   'type': 'earthquake',
#   'title': 'M 4.1 - 19km NE of San Jeronimo Ixtepec, Mexico'},
#  'geometry': {'type': 'Point', 'coordinates': [-94.9587, 16.688, 73.31]},
#  'id': 'us2000ghw0'}

# %% [markdown]
# Schauen wir uns das erste Element an

# %%
for key in dct['features'][0]:
    print(key)
# Out:
# type
# properties
# geometry
# id

# %%
dct['features'][0]['properties']
# Out:
# {'mag': 4.1,
#  'place': '19km NE of San Jeronimo Ixtepec, Mexico',
#  'time': 1533010343830,
#  'updated': 1539704053040,
#  'tz': -360,
#  'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us2000ghw0',
#  'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us2000ghw0&format=geojson',
#  'felt': 1,
#  'cdi': 2,
#  'mmi': None,
#  'alert': None,
#  'status': 'reviewed',
#  'tsunami': 0,
#  'sig': 259,
#  'net': 'us',
#  'code': '2000ghw0',
#  'ids': ',us2000ghw0,',
#  'sources': ',us,',
#  'types': ',dyfi,geoserve,origin,phase-data,',
#  'nst': None,
#  'dmin': 2.737,
#  'rms': 0.97,
#  'gap': 161,
#  'magType': 'mb',
#  'type': 'earthquake',
#  'title': 'M 4.1 - 19km NE of San Jeronimo Ixtepec, Mexico'}

# %% [markdown]
# Lesen wir folgendes aus:
# 1. Type
# 2. Magnitude
# 4. Örtlichkeit
# 5. Time

# %%
earthquakes = []

for elem in dct['features']:
    
    t = elem['properties']['type']
    m = elem['properties']['mag']
    p = elem['properties']['place']
    tm = elem['properties']['time']
    
    mini_dict = {'Type': t,
                 'Mag': m,
                 'Place': p,
                 'Time': tm}
    
    earthquakes.append(mini_dict)

# %% [markdown]
# Dealing with Unix time

# %%
pd.DataFrame(earthquakes).to_csv('testfile.csv')

# %%
earthquakes = []

for elem in dct['features']:
    t = elem['properties']['type']
    m = elem['properties']['mag']
    p = elem['properties']['place']
    
    #Ints bearbeiten, die letzten drei Stellen abschneiden
    tm = str(elem['properties']['time'])[:-3]
        
    mini_dict = {'Type': t,
                 'Mag': m,
                 'Place': p,
                 'Time': tm}
    
    earthquakes.append(mini_dict)

# %%
pd.DataFrame(earthquakes)
# Out:
#     Mag                                      Place        Time        Type
# 0  4.10    19km NE of San Jeronimo Ixtepec, Mexico  1533010343  earthquake
# 1  1.86              34km NE of Ensenada, B.C., MX  1533008835  earthquake
# 2  1.85                9km W of Progreso, B.C., MX  1532977028  earthquake
# 3  1.82                26km ENE of Pine Valley, CA  1532964179  earthquake
# 4  1.86                   6km WSW of Holtville, CA  1532953778  earthquake
# 5  1.67  70km WSW of Alberto Oviedo Mota, B.C., MX  1532941201  earthquake
# 6  2.79  72km WSW of Alberto Oviedo Mota, B.C., MX  1532931837  earthquake

# %% [markdown]
# ### Erste Erfahrung mit Pandas

# %%
pd.DataFrame(earthquakes)
# Out:
#     Mag                                      Place        Time        Type
# 0  4.10    19km NE of San Jeronimo Ixtepec, Mexico  1533010343  earthquake
# 1  1.86              34km NE of Ensenada, B.C., MX  1533008835  earthquake
# 2  1.85                9km W of Progreso, B.C., MX  1532977028  earthquake
# 3  1.82                26km ENE of Pine Valley, CA  1532964179  earthquake
# 4  1.86                   6km WSW of Holtville, CA  1532953778  earthquake
# 5  1.67  70km WSW of Alberto Oviedo Mota, B.C., MX  1532941201  earthquake
# 6  2.79  72km WSW of Alberto Oviedo Mota, B.C., MX  1532931837  earthquake

# %%
df = pd.DataFrame(earthquakes)

# %% [markdown]
# Speichern wir das ab.

# %%
df.to_csv('erdbeben.csv')

# %% [markdown]
# # Üben wir das Ganze! Weiter zur Übung 1.
